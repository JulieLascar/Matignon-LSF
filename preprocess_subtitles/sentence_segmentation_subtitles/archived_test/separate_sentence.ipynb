# %% [markdown]
# # Intermediate Processing
#
# This notebook allows retrieving, from a subtitle file, two new files that will be used to obtain sentence-segmented subtitles:
# 1. An oversubtitled .vtt subtitle file, where each subtitle corresponds exclusively to a sentence or a portion of sentences.
# 2. (archived) A .txt file containing one sentence per line.

# %%
import spacy
import os
import re
import module_traitement as m
# spacy.prefer_gpu()
# nlp = spacy.load("fr_dep_news_trf")
# from spacy.language import Language

# %%
# Pour Mediapi
file_with_path = m.lister_fichiers_with_path("../data/aligned_mediapi/")
folder = m.lister_fichiers("../data/aligned_mediapi/")
output_seg = "../data/new_segmentation_mediapi/"
output_sent = "../data/sentence_mediapi/"

# %%
# Pour Matignon - LSF 
file_with_path = m.lister_fichiers_with_path("../data/cr_audio_aligned/")
folder = m.lister_fichiers("../data/cr_audio_aligned/")
output_seg = "../data/new_segmentation_cr/"
output_sent = "../data/sentence_matignon/"

# %% [markdown]
# ## 1. Clean files
# Clean the file before various preprocessing steps to facilitate sentence detection and segmentation

# %%
# TEST - Pour Matignon - LSF 
file_with_path = m.lister_fichiers_with_path("../data/cr_audio_aligned/")
folder = m.lister_fichiers("../data/cr_audio_aligned/")
output_seg = "test_new_seg_cr/"
output_cleaning = "test_cleaning_cr/"
#output_sent = "../data/sentence_matignon/"

# %%
# TEST - Pour Mediapi 
file_with_path = m.lister_fichiers_with_path("../data/aligned_mediapi//")
folder = m.lister_fichiers("../data/aligned_mediapi/")
output_seg = "test_new_seg_mediapi/"
output_cleaning = "test_cleaning_mediapi/"
#output_sent = "../data/sentence_matignon/"

# %%
def convertir_grand_nombre(nombre_texte):
    nombre_sans_points = re.sub(r'(\d)\.(\d)', r'\1\2', nombre_texte)
    return nombre_sans_points

def remplacer_points_adresses_email(texte):
    # Expression régulière pour repérer les adresses e-mail
    pattern = r'\b[\w.%+-]+@[\w.-]+\.[a-zA-Z]{2,}\b'

    # Fonction de remplacement pour remplacer les points par "POINT"
    def remplacer(match):
        return match.group().replace('.', 'POINT')

    texte_modifie = re.sub(pattern, remplacer, texte)
    return texte_modifie

def remplacer_points_adresses(texte):
    # Expression régulière pour repérer différentes formes d'adresses de site internet
    pattern = r'\b(?:https?://)?(?:www\.)?[\w.-]+\.[a-zA-Z]{2,}\b'

    # Fonction de remplacement pour remplacer les points par "POINT"
    def remplacer(match):
        return match.group().replace('.', 'POINT')

    texte_modifie = re.sub(pattern, remplacer, texte)
    return texte_modifie

def normaliser_points_de_suspension(texte):
    # Ajouter un espace après les points de suspension suivis d'une lettre
    texte_modifie = re.sub(r'\.\.\.(\w)', r'... \1', texte)

    # Retirer un espace avant les points de suspension précédés d'une lettre
    texte_modifie = re.sub(r'(\w)\s*\.\.\.', r'\1...', texte_modifie)

    return texte_modifie

def remplacer_ponctuation_html(texte):
    substitutions = [
        ("(", "&#40;"),
        (")", "&#41;"),
        ("?", "&#63;"),
        ("!", "&#33;"),
        (".", "&#46;"),
        ("...", "&#8230;")
    ]

    def remplacer_match(match):
        contenu_parentheses = match.group(1)
        for recherche, remplacement in substitutions:
            contenu_parentheses = contenu_parentheses.replace(recherche, remplacement)
        return f'({contenu_parentheses})'

    texte_modifie = re.sub(r'\(([^)]*)\)', remplacer_match, texte)
    return texte_modifie

def get_dict_vtt_clean(input):
    with open(input,encoding="utf-8") as f:
        lines = f.readlines()

    dict_sub = {}
    i = 0
    j = 0  

    while j < len(lines): 
        element = lines[j]
        if element.startswith("00:") or element.startswith("01:") or element.startswith("02:"):
            # Extraire le temps de début et de fin
            timing_line = element.strip().split(' --> ')
            start_time, end_time = timing_line

            text = ""
            while j + 1 < len(lines) and not lines[j + 1].startswith("00:") and not lines[j+1].startswith("01:") and not lines[j+1].startswith("02:"):
                j += 1
                content = lines[j]
                text = text + " " + content.strip()
                text = normaliser_points_de_suspension(text)
                text = text.replace("(...)","[SUSPENSIONP]") #régler ce problème.
                text = text.replace("....","[POINTS4]")
                text = remplacer_ponctuation_html(text)
                ### changement
                text = text.replace("…","...")
                text = text.replace("...","[SUSPENSION].") ### gérer la double suspension !
                text = re.sub(r'["“”«»]', '', text)
                text = text.replace("?!","[INTEREXCL].")
                text = text.replace("(???)","[INTERROGATION3]")
                text = text.replace("(?)","[INTERROGATION1]")
                text = text.replace("(??)","[INTERROGATION2]")
                text = text.replace("( ?)","[INTERROGATION1]")
                text = text.replace("?,","[INTERROGATION],")
                text = text.replace("!,","[EXCLAMATION],")
                text = text.replace("etc.,","[ETC],")
                text = text.replace("etc.)","[ETC])")
                text = text.replace("etc. .","[ETC].")
                text = text.replace("Etc","etc")
                text = text.replace("PAM !","[PAM]")
                text = text.replace("Média'Pi!","[NOM_MEDIA]")
                text = text.replace("Média'Pi !","[NOM_MEDIA]")
                text = text.replace("Media'Pi !","[NOM_MEDIA]")
                text = text.replace("Média'Pi&nbsp;!","[NOM_MEDIA]")
                text = text.replace("Média' Pi !","[NOM_MEDIA]")
                text = text.replace(".e.s","")
                text = text.replace(".ne.s","")
                text = text.replace(".e.","")
                text = text.replace(".e","")
                text = text.replace("!!","!")
                text = text.replace("??","?")
                #text = re.sub(r'\b(\w+)\s*\.\.\.\s*(\w+)\b', r'\1... \2', text)
                text = remplacer_points_adresses_email(text)
                text = remplacer_points_adresses(text)
                text = text.replace(".,","[POINT],")
                text = text.replace("y.a","y a")
                ### 
                text=text.replace("... -G. Attal : ","")
                text=text.replace("-G. Attal : ","")
                text=text.replace("G. Attal : ","")
                text = text.replace("-Bonjour", "Bonjour")
                text = text.replace("Bonjour.", "Bonjour,")
                text = text.replace(" M."," Monsieur")
                text = text.replace(" Mme"," Madame")
                text = text.replace("-"," ")
                text = convertir_grand_nombre(text)
                # text = text.replace("(","&#40;")
                # text = text.replace(")","&#41;")
                

            dict_sub[i] = {'start': start_time, 'end': end_time, 'text': text.strip()}
            i += 1

        j += 1

    return dict_sub

# %%
for file,name in zip(file_with_path,folder):
    dict_sub = get_dict_vtt_clean(file)
    m.create_vtt_file(dict_sub,f"{output_cleaning}/{name}")

# %% [markdown]
# ## 2. Oversubtitled File
#
# In these files, the following treatments are applied:
# 1. Retrieve strong punctuations (period, exclamation mark, question mark) within the subtitles.
# 2. Keep timestamps in memory.
# 3. Obtain the duration of a letter to segment the subtitle accordingly.
# 4. Segment the subtitle and generate a new .vtt file

# %% [markdown]
# ### Processing
#
# The next treatment can be performed twice in case there were multiple strong punctuations.
#
# TODO : I can modify the regular expression to exclude LETTRE_MAJ from my segmentation.

# %%
import module_traitement as m

# %%
file_with_path = m.lister_fichiers_with_path("test_cleaning_mediapi/")
folder = m.lister_fichiers("test_cleaning_mediapi/")

# %%
file_with_path = m.lister_fichiers_with_path("try_seg_end/")
folder = m.lister_fichiers("try_seg_end/")
output_seg="try_seg_end/"

# %%
for file,name in zip(file_with_path,folder):
    print(f"TRAITEMENT {file} ---- {name}")
    dict_sub = get_dict_vtt_clean(file)
    new_dict = {}
    mm = 0
    pattern = r'([.!?]+)[^)]' # bonne solution
    sous_unite = []
    for k, v in dict_sub.items():
        for kk, vv in v.items():
            if kk == "text":
                # Replace the point between two capital letters with '#'
                modified_text = re.sub(r'(?<=[A-Z])\.(?=[A-Z])', '#', vv)
                # Use re.split() to split the text based on the pattern
                sentences = re.split(pattern, modified_text)
                # Combine pairs of adjacent list elements (sentence + punctuation)
                result = [sentences[i] + sentences[i + 1] if i < len(sentences) - 1 else sentences[i] for i in range(0, len(sentences), 2)]
                # Remove empty strings from the result
                result = [sentence.strip() for sentence in result if sentence.strip()]
                if len(result) == 1:
                    if mm not in new_dict:
                        new_dict[mm]=v
                        mm = mm +1
                else:
                    if result:
                        print(f"resultat : {result}")
                        start_time_str = v["start"]
                        end_time_str = v["end"]
                        # start_time = m.conv_str_to_time(start_time_str)
                        # end_time = m.conv_str_to_time(end_time_str)
                        nb_of_carach = len(v["text"])
                        duration = m.time_to_seconds(end_time_str) - m.time_to_seconds(start_time_str)
                        duration_sec = duration
                        print(duration)
                        sec_par_letter = duration_sec / nb_of_carach
                        for match in result:
                            len_match = len(match)
                            duration_match = len_match*sec_par_letter
                            if mm not in new_dict:
                                #print(end_time)
                                end_time = m.ajouter_secondes(start_time_str,duration_match)
                                print(end_time)
                                print(f"start time ({type(start_time_str)}) : {start_time_str}, end time ({type(end_time)}) : {end_time}, text : {match}")
                                new_dict[mm]={'start':start_time_str,"end":end_time,'text':match}
                                start_time_str = end_time
                                mm = mm +1
                    else:
                        continue
    m.create_vtt_file(new_dict,f"{output_seg}/{name}")
# Out:
# TRAITEMENT try_seg_end/b7f2d8f0c3.vtt ---- b7f2d8f0c3.vtt
# TRAITEMENT try_seg_end/3d0b82b459.vtt ---- 3d0b82b459.vtt
# TRAITEMENT try_seg_end/44f554f914.vtt ---- 44f554f914.vtt
# TRAITEMENT try_seg_end/b9a51f4361.vtt ---- b9a51f4361.vtt
# TRAITEMENT try_seg_end/4e073949b1.vtt ---- 4e073949b1.vtt
# TRAITEMENT try_seg_end/0b1437bc85.vtt ---- 0b1437bc85.vtt
# TRAITEMENT try_seg_end/752500b761.vtt ---- 752500b761.vtt
# TRAITEMENT try_seg_end/cba6cefad2.vtt ---- cba6cefad2.vtt
# TRAITEMENT try_seg_end/5bf0f577d3.vtt ---- 5bf0f577d3.vtt

# %%
from IPython.display import HTML

# %% [markdown]
# # <font color='red'> ARCHIVED - not useful anymore </font>
# ## Sortir un fichier de phrases
#
# L'idée est de sortie un fichier contenant une phrase par ligne pour pouvoir créer plus simplement le nouveau fichier de sous-titre segmenté en phrases.
#
# ### Traitement
#
# Utilisation de SpaCy pour récupérer les phrases

# %%
file_with_path
# Out:
# ['test_cleaning_mediapi/b7f2d8f0c3.vtt',
#  'test_cleaning_mediapi/3d0b82b459.vtt',
#  'test_cleaning_mediapi/44f554f914.vtt',
#  'test_cleaning_mediapi/b9a51f4361.vtt',
#  'test_cleaning_mediapi/4e073949b1.vtt',
#  'test_cleaning_mediapi/0b1437bc85.vtt',
#  'test_cleaning_mediapi/752500b761.vtt',
#  'test_cleaning_mediapi/cba6cefad2.vtt',
#  'test_cleaning_mediapi/41c606553f.vtt',
#  'test_cleaning_mediapi/3f1b2118ca.vtt',
#  'test_cleaning_mediapi/ed969c3e70.vtt',
#  'test_cleaning_mediapi/26f1ff8385.vtt',
#  'test_cleaning_mediapi/2b4b33189c.vtt',
#  'test_cleaning_mediapi/ada7d10a19.vtt',
#  'test_cleaning_mediapi/fd41a24117.vtt',
#  'test_cleaning_mediapi/15abfc95ae.vtt',
#  'test_cleaning_mediapi/495145911e.vtt',
#  'test_cleaning_mediapi/5ef5fa319a.vtt',
#  'test_cleaning_mediapi/0fd91cb814.vtt',
#  'test_cleaning_mediapi/9a58b08185.vtt',
#  'test_cleaning_mediapi/ac6160b61a.vtt',
#  'test_cleaning_mediapi/74bb642e72.vtt',
#  'test_cleaning_mediapi/17217ca54b.vtt',
#  'test_cleaning_mediapi/928499b438.vtt',
#  'test_cleaning_mediapi/8036e9b4bc.vtt',
#  'test_cleaning_mediapi/5dfad26566.vtt',
#  'test_cleaning_mediapi/71e94f545f.vtt',
#  'test_cleaning_mediapi/008420cac0.vtt',
#  'test_cleaning_mediapi/689abe06d3.vtt',
#  'test_cleaning_mediapi/870fcc2c39.vtt',
#  'test_cleaning_mediapi/575f99a4af.vtt',
#  'test_cleaning_mediapi/5813b21ceb.vtt',
#  'test_cleaning_mediapi/6e72821691.vtt',
#  'test_cleaning_mediapi/cee1643fd7.vtt',
#  'test_cleaning_mediapi/88fb28815b.vtt',
#  'test_cleaning_mediapi/a710e36c40.vtt',
#  'test_cleaning_mediapi/31201b65bf.vtt',
#  'test_cleaning_mediapi/72aeba358a.vtt',
#  'test_cleaning_mediapi/1dd7333d1b.vtt',
#  'test_cleaning_mediapi/a6a8d92675.vtt',
#  'test_cleaning_mediapi/bdc14ece6e.vtt',
#  'test_cleaning_mediapi/d9730fe376.vtt',
#  'test_cleaning_mediapi/142a8e3b5d.vtt',
#  'test_cleaning_mediapi/383f2888b6.vtt',
#  'test_cleaning_mediapi/b72ca1fa4f.vtt',
#  'test_cleaning_mediapi/3adc6931bf.vtt',
#  'test_cleaning_mediapi/7a7a8be63d.vtt',
#  'test_cleaning_mediapi/8da1b28015.vtt',
#  'test_cleaning_mediapi/b6c03b60b7.vtt',
#  'test_cleaning_mediapi/e3edfd09b6.vtt',
#  'test_cleaning_mediapi/3013321813.vtt',
#  'test_cleaning_mediapi/88d76860dd.vtt',
#  'test_cleaning_mediapi/f49546dd7d.vtt',
#  'test_cleaning_mediapi/34210d5c72.vtt',
#  'test_cleaning_mediapi/099c404cc1.vtt',
#  'test_cleaning_mediapi/bfcd06419a.vtt',
#  'test_cleaning_mediapi/f978fa2dea.vtt',
#  'test_cleaning_mediapi/4151b008b6.vtt',
#  'test_cleaning_mediapi/bc3726d559.vtt',
#  'test_cleaning_mediapi/6706655430.vtt',
#  'test_cleaning_mediapi/2b38719c3e.vtt',
#  'test_cleaning_mediapi/a0ec06d1d3.vtt',
#  'test_cleaning_mediapi/29a437b7e7.vtt',
#  'test_cleaning_mediapi/c90bbbf71e.vtt',
#  'test_cleaning_mediapi/a6de2b7652.vtt',
#  'test_cleaning_mediapi/38e41f547d.vtt',
#  'test_cleaning_mediapi/13a80ac2d1.vtt',
#  'test_cleaning_mediapi/ad79e17356.vtt',
#  'test_cleaning_mediapi/b28f6ce507.vtt',
#  'test_cleaning_mediapi/6cf26927ca.vtt',
#  'test_cleaning_mediapi/c3258a13e3.vtt',
#  'test_cleaning_mediapi/1992ebbd09.vtt',
#  'test_cleaning_mediapi/d92e970202.vtt',
#  'test_cleaning_mediapi/dcd9053975.vtt',
#  'test_cleaning_mediapi/4e92363ed6.vtt',
#  'test_cleaning_mediapi/80d22962f8.vtt',
#  'test_cleaning_mediapi/0eb1494855.vtt',
#  'test_cleaning_mediapi/a8d35c1600.vtt',
#  'test_cleaning_mediapi/608fc0be13.vtt',
#  'test_cleaning_mediapi/c11e5da161.vtt',
#  'test_cleaning_mediapi/4b51501587.vtt',
#  'test_cleaning_mediapi/0bfab1c3b4.vtt',
#  'test_cleaning_mediapi/12b9062560.vtt',
#  'test_cleaning_mediapi/eb7811a094.vtt',
#  'test_cleaning_mediapi/491aadc1cf.vtt',
#  'test_cleaning_mediapi/eea98dceef.vtt',
#  'test_cleaning_mediapi/11b9db4892.vtt',
#  'test_cleaning_mediapi/9f59e3b226.vtt',
#  'test_cleaning_mediapi/82ee104b19.vtt',
#  'test_cleaning_mediapi/14a49c07ef.vtt',
#  'test_cleaning_mediapi/7631f48964.vtt',
#  'test_cleaning_mediapi/e597c8cd01.vtt',
#  'test_cleaning_mediapi/fad6c87636.vtt',
#  'test_cleaning_mediapi/d3a84a8ccd.vtt',
#  'test_cleaning_mediapi/e1f484b5f8.vtt',
#  'test_cleaning_mediapi/ac9ff299f9.vtt',
#  'test_cleaning_mediapi/1371e28e24.vtt',
#  'test_cleaning_mediapi/dd977a1f2a.vtt',
#  'test_cleaning_mediapi/2a6ad1a50a.vtt',
#  'test_cleaning_mediapi/1ff266482c.vtt',
#  'test_cleaning_mediapi/2a59b007d4.vtt',
#  'test_cleaning_mediapi/7093118618.vtt',
#  'test_cleaning_mediapi/6648393ad0.vtt',
#  'test_cleaning_mediapi/042af81098.vtt',
#  'test_cleaning_mediapi/8c26149486.vtt',
#  'test_cleaning_mediapi/ef4b03eab2.vtt',
#  'test_cleaning_mediapi/826afd29f8.vtt',
#  'test_cleaning_mediapi/040fde163f.vtt',
#  'test_cleaning_mediapi/4cc54e86f5.vtt',
#  'test_cleaning_mediapi/2fee0f7592.vtt',
#  'test_cleaning_mediapi/9e5e128447.vtt',
#  'test_cleaning_mediapi/c407147f2f.vtt',
#  'test_cleaning_mediapi/8d58d72944.vtt',
#  'test_cleaning_mediapi/05211c15bf.vtt',
#  'test_cleaning_mediapi/5351d97f20.vtt',
#  'test_cleaning_mediapi/d1636da393.vtt',
#  'test_cleaning_mediapi/28420f7cbe.vtt',
#  'test_cleaning_mediapi/e21f0e23a7.vtt',
#  'test_cleaning_mediapi/a588a2cf33.vtt',
#  'test_cleaning_mediapi/33c47d59d2.vtt',
#  'test_cleaning_mediapi/8a6b2fb0ce.vtt',
#  'test_cleaning_mediapi/1cb5e71134.vtt',
#  'test_cleaning_mediapi/b07ede0159.vtt',
#  'test_cleaning_mediapi/6c7ce53264.vtt',
#  'test_cleaning_mediapi/d2de84864b.vtt',
#  'test_cleaning_mediapi/9498b85b5b.vtt',
#  'test_cleaning_mediapi/13d32c0f21.vtt',
#  'test_cleaning_mediapi/e95f4949ed.vtt',
#  'test_cleaning_mediapi/de31ed9096.vtt',
#  'test_cleaning_mediapi/ba24810c74.vtt',
#  'test_cleaning_mediapi/458237489a.vtt',
#  'test_cleaning_mediapi/a1c9365f5d.vtt',
#  'test_cleaning_mediapi/5f10aa9293.vtt',
#  'test_cleaning_mediapi/5e678b4eb7.vtt',
#  'test_cleaning_mediapi/17e4f7380a.vtt',
#  'test_cleaning_mediapi/207c2f7171.vtt',
#  'test_cleaning_mediapi/f981fbe6af.vtt',
#  'test_cleaning_mediapi/2af7497055.vtt',
#  'test_cleaning_mediapi/1bf9bf7cec.vtt',
#  'test_cleaning_mediapi/9ae39abf0b.vtt',
#  'test_cleaning_mediapi/5481e47a19.vtt',
#  'test_cleaning_mediapi/a4064555c2.vtt',
#  'test_cleaning_mediapi/14cf31e15f.vtt',
#  'test_cleaning_mediapi/09c5b8a52b.vtt',
#  'test_cleaning_mediapi/1926b5a3cd.vtt',
#  'test_cleaning_mediapi/3010fa2532.vtt',
#  'test_cleaning_mediapi/5edd365f55.vtt',
#  'test_cleaning_mediapi/ad86de5a8c.vtt',
#  'test_cleaning_mediapi/457a01b248.vtt',
#  'test_cleaning_mediapi/110092623c.vtt',
#  'test_cleaning_mediapi/3879c2ece5.vtt',
#  'test_cleaning_mediapi/e408818334.vtt',
#  'test_cleaning_mediapi/163b0c88eb.vtt',
#  'test_cleaning_mediapi/252c04af8c.vtt',
#  'test_cleaning_mediapi/48be2d5494.vtt',
#  'test_cleaning_mediapi/2c7dd7d7a0.vtt',
#  'test_cleaning_mediapi/648f2d616a.vtt',
#  'test_cleaning_mediapi/d1a36bfbad.vtt',
#  'test_cleaning_mediapi/75f0bcdd54.vtt',
#  'test_cleaning_mediapi/bbfaf1ee13.vtt',
#  'test_cleaning_mediapi/f18b71d989.vtt',
#  'test_cleaning_mediapi/2f1e1d3af4.vtt',
#  'test_cleaning_mediapi/7932f9a3de.vtt',
#  'test_cleaning_mediapi/2f82f046d5.vtt',
#  'test_cleaning_mediapi/4d9577ab24.vtt',
#  'test_cleaning_mediapi/7e4dc844f4.vtt',
#  'test_cleaning_mediapi/061183eb54.vtt',
#  'test_cleaning_mediapi/9398a7ed45.vtt',
#  'test_cleaning_mediapi/530970ed94.vtt',
#  'test_cleaning_mediapi/657dca485a.vtt',
#  'test_cleaning_mediapi/2c0e5e2432.vtt',
#  'test_cleaning_mediapi/1283dc2bc6.vtt',
#  'test_cleaning_mediapi/55b79b1f96.vtt',
#  'test_cleaning_mediapi/36129e8e7e.vtt',
#  'test_cleaning_mediapi/66b8ddb330.vtt',
#  'test_cleaning_mediapi/8fc0505a8e.vtt',
#  'test_cleaning_mediapi/91c3a16492.vtt',
#  'test_cleaning_mediapi/87f4b77d47.vtt',
#  'test_cleaning_mediapi/a8318f25e7.vtt',
#  'test_cleaning_mediapi/b4ce85fbf7.vtt',
#  'test_cleaning_mediapi/647638a97c.vtt',
#  'test_cleaning_mediapi/3c9c76395a.vtt',
#  'test_cleaning_mediapi/493574a037.vtt',
#  'test_cleaning_mediapi/db1ee8312d.vtt',
#  'test_cleaning_mediapi/3d1087ebe4.vtt',
#  'test_cleaning_mediapi/3f62714c82.vtt',
#  'test_cleaning_mediapi/1b4b91655b.vtt',
#  'test_cleaning_mediapi/78d0acb6e7.vtt',
#  'test_cleaning_mediapi/245a286c8e.vtt',
#  'test_cleaning_mediapi/13adb98a30.vtt',
#  'test_cleaning_mediapi/9088be11a1.vtt',
#  'test_cleaning_mediapi/cb28f32304.vtt',
#  'test_cleaning_mediapi/d8687ad02b.vtt',
#  'test_cleaning_mediapi/b58d9b077e.vtt',
#  'test_cleaning_mediapi/1cb22a2279.vtt',
#  'test_cleaning_mediapi/2fc7967195.vtt',
#  'test_cleaning_mediapi/14595aa066.vtt',
#  'test_cleaning_mediapi/879dece3e4.vtt',
#  'test_cleaning_mediapi/0408ad5430.vtt',
#  'test_cleaning_mediapi/7c92a479c2.vtt',
#  'test_cleaning_mediapi/49c7c0f2b7.vtt',
#  'test_cleaning_mediapi/91900415b1.vtt',
#  'test_cleaning_mediapi/611cd8bac1.vtt',
#  'test_cleaning_mediapi/1f963b12c6.vtt',
#  'test_cleaning_mediapi/b5af2cb79d.vtt',
#  'test_cleaning_mediapi/938d9996d9.vtt',
#  'test_cleaning_mediapi/4ae8b991ee.vtt',
#  'test_cleaning_mediapi/b03e954ae1.vtt',
#  'test_cleaning_mediapi/2a3064d64a.vtt',
#  'test_cleaning_mediapi/0b2e490c12.vtt',
#  'test_cleaning_mediapi/d1f4036e1d.vtt',
#  'test_cleaning_mediapi/d36b54adb5.vtt',
#  'test_cleaning_mediapi/c810f8ff26.vtt',
#  'test_cleaning_mediapi/7b59ef6cd5.vtt',
#  'test_cleaning_mediapi/3d0f798301.vtt',
#  'test_cleaning_mediapi/f73744b1d5.vtt',
#  'test_cleaning_mediapi/b2803a42cb.vtt',
#  'test_cleaning_mediapi/3614c300a2.vtt',
#  'test_cleaning_mediapi/83ea4b70b9.vtt',
#  'test_cleaning_mediapi/29afc9b364.vtt',
#  'test_cleaning_mediapi/82c3c558d8.vtt',
#  'test_cleaning_mediapi/a835c5a096.vtt',
#  'test_cleaning_mediapi/596653a27e.vtt',
#  'test_cleaning_mediapi/baf83ae145.vtt',
#  'test_cleaning_mediapi/2c5fca9371.vtt',
#  'test_cleaning_mediapi/6462ce3913.vtt',
#  'test_cleaning_mediapi/581d5c3587.vtt',
#  'test_cleaning_mediapi/50d53eca84.vtt',
#  'test_cleaning_mediapi/b28b182a5e.vtt',
#  'test_cleaning_mediapi/4836a95980.vtt',
#  'test_cleaning_mediapi/02eb959bf5.vtt',
#  'test_cleaning_mediapi/3f8f90ad63.vtt',
#  'test_cleaning_mediapi/a7b7ca660a.vtt',
#  'test_cleaning_mediapi/b79a744ad3.vtt',
#  'test_cleaning_mediapi/56fa0513af.vtt',
#  'test_cleaning_mediapi/ecc384c1fb.vtt',
#  'test_cleaning_mediapi/079f72dc4a.vtt',
#  'test_cleaning_mediapi/94b2ecc091.vtt',
#  'test_cleaning_mediapi/22d5ed99a6.vtt',
#  'test_cleaning_mediapi/4b0331f8b5.vtt',
#  'test_cleaning_mediapi/262f486e74.vtt',
#  'test_cleaning_mediapi/adc23c06f4.vtt',
#  'test_cleaning_mediapi/2d57e809c8.vtt',
#  'test_cleaning_mediapi/f669555f31.vtt',
#  'test_cleaning_mediapi/9b020e4642.vtt',
#  'test_cleaning_mediapi/df91b67bdd.vtt',
#  'test_cleaning_mediapi/98c9059ef5.vtt',
#  'test_cleaning_mediapi/e7eaf5f54b.vtt',
#  'test_cleaning_mediapi/c2f70ec746.vtt',
#  'test_cleaning_mediapi/5fcd740228.vtt',
#  'test_cleaning_mediapi/b0e33af935.vtt',
#  'test_cleaning_mediapi/4e0f12fb20.vtt',
#  'test_cleaning_mediapi/f2050e12cc.vtt',
#  'test_cleaning_mediapi/9cdb546cc1.vtt',
#  'test_cleaning_mediapi/df93a88957.vtt',
#  'test_cleaning_mediapi/98ebcdf002.vtt',
#  'test_cleaning_mediapi/d3a2006274.vtt',
#  'test_cleaning_mediapi/d6c3da0752.vtt',
#  'test_cleaning_mediapi/aef8da9eff.vtt',
#  'test_cleaning_mediapi/12e13163de.vtt',
#  'test_cleaning_mediapi/c024039cd1.vtt',
#  'test_cleaning_mediapi/110161a856.vtt',
#  'test_cleaning_mediapi/ffc3c7d040.vtt',
#  'test_cleaning_mediapi/80a81fa418.vtt',
#  'test_cleaning_mediapi/465a324941.vtt',
#  'test_cleaning_mediapi/f1c48db332.vtt',
#  'test_cleaning_mediapi/c50df9cd1b.vtt',
#  'test_cleaning_mediapi/6776ba2cde.vtt',
#  'test_cleaning_mediapi/bee7f98af4.vtt',
#  'test_cleaning_mediapi/50fcb24556.vtt',
#  'test_cleaning_mediapi/38202ef76f.vtt',
#  'test_cleaning_mediapi/851117a952.vtt',
#  'test_cleaning_mediapi/237a756522.vtt',
#  'test_cleaning_mediapi/18844bd024.vtt',
#  'test_cleaning_mediapi/359672c30c.vtt',
#  'test_cleaning_mediapi/c40c5cce62.vtt',
#  'test_cleaning_mediapi/75fff80619.vtt',
#  'test_cleaning_mediapi/2ec071dc19.vtt',
#  'test_cleaning_mediapi/970f89d01d.vtt',
#  'test_cleaning_mediapi/f10b42a97a.vtt',
#  'test_cleaning_mediapi/660a4436f6.vtt',
#  'test_cleaning_mediapi/8ec5a10644.vtt',
#  'test_cleaning_mediapi/e12bcc6268.vtt',
#  'test_cleaning_mediapi/f9924c0357.vtt',
#  'test_cleaning_mediapi/703e807fa9.vtt',
#  'test_cleaning_mediapi/64a5d50769.vtt',
#  'test_cleaning_mediapi/d0d25df866.vtt',
#  'test_cleaning_mediapi/5f6f04ed2f.vtt',
#  'test_cleaning_mediapi/f08bf6fffb.vtt',
#  'test_cleaning_mediapi/630fab7050.vtt',
#  'test_cleaning_mediapi/7aff2e5997.vtt',
#  'test_cleaning_mediapi/c88f77f27b.vtt',
#  'test_cleaning_mediapi/0422a33fd6.vtt',
#  'test_cleaning_mediapi/024e1e4beb.vtt',
#  'test_cleaning_mediapi/b505799506.vtt',
#  'test_cleaning_mediapi/479ce05131.vtt',
#  'test_cleaning_mediapi/09e56af09e.vtt',
#  'test_cleaning_mediapi/f1a40cd6a4.vtt',
#  'test_cleaning_mediapi/3ffc340a29.vtt',
#  'test_cleaning_mediapi/ba0e817586.vtt',
#  'test_cleaning_mediapi/16833af47a.vtt',
#  'test_cleaning_mediapi/8416c37a49.vtt',
#  'test_cleaning_mediapi/8ad919dc08.vtt',
#  'test_cleaning_mediapi/ffcc270e75.vtt',
#  'test_cleaning_mediapi/d0b3cbccd3.vtt',
#  'test_cleaning_mediapi/9479ab515c.vtt',
#  'test_cleaning_mediapi/be44b82e10.vtt',
#  'test_cleaning_mediapi/14b6db6d50.vtt',
#  'test_cleaning_mediapi/5ccd47775a.vtt',
#  'test_cleaning_mediapi/4abc7be8e2.vtt',
#  'test_cleaning_mediapi/6ea6b559da.vtt',
#  'test_cleaning_mediapi/a74d5929b7.vtt',
#  'test_cleaning_mediapi/d8ceb8bb80.vtt',
#  'test_cleaning_mediapi/5d686de51e.vtt',
#  'test_cleaning_mediapi/271112375a.vtt',
#  'test_cleaning_mediapi/90d4dcda22.vtt',
#  'test_cleaning_mediapi/36cb6ff5ca.vtt',
#  'test_cleaning_mediapi/66bbb5f541.vtt',
#  'test_cleaning_mediapi/e01254488b.vtt',
#  'test_cleaning_mediapi/b40675cb79.vtt',
#  'test_cleaning_mediapi/949d9b46f8.vtt',
#  'test_cleaning_mediapi/3442d011f6.vtt',
#  'test_cleaning_mediapi/14546e7c31.vtt',
#  'test_cleaning_mediapi/1c0ecded91.vtt',
#  'test_cleaning_mediapi/9aaa0e038c.vtt',
#  'test_cleaning_mediapi/11037b4757.vtt',
#  'test_cleaning_mediapi/edd6eab05a.vtt',
#  'test_cleaning_mediapi/e0f686963a.vtt',
#  'test_cleaning_mediapi/9f4d5f898a.vtt',
#  'test_cleaning_mediapi/615a53241e.vtt',
#  'test_cleaning_mediapi/38784516fe.vtt',
#  'test_cleaning_mediapi/88e7af4054.vtt',
#  'test_cleaning_mediapi/e19facc031.vtt',
#  'test_cleaning_mediapi/386bc62c25.vtt',
#  'test_cleaning_mediapi/297c2bd10f.vtt',
#  'test_cleaning_mediapi/9340df476f.vtt',
#  'test_cleaning_mediapi/41be318122.vtt',
#  'test_cleaning_mediapi/88c3d03c46.vtt',
#  'test_cleaning_mediapi/ca37cca7de.vtt',
#  'test_cleaning_mediapi/a4e45aa2a4.vtt',
#  'test_cleaning_mediapi/8a6d7f5002.vtt',
#  'test_cleaning_mediapi/10f8859418.vtt',
#  'test_cleaning_mediapi/707744965b.vtt',
#  'test_cleaning_mediapi/b9e908d0b5.vtt',
#  'test_cleaning_mediapi/2cbe7d2a9f.vtt',
#  'test_cleaning_mediapi/272d389416.vtt',
#  'test_cleaning_mediapi/7994acc604.vtt',
#  'test_cleaning_mediapi/22b403a6ba.vtt',
#  'test_cleaning_mediapi/b999628114.vtt',
#  'test_cleaning_mediapi/32d8e4cb1a.vtt',
#  'test_cleaning_mediapi/4a5b8b88d3.vtt',
#  'test_cleaning_mediapi/976db5c061.vtt',
#  'test_cleaning_mediapi/b919eb82f9.vtt',
#  'test_cleaning_mediapi/eb8d1a582f.vtt',
#  'test_cleaning_mediapi/acf0268cfb.vtt',
#  'test_cleaning_mediapi/1c70031f32.vtt',
#  'test_cleaning_mediapi/b7ef5a5728.vtt',
#  'test_cleaning_mediapi/9e4aec6d41.vtt',
#  'test_cleaning_mediapi/765d9c5adb.vtt',
#  'test_cleaning_mediapi/e7708e38ae.vtt',
#  'test_cleaning_mediapi/005c1d83b5.vtt',
#  'test_cleaning_mediapi/03a663d287.vtt',
#  'test_cleaning_mediapi/bc3e50e582.vtt',
#  'test_cleaning_mediapi/1fbaf3f4f6.vtt',
#  'test_cleaning_mediapi/a6e280e756.vtt',
#  'test_cleaning_mediapi/99fc016b5c.vtt',
#  'test_cleaning_mediapi/95d846a441.vtt',
#  'test_cleaning_mediapi/effdd1d4e1.vtt',
#  'test_cleaning_mediapi/947de0ab18.vtt',
#  'test_cleaning_mediapi/ad9f94ce37.vtt',
#  'test_cleaning_mediapi/b04456b1fd.vtt',
#  'test_cleaning_mediapi/84085b1bd6.vtt',
#  'test_cleaning_mediapi/c594d9509f.vtt',
#  'test_cleaning_mediapi/b21d98af65.vtt',
#  'test_cleaning_mediapi/c0610253ed.vtt',
#  'test_cleaning_mediapi/f2fe524efc.vtt',
#  'test_cleaning_mediapi/1dcc266cc2.vtt',
#  'test_cleaning_mediapi/8eb47e34e0.vtt',
#  'test_cleaning_mediapi/a98b8cf2c3.vtt',
#  'test_cleaning_mediapi/cba694874b.vtt',
#  'test_cleaning_mediapi/25aeb2b40b.vtt',
#  'test_cleaning_mediapi/e670e798a7.vtt',
#  'test_cleaning_mediapi/a554388c1f.vtt',
#  'test_cleaning_mediapi/3bc00c3615.vtt',
#  'test_cleaning_mediapi/76677dc1f6.vtt',
#  'test_cleaning_mediapi/0e2a1bdaf5.vtt',
#  'test_cleaning_mediapi/65947fe1c1.vtt',
#  'test_cleaning_mediapi/35c67ac1f7.vtt',
#  'test_cleaning_mediapi/4e80578498.vtt',
#  'test_cleaning_mediapi/a5b3b88bdc.vtt',
#  'test_cleaning_mediapi/1e70ec9d20.vtt',
#  'test_cleaning_mediapi/3e28e0e644.vtt',
#  'test_cleaning_mediapi/230f85da51.vtt',
#  'test_cleaning_mediapi/6117dcd7a2.vtt',
#  'test_cleaning_mediapi/96adc457d0.vtt',
#  'test_cleaning_mediapi/8c2b65d935.vtt',
#  'test_cleaning_mediapi/2b6e3a9da2.vtt',
#  'test_cleaning_mediapi/39ead9e95a.vtt',
#  'test_cleaning_mediapi/44747be184.vtt',
#  'test_cleaning_mediapi/8edc772a9a.vtt',
#  'test_cleaning_mediapi/a41024bd3b.vtt',
#  'test_cleaning_mediapi/24a2f80399.vtt',
#  'test_cleaning_mediapi/a403b7bb54.vtt',
#  'test_cleaning_mediapi/e59917d79e.vtt',
#  'test_cleaning_mediapi/e43f408c99.vtt',
#  'test_cleaning_mediapi/d0c357c68d.vtt',
#  'test_cleaning_mediapi/57ae2510fe.vtt',
#  'test_cleaning_mediapi/335d2d2b5c.vtt',
#  'test_cleaning_mediapi/5c29af74aa.vtt',
#  'test_cleaning_mediapi/8a20ab9bf6.vtt',
#  'test_cleaning_mediapi/6301f34c78.vtt',
#  'test_cleaning_mediapi/5f562efece.vtt',
#  'test_cleaning_mediapi/dc1c1a52bc.vtt',
#  'test_cleaning_mediapi/24de616d2b.vtt',
#  'test_cleaning_mediapi/142b256d4d.vtt',
#  'test_cleaning_mediapi/69d2ad88ba.vtt',
#  'test_cleaning_mediapi/8359481cc4.vtt',
#  'test_cleaning_mediapi/d2e39b6d9c.vtt',
#  'test_cleaning_mediapi/77fee386a7.vtt',
#  'test_cleaning_mediapi/e464d9dcc5.vtt',
#  'test_cleaning_mediapi/07befc1812.vtt',
#  'test_cleaning_mediapi/3c3c93c444.vtt',
#  'test_cleaning_mediapi/2e078832df.vtt',
#  'test_cleaning_mediapi/090d0be02e.vtt',
#  'test_cleaning_mediapi/01dd99ecbe.vtt',
#  'test_cleaning_mediapi/a83ab651cf.vtt',
#  'test_cleaning_mediapi/11af6bdd76.vtt',
#  'test_cleaning_mediapi/8e0c9606b6.vtt',
#  'test_cleaning_mediapi/21a181e1ae.vtt',
#  'test_cleaning_mediapi/0dcd5e10b0.vtt',
#  'test_cleaning_mediapi/adf8fb3f23.vtt',
#  'test_cleaning_mediapi/8d8fb3b4cd.vtt',
#  'test_cleaning_mediapi/8642070414.vtt',
#  'test_cleaning_mediapi/5a5a694c34.vtt',
#  'test_cleaning_mediapi/95c12148e2.vtt',
#  'test_cleaning_mediapi/da8eb72bc1.vtt',
#  'test_cleaning_mediapi/a2e5d49b61.vtt',
#  'test_cleaning_mediapi/d60ff1ef18.vtt',
#  'test_cleaning_mediapi/e1e045ad7d.vtt',
#  'test_cleaning_mediapi/efc93baeb2.vtt',
#  'test_cleaning_mediapi/43f582c164.vtt',
#  'test_cleaning_mediapi/81ca26f220.vtt',
#  'test_cleaning_mediapi/4daaf2c66f.vtt',
#  'test_cleaning_mediapi/e19a9925b1.vtt',
#  'test_cleaning_mediapi/2c3e419f2b.vtt',
#  'test_cleaning_mediapi/45d6cf7828.vtt',
#  'test_cleaning_mediapi/dd5b0e331a.vtt',
#  'test_cleaning_mediapi/77f261808f.vtt',
#  'test_cleaning_mediapi/866c289c93.vtt',
#  'test_cleaning_mediapi/a224f59ad6.vtt',
#  'test_cleaning_mediapi/c8c66bdd6f.vtt',
#  'test_cleaning_mediapi/19a1bba43b.vtt',
#  'test_cleaning_mediapi/d8bbccd121.vtt',
#  'test_cleaning_mediapi/5004a94819.vtt',
#  'test_cleaning_mediapi/82c624dbaf.vtt',
#  'test_cleaning_mediapi/c22c376d52.vtt',
#  'test_cleaning_mediapi/ade0ef2c55.vtt',
#  'test_cleaning_mediapi/e30a464eee.vtt',
#  'test_cleaning_mediapi/7f3beb2d58.vtt',
#  'test_cleaning_mediapi/3359f1be56.vtt',
#  'test_cleaning_mediapi/c1f430c2f0.vtt',
#  'test_cleaning_mediapi/d44180b637.vtt',
#  'test_cleaning_mediapi/ee9b3a1e3e.vtt',
#  'test_cleaning_mediapi/0f1051cb25.vtt',
#  'test_cleaning_mediapi/48f549652e.vtt',
#  'test_cleaning_mediapi/7505042632.vtt',
#  'test_cleaning_mediapi/6e6af002ad.vtt',
#  'test_cleaning_mediapi/89489be991.vtt',
#  'test_cleaning_mediapi/1d745d545b.vtt',
#  'test_cleaning_mediapi/2228305d06.vtt',
#  'test_cleaning_mediapi/74ae0ed0a5.vtt',
#  'test_cleaning_mediapi/eba92cae3d.vtt',
#  'test_cleaning_mediapi/563676970c.vtt',
#  'test_cleaning_mediapi/6f90984e91.vtt',
#  'test_cleaning_mediapi/cc35f77853.vtt',
#  'test_cleaning_mediapi/7864c44ef3.vtt',
#  'test_cleaning_mediapi/53368e68f9.vtt',
#  'test_cleaning_mediapi/cde20f4012.vtt',
#  'test_cleaning_mediapi/c13dd9f62c.vtt',
#  'test_cleaning_mediapi/9176874f0e.vtt',
#  'test_cleaning_mediapi/5a1ce9d645.vtt',
#  'test_cleaning_mediapi/55d31feed0.vtt',
#  'test_cleaning_mediapi/b1483e5350.vtt',
#  'test_cleaning_mediapi/8669cf38d8.vtt',
#  'test_cleaning_mediapi/31a057a3a5.vtt',
#  'test_cleaning_mediapi/1c88ec3e06.vtt',
#  'test_cleaning_mediapi/dfbdc630e8.vtt',
#  'test_cleaning_mediapi/8c2e52e760.vtt',
#  'test_cleaning_mediapi/36fdaab1d9.vtt',
#  'test_cleaning_mediapi/c67b4711f0.vtt',
#  'test_cleaning_mediapi/81ac1c0dbf.vtt',
#  'test_cleaning_mediapi/4acb37ab13.vtt',
#  'test_cleaning_mediapi/d1f07ae7be.vtt',
#  'test_cleaning_mediapi/dc185a226a.vtt',
#  'test_cleaning_mediapi/9bb0f3568a.vtt',
#  'test_cleaning_mediapi/09d9fd8274.vtt',
#  'test_cleaning_mediapi/68d6ea066e.vtt',
#  'test_cleaning_mediapi/0d7eab9559.vtt',
#  'test_cleaning_mediapi/4e4f33a56c.vtt',
#  'test_cleaning_mediapi/2c3e431912.vtt',
#  'test_cleaning_mediapi/4b55cb4b47.vtt',
#  'test_cleaning_mediapi/b0c699509f.vtt',
#  'test_cleaning_mediapi/158512e90e.vtt',
#  'test_cleaning_mediapi/bf961c01d4.vtt',
#  'test_cleaning_mediapi/dd42853f7f.vtt',
#  'test_cleaning_mediapi/dbedbbb968.vtt',
#  'test_cleaning_mediapi/bf2a32e353.vtt',
#  'test_cleaning_mediapi/6f2c5e8b83.vtt',
#  'test_cleaning_mediapi/b66ce7f665.vtt',
#  'test_cleaning_mediapi/6393749f81.vtt',
#  'test_cleaning_mediapi/9ed39ce7f5.vtt',
#  'test_cleaning_mediapi/6792e8ffe5.vtt',
#  'test_cleaning_mediapi/b7324e955e.vtt',
#  'test_cleaning_mediapi/ed1ed9215f.vtt',
#  'test_cleaning_mediapi/87e499e7d6.vtt',
#  'test_cleaning_mediapi/4b75fc29cc.vtt',
#  'test_cleaning_mediapi/d034fc5d24.vtt',
#  'test_cleaning_mediapi/879211e014.vtt',
#  'test_cleaning_mediapi/4fbfd0f4d8.vtt',
#  'test_cleaning_mediapi/a05bf5591e.vtt',
#  'test_cleaning_mediapi/c0df314bc4.vtt',
#  'test_cleaning_mediapi/007e93fe10.vtt',
#  'test_cleaning_mediapi/f809b59df3.vtt',
#  'test_cleaning_mediapi/e368178763.vtt',
#  'test_cleaning_mediapi/1ddacc21a0.vtt',
#  'test_cleaning_mediapi/c4d00ff49a.vtt',
#  'test_cleaning_mediapi/7fc84d9a5a.vtt',
#  'test_cleaning_mediapi/db44861992.vtt',
#  'test_cleaning_mediapi/8d2df25953.vtt',
#  'test_cleaning_mediapi/77ecdba15d.vtt',
#  'test_cleaning_mediapi/c9953b740c.vtt',
#  'test_cleaning_mediapi/c3f983e868.vtt',
#  'test_cleaning_mediapi/097a4fef22.vtt',
#  'test_cleaning_mediapi/66ebb89c4c.vtt',
#  'test_cleaning_mediapi/e95a567a09.vtt',
#  'test_cleaning_mediapi/989a1835fe.vtt',
#  'test_cleaning_mediapi/c34ffa64e0.vtt',
#  'test_cleaning_mediapi/1889b75efa.vtt',
#  'test_cleaning_mediapi/6712d91613.vtt',
#  'test_cleaning_mediapi/594611e383.vtt',
#  'test_cleaning_mediapi/3353a269d2.vtt',
#  'test_cleaning_mediapi/d52cf3dcd1.vtt',
#  'test_cleaning_mediapi/8798b0daac.vtt',
#  'test_cleaning_mediapi/a96eb76066.vtt',
#  'test_cleaning_mediapi/d3a8db7edc.vtt',
#  'test_cleaning_mediapi/e33dc93738.vtt',
#  'test_cleaning_mediapi/61c5ab3727.vtt',
#  'test_cleaning_mediapi/8887fb224c.vtt',
#  'test_cleaning_mediapi/c227ed8574.vtt',
#  'test_cleaning_mediapi/2fda2f3c58.vtt',
#  'test_cleaning_mediapi/2e8beb516a.vtt',
#  'test_cleaning_mediapi/2d7c91971e.vtt',
#  'test_cleaning_mediapi/707ec17828.vtt',
#  'test_cleaning_mediapi/400d74e17c.vtt',
#  'test_cleaning_mediapi/d4257e9a67.vtt',
#  'test_cleaning_mediapi/80e3770f7a.vtt',
#  'test_cleaning_mediapi/e2579db45f.vtt',
#  'test_cleaning_mediapi/2105272292.vtt',
#  'test_cleaning_mediapi/06bd1b1086.vtt',
#  'test_cleaning_mediapi/90e3f2e10d.vtt',
#  'test_cleaning_mediapi/61c4591cc4.vtt',
#  'test_cleaning_mediapi/1075c6bd0d.vtt',
#  'test_cleaning_mediapi/e86049976c.vtt',
#  'test_cleaning_mediapi/ca66f9d3a4.vtt',
#  'test_cleaning_mediapi/4ad7c1e022.vtt',
#  'test_cleaning_mediapi/6a81037850.vtt',
#  'test_cleaning_mediapi/a5e77d9fa0.vtt',
#  'test_cleaning_mediapi/ff4fce1cea.vtt',
#  'test_cleaning_mediapi/123a1b5841.vtt',
#  'test_cleaning_mediapi/cb84e53bae.vtt',
#  'test_cleaning_mediapi/2e3e2c8edd.vtt',
#  'test_cleaning_mediapi/bcf9c6c740.vtt',
#  'test_cleaning_mediapi/7e8367dedc.vtt',
#  'test_cleaning_mediapi/b755b0b8e2.vtt',
#  'test_cleaning_mediapi/b0c397bea1.vtt',
#  'test_cleaning_mediapi/a98727918a.vtt',
#  'test_cleaning_mediapi/42c0f86874.vtt',
#  'test_cleaning_mediapi/540d68480b.vtt',
#  'test_cleaning_mediapi/12e80c1738.vtt',
#  'test_cleaning_mediapi/29ccad584f.vtt',
#  'test_cleaning_mediapi/fdbd52af78.vtt',
#  'test_cleaning_mediapi/80f0119bfc.vtt',
#  'test_cleaning_mediapi/2e7bce1ed4.vtt',
#  'test_cleaning_mediapi/1f8375ce7c.vtt',
#  'test_cleaning_mediapi/8b83f9214e.vtt',
#  'test_cleaning_mediapi/8766a6d6de.vtt',
#  'test_cleaning_mediapi/cc00634e86.vtt',
#  'test_cleaning_mediapi/d95ab8bdab.vtt',
#  'test_cleaning_mediapi/d8a9599586.vtt',
#  'test_cleaning_mediapi/bfb2a15e14.vtt',
#  'test_cleaning_mediapi/49caa465d3.vtt',
#  'test_cleaning_mediapi/4699dc221b.vtt',
#  'test_cleaning_mediapi/72ceebd88e.vtt',
#  'test_cleaning_mediapi/20cf216ad7.vtt',
#  'test_cleaning_mediapi/b4c9e8385b.vtt',
#  'test_cleaning_mediapi/eb77b5308c.vtt',
#  'test_cleaning_mediapi/2618677de2.vtt',
#  'test_cleaning_mediapi/0ad3102bff.vtt',
#  'test_cleaning_mediapi/7960117bbf.vtt',
#  'test_cleaning_mediapi/29b4b507f2.vtt',
#  'test_cleaning_mediapi/313f76e7c3.vtt',
#  'test_cleaning_mediapi/dccdecda4e.vtt',
#  'test_cleaning_mediapi/aaf27b88b4.vtt',
#  'test_cleaning_mediapi/ce5d5018fd.vtt',
#  'test_cleaning_mediapi/7b3f88ddd2.vtt',
#  'test_cleaning_mediapi/4e31163122.vtt',
#  'test_cleaning_mediapi/734390434c.vtt',
#  'test_cleaning_mediapi/bd9e379d2a.vtt',
#  'test_cleaning_mediapi/ad6110f483.vtt',
#  'test_cleaning_mediapi/4768569d45.vtt',
#  'test_cleaning_mediapi/7e44de75cd.vtt',
#  'test_cleaning_mediapi/394f28da6d.vtt',
#  'test_cleaning_mediapi/3021b49a67.vtt',
#  'test_cleaning_mediapi/b342c8a1aa.vtt',
#  'test_cleaning_mediapi/bfff04a4a5.vtt',
#  'test_cleaning_mediapi/d825b2c63b.vtt',
#  'test_cleaning_mediapi/2bb2f10521.vtt',
#  'test_cleaning_mediapi/f34e489689.vtt',
#  'test_cleaning_mediapi/db0657fe2d.vtt',
#  'test_cleaning_mediapi/382e80de8e.vtt',
#  'test_cleaning_mediapi/c7abaa3eec.vtt',
#  'test_cleaning_mediapi/2f3e563b8a.vtt',
#  'test_cleaning_mediapi/c701ca2185.vtt',
#  'test_cleaning_mediapi/4908681725.vtt',
#  'test_cleaning_mediapi/5646a154f8.vtt',
#  'test_cleaning_mediapi/05b2391c69.vtt',
#  'test_cleaning_mediapi/229d83b08d.vtt',
#  'test_cleaning_mediapi/4eb6737c5e.vtt',
#  'test_cleaning_mediapi/fe7620b018.vtt',
#  'test_cleaning_mediapi/af53f5f1b5.vtt',
#  'test_cleaning_mediapi/2a82fefa67.vtt',
#  'test_cleaning_mediapi/0bc405ea52.vtt',
#  'test_cleaning_mediapi/e4479999e0.vtt',
#  'test_cleaning_mediapi/73a7632c39.vtt',
#  'test_cleaning_mediapi/7e92fc992c.vtt',
#  'test_cleaning_mediapi/5691b6660e.vtt',
#  'test_cleaning_mediapi/2ed4d01376.vtt',
#  'test_cleaning_mediapi/36b0bdaedd.vtt',
#  'test_cleaning_mediapi/d56bb29d5a.vtt',
#  'test_cleaning_mediapi/4b7075153d.vtt',
#  'test_cleaning_mediapi/74493084b4.vtt',
#  'test_cleaning_mediapi/c3bbbe3ed6.vtt',
#  'test_cleaning_mediapi/d497ab281a.vtt',
#  'test_cleaning_mediapi/4ac466ae53.vtt',
#  'test_cleaning_mediapi/626d031ee1.vtt',
#  'test_cleaning_mediapi/6a298953f1.vtt',
#  'test_cleaning_mediapi/b79d4431f4.vtt',
#  'test_cleaning_mediapi/064c29757d.vtt',
#  'test_cleaning_mediapi/aecfacc5d8.vtt',
#  'test_cleaning_mediapi/c3cd5979fc.vtt',
#  'test_cleaning_mediapi/e4706995b4.vtt',
#  'test_cleaning_mediapi/37565c45b8.vtt',
#  'test_cleaning_mediapi/7b7a12d16a.vtt',
#  'test_cleaning_mediapi/83a3280632.vtt',
#  'test_cleaning_mediapi/e230e106ef.vtt',
#  'test_cleaning_mediapi/62be27fbdf.vtt',
#  'test_cleaning_mediapi/37649fe849.vtt',
#  'test_cleaning_mediapi/55640c76bc.vtt',
#  'test_cleaning_mediapi/97008f55fe.vtt',
#  'test_cleaning_mediapi/9cf248b494.vtt',
#  'test_cleaning_mediapi/54f0b235d2.vtt',
#  'test_cleaning_mediapi/39296e7eeb.vtt',
#  'test_cleaning_mediapi/7aad4499ce.vtt',
#  'test_cleaning_mediapi/0765d24a4b.vtt',
#  'test_cleaning_mediapi/18c81f1726.vtt',
#  'test_cleaning_mediapi/9fc61f22f8.vtt',
#  'test_cleaning_mediapi/66abe05bf2.vtt',
#  'test_cleaning_mediapi/6690aa372a.vtt',
#  'test_cleaning_mediapi/76527ca4a1.vtt',
#  'test_cleaning_mediapi/ed5fc55af8.vtt',
#  'test_cleaning_mediapi/162f0a069d.vtt',
#  'test_cleaning_mediapi/e8f32b5aec.vtt',
#  'test_cleaning_mediapi/305ece2b43.vtt',
#  'test_cleaning_mediapi/7a470b0584.vtt',
#  'test_cleaning_mediapi/7965914d3c.vtt',
#  'test_cleaning_mediapi/0e4b9b61cd.vtt',
#  'test_cleaning_mediapi/cf0560302a.vtt',
#  'test_cleaning_mediapi/c541fe2f8f.vtt',
#  'test_cleaning_mediapi/c6fa62301e.vtt',
#  'test_cleaning_mediapi/a866723238.vtt',
#  'test_cleaning_mediapi/0d443f2a98.vtt',
#  'test_cleaning_mediapi/f6e5c0c26a.vtt',
#  'test_cleaning_mediapi/45b9ad5268.vtt',
#  'test_cleaning_mediapi/a696bb71a9.vtt',
#  'test_cleaning_mediapi/7c37473c3c.vtt',
#  'test_cleaning_mediapi/e66392581f.vtt',
#  'test_cleaning_mediapi/ecc5a3942b.vtt',
#  'test_cleaning_mediapi/0115c2b09b.vtt',
#  'test_cleaning_mediapi/a641f42166.vtt',
#  'test_cleaning_mediapi/3b79decbc9.vtt',
#  'test_cleaning_mediapi/a280ff1c53.vtt',
#  'test_cleaning_mediapi/3ffa63d75a.vtt',
#  'test_cleaning_mediapi/c363cbfd61.vtt',
#  'test_cleaning_mediapi/8138a541a5.vtt',
#  'test_cleaning_mediapi/8ea183f1f5.vtt',
#  'test_cleaning_mediapi/feca49cbaa.vtt',
#  'test_cleaning_mediapi/d425fce2da.vtt',
#  'test_cleaning_mediapi/326141f1f4.vtt',
#  'test_cleaning_mediapi/33a54cbee5.vtt',
#  'test_cleaning_mediapi/6af24e6b9c.vtt',
#  'test_cleaning_mediapi/ddeb744c53.vtt',
#  'test_cleaning_mediapi/99ae96b29c.vtt',
#  'test_cleaning_mediapi/e57e8b7c37.vtt',
#  'test_cleaning_mediapi/62276f91e1.vtt',
#  'test_cleaning_mediapi/8d0823d738.vtt',
#  'test_cleaning_mediapi/b429f5a759.vtt',
#  'test_cleaning_mediapi/b6cc4945b6.vtt',
#  'test_cleaning_mediapi/55d08c6fc4.vtt',
#  'test_cleaning_mediapi/3fa25c7095.vtt',
#  'test_cleaning_mediapi/4a252ec277.vtt',
#  'test_cleaning_mediapi/22a16b62bc.vtt',
#  'test_cleaning_mediapi/31dad5f98a.vtt',
#  'test_cleaning_mediapi/615add5cf4.vtt',
#  'test_cleaning_mediapi/e240fee64a.vtt',
#  'test_cleaning_mediapi/7b90788a67.vtt',
#  'test_cleaning_mediapi/620d38721f.vtt',
#  'test_cleaning_mediapi/a070f05a21.vtt',
#  'test_cleaning_mediapi/6c450e66ea.vtt',
#  'test_cleaning_mediapi/0643216cf1.vtt',
#  'test_cleaning_mediapi/79e0b54a84.vtt',
#  'test_cleaning_mediapi/0609375190.vtt',
#  'test_cleaning_mediapi/29944461b4.vtt',
#  'test_cleaning_mediapi/ba055a3460.vtt',
#  'test_cleaning_mediapi/274d19924a.vtt',
#  'test_cleaning_mediapi/a8f20e0935.vtt',
#  'test_cleaning_mediapi/c5c018814c.vtt',
#  'test_cleaning_mediapi/fc5562f5f4.vtt',
#  'test_cleaning_mediapi/0a8eed3371.vtt',
#  'test_cleaning_mediapi/16f8f3e4f3.vtt',
#  'test_cleaning_mediapi/3878bf6a4b.vtt',
#  'test_cleaning_mediapi/dbe8fe3cd8.vtt',
#  'test_cleaning_mediapi/b190a8fcf3.vtt',
#  'test_cleaning_mediapi/91f7602dd7.vtt',
#  'test_cleaning_mediapi/7eb31feb7b.vtt',
#  'test_cleaning_mediapi/0d4eb20351.vtt',
#  'test_cleaning_mediapi/08833bc0f6.vtt',
#  'test_cleaning_mediapi/e704e87b4e.vtt',
#  'test_cleaning_mediapi/27041103dd.vtt',
#  'test_cleaning_mediapi/0470c7f913.vtt',
#  'test_cleaning_mediapi/e5fbe410e6.vtt',
#  'test_cleaning_mediapi/13e4e917e1.vtt',
#  'test_cleaning_mediapi/0b4ce617de.vtt',
#  'test_cleaning_mediapi/a6d38e5bdb.vtt',
#  'test_cleaning_mediapi/e148dfeb65.vtt',
#  'test_cleaning_mediapi/f2f7d8d5f8.vtt',
#  'test_cleaning_mediapi/8df5d27beb.vtt',
#  'test_cleaning_mediapi/6e8700e1ae.vtt',
#  'test_cleaning_mediapi/1b820316ba.vtt',
#  'test_cleaning_mediapi/b5cda239b9.vtt',
#  'test_cleaning_mediapi/53460aff7b.vtt',
#  'test_cleaning_mediapi/66c4c805b1.vtt',
#  'test_cleaning_mediapi/43802ca36d.vtt',
#  'test_cleaning_mediapi/6639a5e1cc.vtt',
#  'test_cleaning_mediapi/f148c7a6e3.vtt',
#  'test_cleaning_mediapi/9f1510e3bf.vtt',
#  'test_cleaning_mediapi/02454a574c.vtt',
#  'test_cleaning_mediapi/4a3cf6910c.vtt',
#  'test_cleaning_mediapi/62b65369f4.vtt',
#  'test_cleaning_mediapi/aae77ee509.vtt',
#  'test_cleaning_mediapi/dd4a18210b.vtt',
#  'test_cleaning_mediapi/94c8044c4d.vtt',
#  'test_cleaning_mediapi/5e773ff027.vtt',
#  'test_cleaning_mediapi/76ac6bd7eb.vtt',
#  'test_cleaning_mediapi/de9aeb3d1c.vtt',
#  'test_cleaning_mediapi/22219f1214.vtt',
#  'test_cleaning_mediapi/a313560383.vtt',
#  'test_cleaning_mediapi/980e043757.vtt',
#  'test_cleaning_mediapi/0ecd091d66.vtt',
#  'test_cleaning_mediapi/b12b5cb8d2.vtt',
#  'test_cleaning_mediapi/c76bd2fa97.vtt',
#  'test_cleaning_mediapi/303c2ebc1c.vtt',
#  'test_cleaning_mediapi/1bf7ca7f7a.vtt',
#  'test_cleaning_mediapi/080cef75a5.vtt',
#  'test_cleaning_mediapi/28450633f3.vtt',
#  'test_cleaning_mediapi/f1c5933e60.vtt',
#  'test_cleaning_mediapi/0ddc51381c.vtt',
#  'test_cleaning_mediapi/444eb064b8.vtt',
#  'test_cleaning_mediapi/ce13093e98.vtt',
#  'test_cleaning_mediapi/36d9b7f468.vtt',
#  'test_cleaning_mediapi/2e4792ecf5.vtt',
#  'test_cleaning_mediapi/2351782cb1.vtt',
#  'test_cleaning_mediapi/971c724c90.vtt',
#  'test_cleaning_mediapi/e554b40322.vtt',
#  'test_cleaning_mediapi/871a2fa2a3.vtt',
#  'test_cleaning_mediapi/b6d8438015.vtt',
#  'test_cleaning_mediapi/516c601ede.vtt',
#  'test_cleaning_mediapi/e1568c64a1.vtt',
#  'test_cleaning_mediapi/a510e54dbf.vtt',
#  'test_cleaning_mediapi/0a6241dd8c.vtt',
#  'test_cleaning_mediapi/5463ff64ee.vtt',
#  'test_cleaning_mediapi/3e015a14dd.vtt',
#  'test_cleaning_mediapi/882604ad5f.vtt',
#  'test_cleaning_mediapi/1e65785dc0.vtt',
#  'test_cleaning_mediapi/4fde20cbae.vtt',
#  'test_cleaning_mediapi/7c0156e7b3.vtt',
#  'test_cleaning_mediapi/bd53cb1f5c.vtt',
#  'test_cleaning_mediapi/87bcbad202.vtt',
#  'test_cleaning_mediapi/e5046eb518.vtt',
#  'test_cleaning_mediapi/c9188f102a.vtt',
#  'test_cleaning_mediapi/86004d509b.vtt',
#  'test_cleaning_mediapi/904eb89776.vtt',
#  'test_cleaning_mediapi/7c8deafb0b.vtt',
#  'test_cleaning_mediapi/3ff6d701ae.vtt',
#  'test_cleaning_mediapi/fc45e23df6.vtt',
#  'test_cleaning_mediapi/22bf8a6ef4.vtt',
#  'test_cleaning_mediapi/50dc97f5f7.vtt',
#  'test_cleaning_mediapi/cb962659c9.vtt',
#  'test_cleaning_mediapi/d4edb99609.vtt',
#  'test_cleaning_mediapi/e2e372253f.vtt',
#  'test_cleaning_mediapi/e716109270.vtt',
#  'test_cleaning_mediapi/97547b6486.vtt',
#  'test_cleaning_mediapi/e27fcfc001.vtt',
#  'test_cleaning_mediapi/67d76c2ebb.vtt',
#  'test_cleaning_mediapi/27792377b0.vtt',
#  'test_cleaning_mediapi/693fba67d5.vtt',
#  'test_cleaning_mediapi/58aac62109.vtt',
#  'test_cleaning_mediapi/9f0c335f6e.vtt',
#  'test_cleaning_mediapi/ebe0f6eae0.vtt',
#  'test_cleaning_mediapi/ad327ce1d4.vtt',
#  'test_cleaning_mediapi/a3f25cb374.vtt',
#  'test_cleaning_mediapi/df379c2a7f.vtt',
#  'test_cleaning_mediapi/a8ce431845.vtt',
#  'test_cleaning_mediapi/f7190538c0.vtt',
#  'test_cleaning_mediapi/0f1dec5f45.vtt',
#  'test_cleaning_mediapi/80f90d59ef.vtt',
#  'test_cleaning_mediapi/9db791e8d6.vtt',
#  'test_cleaning_mediapi/4625530392.vtt',
#  'test_cleaning_mediapi/a1fd06e90a.vtt',
#  'test_cleaning_mediapi/91f5041a73.vtt',
#  'test_cleaning_mediapi/cfaa71738f.vtt',
#  'test_cleaning_mediapi/2e04c8d141.vtt',
#  'test_cleaning_mediapi/9d00a9404f.vtt',
#  'test_cleaning_mediapi/763ff23db6.vtt',
#  'test_cleaning_mediapi/87cbe14986.vtt',
#  'test_cleaning_mediapi/35d0453ab7.vtt',
#  'test_cleaning_mediapi/72728a4a6f.vtt',
#  'test_cleaning_mediapi/053c8df6ce.vtt',
#  'test_cleaning_mediapi/10603cbcf6.vtt',
#  'test_cleaning_mediapi/50f92872ae.vtt',
#  'test_cleaning_mediapi/a950829bf8.vtt',
#  'test_cleaning_mediapi/9473529513.vtt',
#  'test_cleaning_mediapi/49101cd1b2.vtt',
#  'test_cleaning_mediapi/f5972347f4.vtt',
#  'test_cleaning_mediapi/ef92a98157.vtt',
#  'test_cleaning_mediapi/ddc83f4224.vtt',
#  'test_cleaning_mediapi/25e056ece5.vtt',
#  'test_cleaning_mediapi/4184d3d4df.vtt',
#  'test_cleaning_mediapi/bfe1e71c08.vtt',
#  'test_cleaning_mediapi/a15127e89b.vtt',
#  'test_cleaning_mediapi/a2a69a013d.vtt',
#  'test_cleaning_mediapi/bd62962446.vtt',
#  'test_cleaning_mediapi/3f01669782.vtt',
#  'test_cleaning_mediapi/ee0e21e91c.vtt',
#  'test_cleaning_mediapi/924cacaba2.vtt',
#  'test_cleaning_mediapi/2d4da5eb35.vtt',
#  'test_cleaning_mediapi/4c2e89b00b.vtt',
#  'test_cleaning_mediapi/f14107b372.vtt',
#  'test_cleaning_mediapi/134f0719e2.vtt',
#  'test_cleaning_mediapi/f5de80f176.vtt',
#  'test_cleaning_mediapi/7ec9f59c86.vtt',
#  'test_cleaning_mediapi/ec7d9c3ce3.vtt',
#  'test_cleaning_mediapi/ba457b68ef.vtt',
#  'test_cleaning_mediapi/37d9782273.vtt',
#  'test_cleaning_mediapi/d62d4d6258.vtt',
#  'test_cleaning_mediapi/6e6b0ab4c6.vtt',
#  'test_cleaning_mediapi/348b16c789.vtt',
#  'test_cleaning_mediapi/911e468394.vtt',
#  'test_cleaning_mediapi/19017f7505.vtt',
#  'test_cleaning_mediapi/de35ab9c5b.vtt',
#  'test_cleaning_mediapi/f7a90779bc.vtt',
#  'test_cleaning_mediapi/b74bbb42a9.vtt',
#  'test_cleaning_mediapi/2a1adda19f.vtt',
#  'test_cleaning_mediapi/85c2c056e6.vtt',
#  'test_cleaning_mediapi/4138b5b69e.vtt',
#  'test_cleaning_mediapi/f4ef94bd1f.vtt',
#  'test_cleaning_mediapi/0dea50e738.vtt',
#  'test_cleaning_mediapi/a5eb8162d1.vtt',
#  'test_cleaning_mediapi/dda86a5da7.vtt',
#  'test_cleaning_mediapi/fe057d9f9f.vtt',
#  'test_cleaning_mediapi/0e3388eb36.vtt',
#  'test_cleaning_mediapi/1fdc547be2.vtt',
#  'test_cleaning_mediapi/daa31bf7c1.vtt',
#  'test_cleaning_mediapi/d5cb8c430d.vtt',
#  'test_cleaning_mediapi/0958edc330.vtt',
#  'test_cleaning_mediapi/3adcab9aa3.vtt',
#  'test_cleaning_mediapi/bcf3072975.vtt',
#  'test_cleaning_mediapi/458db448ae.vtt',
#  'test_cleaning_mediapi/80c28b903d.vtt',
#  ...]

# %%
output_sent = "test_clean_sent_mediapi/"

# %%
def get_dict_vtt(input):
    with open(input,encoding="utf-8") as f:
        lines = f.readlines()

    dict_sub = {}
    i = 0
    j = 0  

    while j < len(lines): 
        element = lines[j]
        if element.startswith("00:") or element.startswith("01:") or element.startswith("02:"):
            # Extraire le temps de début et de fin
            timing_line = element.strip().split(' --> ')
            start_time, end_time = timing_line

            text = ""
            while j + 1 < len(lines) and not lines[j + 1].startswith("00:") and not lines[j+1].startswith("01:") and not lines[j+1].startswith("02:"):
                j += 1
                content = lines[j]
                text = text + " " + content.strip()

            dict_sub[i] = {'start': start_time, 'end': end_time, 'text': text.strip()}
            i += 1

        j += 1

    return dict_sub

# %%
for files, name in zip(file_with_path,folder):
    print("Traitement",files,name)
    dict_sub = get_dict_vtt_clean(files)
    text = ""
    sentences = []
    for k,v in dict_sub.items():
        for kk,vv in v.items():
            if kk=="text":
                text = text + vv + " "
    doc = nlp(text)
    assert doc.has_annotation("SENT_START")
    for sent in doc.sents:
        sentences.append(sent.text)
    with open(f"{output_sent}/{name}","w",encoding="utf-8") as output:
        for sent in sentences:
            output.write(sent+"\n")
# Out:
# Traitement test_cleaning_mediapi/b7f2d8f0c3.vtt b7f2d8f0c3.vtt
# Traitement test_cleaning_mediapi/3d0b82b459.vtt 3d0b82b459.vtt
# Traitement test_cleaning_mediapi/44f554f914.vtt 44f554f914.vtt
# Traitement test_cleaning_mediapi/b9a51f4361.vtt b9a51f4361.vtt
# Traitement test_cleaning_mediapi/4e073949b1.vtt 4e073949b1.vtt
# Traitement test_cleaning_mediapi/0b1437bc85.vtt 0b1437bc85.vtt
# Traitement test_cleaning_mediapi/752500b761.vtt 752500b761.vtt
# Traitement test_cleaning_mediapi/cba6cefad2.vtt cba6cefad2.vtt
# Traitement test_cleaning_mediapi/41c606553f.vtt 41c606553f.vtt
# Traitement test_cleaning_mediapi/3f1b2118ca.vtt 3f1b2118ca.vtt
# Traitement test_cleaning_mediapi/ed969c3e70.vtt ed969c3e70.vtt
# Traitement test_cleaning_mediapi/26f1ff8385.vtt 26f1ff8385.vtt
# Traitement test_cleaning_mediapi/2b4b33189c.vtt 2b4b33189c.vtt
# Traitement test_cleaning_mediapi/ada7d10a19.vtt ada7d10a19.vtt
# Traitement test_cleaning_mediapi/fd41a24117.vtt fd41a24117.vtt
# Traitement test_cleaning_mediapi/15abfc95ae.vtt 15abfc95ae.vtt
# Traitement test_cleaning_mediapi/495145911e.vtt 495145911e.vtt
# Traitement test_cleaning_mediapi/a7c3a0d03b.vtt a7c3a0d03b.vtt
# Traitement test_cleaning_mediapi/5bf0f577d3.vtt 5bf0f577d3.vtt

# %% [markdown]
# ### Nettoyer fichier phrase
# - remonter la ponctuation forte si elle est isolée sur une ligne
# - remonter les sections commençant par une virgule si elles sont isolées du reste de la phrase sur la ligne suivante

# %%
files= m.lister_fichiers_with_path(output_sent)

# %%
files
# Out:
# ['test_clean_sent_mediapi/b7f2d8f0c3.vtt',
#  'test_clean_sent_mediapi/3d0b82b459.vtt',
#  'test_clean_sent_mediapi/44f554f914.vtt',
#  'test_clean_sent_mediapi/b9a51f4361.vtt',
#  'test_clean_sent_mediapi/4e073949b1.vtt',
#  'test_clean_sent_mediapi/0b1437bc85.vtt',
#  'test_clean_sent_mediapi/752500b761.vtt',
#  'test_clean_sent_mediapi/cba6cefad2.vtt',
#  'test_clean_sent_mediapi/41c606553f.vtt',
#  'test_clean_sent_mediapi/3f1b2118ca.vtt',
#  'test_clean_sent_mediapi/ed969c3e70.vtt',
#  'test_clean_sent_mediapi/26f1ff8385.vtt',
#  'test_clean_sent_mediapi/2b4b33189c.vtt',
#  'test_clean_sent_mediapi/ada7d10a19.vtt',
#  'test_clean_sent_mediapi/fd41a24117.vtt',
#  'test_clean_sent_mediapi/15abfc95ae.vtt',
#  'test_clean_sent_mediapi/495145911e.vtt',
#  'test_clean_sent_mediapi/5ef5fa319a.vtt',
#  'test_clean_sent_mediapi/0fd91cb814.vtt',
#  'test_clean_sent_mediapi/9a58b08185.vtt',
#  'test_clean_sent_mediapi/ac6160b61a.vtt',
#  'test_clean_sent_mediapi/74bb642e72.vtt',
#  'test_clean_sent_mediapi/17217ca54b.vtt',
#  'test_clean_sent_mediapi/928499b438.vtt',
#  'test_clean_sent_mediapi/8036e9b4bc.vtt',
#  'test_clean_sent_mediapi/5dfad26566.vtt',
#  'test_clean_sent_mediapi/71e94f545f.vtt',
#  'test_clean_sent_mediapi/008420cac0.vtt',
#  'test_clean_sent_mediapi/689abe06d3.vtt',
#  'test_clean_sent_mediapi/870fcc2c39.vtt',
#  'test_clean_sent_mediapi/575f99a4af.vtt',
#  'test_clean_sent_mediapi/5813b21ceb.vtt',
#  'test_clean_sent_mediapi/6e72821691.vtt',
#  'test_clean_sent_mediapi/cee1643fd7.vtt',
#  'test_clean_sent_mediapi/88fb28815b.vtt',
#  'test_clean_sent_mediapi/a710e36c40.vtt',
#  'test_clean_sent_mediapi/31201b65bf.vtt',
#  'test_clean_sent_mediapi/72aeba358a.vtt',
#  'test_clean_sent_mediapi/1dd7333d1b.vtt',
#  'test_clean_sent_mediapi/a6a8d92675.vtt',
#  'test_clean_sent_mediapi/bdc14ece6e.vtt',
#  'test_clean_sent_mediapi/d9730fe376.vtt',
#  'test_clean_sent_mediapi/142a8e3b5d.vtt',
#  'test_clean_sent_mediapi/383f2888b6.vtt',
#  'test_clean_sent_mediapi/b72ca1fa4f.vtt',
#  'test_clean_sent_mediapi/3adc6931bf.vtt',
#  'test_clean_sent_mediapi/7a7a8be63d.vtt',
#  'test_clean_sent_mediapi/8da1b28015.vtt',
#  'test_clean_sent_mediapi/b6c03b60b7.vtt',
#  'test_clean_sent_mediapi/e3edfd09b6.vtt',
#  'test_clean_sent_mediapi/3013321813.vtt',
#  'test_clean_sent_mediapi/88d76860dd.vtt',
#  'test_clean_sent_mediapi/f49546dd7d.vtt',
#  'test_clean_sent_mediapi/34210d5c72.vtt',
#  'test_clean_sent_mediapi/099c404cc1.vtt',
#  'test_clean_sent_mediapi/bfcd06419a.vtt',
#  'test_clean_sent_mediapi/f978fa2dea.vtt',
#  'test_clean_sent_mediapi/4151b008b6.vtt',
#  'test_clean_sent_mediapi/bc3726d559.vtt',
#  'test_clean_sent_mediapi/6706655430.vtt',
#  'test_clean_sent_mediapi/2b38719c3e.vtt',
#  'test_clean_sent_mediapi/a0ec06d1d3.vtt',
#  'test_clean_sent_mediapi/29a437b7e7.vtt',
#  'test_clean_sent_mediapi/c90bbbf71e.vtt',
#  'test_clean_sent_mediapi/a6de2b7652.vtt',
#  'test_clean_sent_mediapi/38e41f547d.vtt',
#  'test_clean_sent_mediapi/13a80ac2d1.vtt',
#  'test_clean_sent_mediapi/ad79e17356.vtt',
#  'test_clean_sent_mediapi/b28f6ce507.vtt',
#  'test_clean_sent_mediapi/6cf26927ca.vtt',
#  'test_clean_sent_mediapi/c3258a13e3.vtt',
#  'test_clean_sent_mediapi/1992ebbd09.vtt',
#  'test_clean_sent_mediapi/d92e970202.vtt',
#  'test_clean_sent_mediapi/dcd9053975.vtt',
#  'test_clean_sent_mediapi/4e92363ed6.vtt',
#  'test_clean_sent_mediapi/80d22962f8.vtt',
#  'test_clean_sent_mediapi/0eb1494855.vtt',
#  'test_clean_sent_mediapi/a8d35c1600.vtt',
#  'test_clean_sent_mediapi/608fc0be13.vtt',
#  'test_clean_sent_mediapi/c11e5da161.vtt',
#  'test_clean_sent_mediapi/4b51501587.vtt',
#  'test_clean_sent_mediapi/0bfab1c3b4.vtt',
#  'test_clean_sent_mediapi/12b9062560.vtt',
#  'test_clean_sent_mediapi/eb7811a094.vtt',
#  'test_clean_sent_mediapi/491aadc1cf.vtt',
#  'test_clean_sent_mediapi/eea98dceef.vtt',
#  'test_clean_sent_mediapi/11b9db4892.vtt',
#  'test_clean_sent_mediapi/9f59e3b226.vtt',
#  'test_clean_sent_mediapi/82ee104b19.vtt',
#  'test_clean_sent_mediapi/14a49c07ef.vtt',
#  'test_clean_sent_mediapi/7631f48964.vtt',
#  'test_clean_sent_mediapi/e597c8cd01.vtt',
#  'test_clean_sent_mediapi/fad6c87636.vtt',
#  'test_clean_sent_mediapi/d3a84a8ccd.vtt',
#  'test_clean_sent_mediapi/e1f484b5f8.vtt',
#  'test_clean_sent_mediapi/ac9ff299f9.vtt',
#  'test_clean_sent_mediapi/1371e28e24.vtt',
#  'test_clean_sent_mediapi/dd977a1f2a.vtt',
#  'test_clean_sent_mediapi/2a6ad1a50a.vtt',
#  'test_clean_sent_mediapi/1ff266482c.vtt',
#  'test_clean_sent_mediapi/2a59b007d4.vtt',
#  'test_clean_sent_mediapi/7093118618.vtt',
#  'test_clean_sent_mediapi/6648393ad0.vtt',
#  'test_clean_sent_mediapi/042af81098.vtt',
#  'test_clean_sent_mediapi/8c26149486.vtt',
#  'test_clean_sent_mediapi/ef4b03eab2.vtt',
#  'test_clean_sent_mediapi/826afd29f8.vtt',
#  'test_clean_sent_mediapi/040fde163f.vtt',
#  'test_clean_sent_mediapi/4cc54e86f5.vtt',
#  'test_clean_sent_mediapi/2fee0f7592.vtt',
#  'test_clean_sent_mediapi/9e5e128447.vtt',
#  'test_clean_sent_mediapi/c407147f2f.vtt',
#  'test_clean_sent_mediapi/8d58d72944.vtt',
#  'test_clean_sent_mediapi/05211c15bf.vtt',
#  'test_clean_sent_mediapi/5351d97f20.vtt',
#  'test_clean_sent_mediapi/d1636da393.vtt',
#  'test_clean_sent_mediapi/28420f7cbe.vtt',
#  'test_clean_sent_mediapi/e21f0e23a7.vtt',
#  'test_clean_sent_mediapi/a588a2cf33.vtt',
#  'test_clean_sent_mediapi/33c47d59d2.vtt',
#  'test_clean_sent_mediapi/8a6b2fb0ce.vtt',
#  'test_clean_sent_mediapi/1cb5e71134.vtt',
#  'test_clean_sent_mediapi/b07ede0159.vtt',
#  'test_clean_sent_mediapi/6c7ce53264.vtt',
#  'test_clean_sent_mediapi/d2de84864b.vtt',
#  'test_clean_sent_mediapi/9498b85b5b.vtt',
#  'test_clean_sent_mediapi/13d32c0f21.vtt',
#  'test_clean_sent_mediapi/e95f4949ed.vtt',
#  'test_clean_sent_mediapi/de31ed9096.vtt',
#  'test_clean_sent_mediapi/ba24810c74.vtt',
#  'test_clean_sent_mediapi/458237489a.vtt',
#  'test_clean_sent_mediapi/a1c9365f5d.vtt',
#  'test_clean_sent_mediapi/5f10aa9293.vtt',
#  'test_clean_sent_mediapi/5e678b4eb7.vtt',
#  'test_clean_sent_mediapi/17e4f7380a.vtt',
#  'test_clean_sent_mediapi/207c2f7171.vtt',
#  'test_clean_sent_mediapi/f981fbe6af.vtt',
#  'test_clean_sent_mediapi/2af7497055.vtt',
#  'test_clean_sent_mediapi/1bf9bf7cec.vtt',
#  'test_clean_sent_mediapi/9ae39abf0b.vtt',
#  'test_clean_sent_mediapi/5481e47a19.vtt',
#  'test_clean_sent_mediapi/a4064555c2.vtt',
#  'test_clean_sent_mediapi/14cf31e15f.vtt',
#  'test_clean_sent_mediapi/09c5b8a52b.vtt',
#  'test_clean_sent_mediapi/1926b5a3cd.vtt',
#  'test_clean_sent_mediapi/3010fa2532.vtt',
#  'test_clean_sent_mediapi/5edd365f55.vtt',
#  'test_clean_sent_mediapi/ad86de5a8c.vtt',
#  'test_clean_sent_mediapi/457a01b248.vtt',
#  'test_clean_sent_mediapi/110092623c.vtt',
#  'test_clean_sent_mediapi/3879c2ece5.vtt',
#  'test_clean_sent_mediapi/e408818334.vtt',
#  'test_clean_sent_mediapi/163b0c88eb.vtt',
#  'test_clean_sent_mediapi/252c04af8c.vtt',
#  'test_clean_sent_mediapi/48be2d5494.vtt',
#  'test_clean_sent_mediapi/2c7dd7d7a0.vtt',
#  'test_clean_sent_mediapi/648f2d616a.vtt',
#  'test_clean_sent_mediapi/d1a36bfbad.vtt',
#  'test_clean_sent_mediapi/75f0bcdd54.vtt',
#  'test_clean_sent_mediapi/bbfaf1ee13.vtt',
#  'test_clean_sent_mediapi/f18b71d989.vtt',
#  'test_clean_sent_mediapi/2f1e1d3af4.vtt',
#  'test_clean_sent_mediapi/7932f9a3de.vtt',
#  'test_clean_sent_mediapi/2f82f046d5.vtt',
#  'test_clean_sent_mediapi/4d9577ab24.vtt',
#  'test_clean_sent_mediapi/7e4dc844f4.vtt',
#  'test_clean_sent_mediapi/061183eb54.vtt',
#  'test_clean_sent_mediapi/9398a7ed45.vtt',
#  'test_clean_sent_mediapi/530970ed94.vtt',
#  'test_clean_sent_mediapi/657dca485a.vtt',
#  'test_clean_sent_mediapi/2c0e5e2432.vtt',
#  'test_clean_sent_mediapi/1283dc2bc6.vtt',
#  'test_clean_sent_mediapi/55b79b1f96.vtt',
#  'test_clean_sent_mediapi/36129e8e7e.vtt',
#  'test_clean_sent_mediapi/66b8ddb330.vtt',
#  'test_clean_sent_mediapi/8fc0505a8e.vtt',
#  'test_clean_sent_mediapi/91c3a16492.vtt',
#  'test_clean_sent_mediapi/87f4b77d47.vtt',
#  'test_clean_sent_mediapi/a8318f25e7.vtt',
#  'test_clean_sent_mediapi/b4ce85fbf7.vtt',
#  'test_clean_sent_mediapi/647638a97c.vtt',
#  'test_clean_sent_mediapi/3c9c76395a.vtt',
#  'test_clean_sent_mediapi/493574a037.vtt',
#  'test_clean_sent_mediapi/db1ee8312d.vtt',
#  'test_clean_sent_mediapi/3d1087ebe4.vtt',
#  'test_clean_sent_mediapi/3f62714c82.vtt',
#  'test_clean_sent_mediapi/1b4b91655b.vtt',
#  'test_clean_sent_mediapi/78d0acb6e7.vtt',
#  'test_clean_sent_mediapi/245a286c8e.vtt',
#  'test_clean_sent_mediapi/13adb98a30.vtt',
#  'test_clean_sent_mediapi/9088be11a1.vtt',
#  'test_clean_sent_mediapi/cb28f32304.vtt',
#  'test_clean_sent_mediapi/d8687ad02b.vtt',
#  'test_clean_sent_mediapi/b58d9b077e.vtt',
#  'test_clean_sent_mediapi/1cb22a2279.vtt',
#  'test_clean_sent_mediapi/2fc7967195.vtt',
#  'test_clean_sent_mediapi/14595aa066.vtt',
#  'test_clean_sent_mediapi/879dece3e4.vtt',
#  'test_clean_sent_mediapi/0408ad5430.vtt',
#  'test_clean_sent_mediapi/7c92a479c2.vtt',
#  'test_clean_sent_mediapi/49c7c0f2b7.vtt',
#  'test_clean_sent_mediapi/91900415b1.vtt',
#  'test_clean_sent_mediapi/611cd8bac1.vtt',
#  'test_clean_sent_mediapi/1f963b12c6.vtt',
#  'test_clean_sent_mediapi/b5af2cb79d.vtt',
#  'test_clean_sent_mediapi/938d9996d9.vtt',
#  'test_clean_sent_mediapi/4ae8b991ee.vtt',
#  'test_clean_sent_mediapi/b03e954ae1.vtt',
#  'test_clean_sent_mediapi/2a3064d64a.vtt',
#  'test_clean_sent_mediapi/0b2e490c12.vtt',
#  'test_clean_sent_mediapi/d1f4036e1d.vtt',
#  'test_clean_sent_mediapi/d36b54adb5.vtt',
#  'test_clean_sent_mediapi/c810f8ff26.vtt',
#  'test_clean_sent_mediapi/7b59ef6cd5.vtt',
#  'test_clean_sent_mediapi/3d0f798301.vtt',
#  'test_clean_sent_mediapi/f73744b1d5.vtt',
#  'test_clean_sent_mediapi/b2803a42cb.vtt',
#  'test_clean_sent_mediapi/3614c300a2.vtt',
#  'test_clean_sent_mediapi/83ea4b70b9.vtt',
#  'test_clean_sent_mediapi/29afc9b364.vtt',
#  'test_clean_sent_mediapi/82c3c558d8.vtt',
#  'test_clean_sent_mediapi/a835c5a096.vtt',
#  'test_clean_sent_mediapi/596653a27e.vtt',
#  'test_clean_sent_mediapi/baf83ae145.vtt',
#  'test_clean_sent_mediapi/2c5fca9371.vtt',
#  'test_clean_sent_mediapi/6462ce3913.vtt',
#  'test_clean_sent_mediapi/581d5c3587.vtt',
#  'test_clean_sent_mediapi/50d53eca84.vtt',
#  'test_clean_sent_mediapi/b28b182a5e.vtt',
#  'test_clean_sent_mediapi/4836a95980.vtt',
#  'test_clean_sent_mediapi/02eb959bf5.vtt',
#  'test_clean_sent_mediapi/3f8f90ad63.vtt',
#  'test_clean_sent_mediapi/a7b7ca660a.vtt',
#  'test_clean_sent_mediapi/b79a744ad3.vtt',
#  'test_clean_sent_mediapi/56fa0513af.vtt',
#  'test_clean_sent_mediapi/ecc384c1fb.vtt',
#  'test_clean_sent_mediapi/079f72dc4a.vtt',
#  'test_clean_sent_mediapi/94b2ecc091.vtt',
#  'test_clean_sent_mediapi/22d5ed99a6.vtt',
#  'test_clean_sent_mediapi/4b0331f8b5.vtt',
#  'test_clean_sent_mediapi/262f486e74.vtt',
#  'test_clean_sent_mediapi/adc23c06f4.vtt',
#  'test_clean_sent_mediapi/2d57e809c8.vtt',
#  'test_clean_sent_mediapi/f669555f31.vtt',
#  'test_clean_sent_mediapi/9b020e4642.vtt',
#  'test_clean_sent_mediapi/df91b67bdd.vtt',
#  'test_clean_sent_mediapi/98c9059ef5.vtt',
#  'test_clean_sent_mediapi/e7eaf5f54b.vtt',
#  'test_clean_sent_mediapi/c2f70ec746.vtt',
#  'test_clean_sent_mediapi/5fcd740228.vtt',
#  'test_clean_sent_mediapi/b0e33af935.vtt',
#  'test_clean_sent_mediapi/4e0f12fb20.vtt',
#  'test_clean_sent_mediapi/f2050e12cc.vtt',
#  'test_clean_sent_mediapi/9cdb546cc1.vtt',
#  'test_clean_sent_mediapi/df93a88957.vtt',
#  'test_clean_sent_mediapi/98ebcdf002.vtt',
#  'test_clean_sent_mediapi/d3a2006274.vtt',
#  'test_clean_sent_mediapi/d6c3da0752.vtt',
#  'test_clean_sent_mediapi/aef8da9eff.vtt',
#  'test_clean_sent_mediapi/12e13163de.vtt',
#  'test_clean_sent_mediapi/c024039cd1.vtt',
#  'test_clean_sent_mediapi/110161a856.vtt',
#  'test_clean_sent_mediapi/ffc3c7d040.vtt',
#  'test_clean_sent_mediapi/80a81fa418.vtt',
#  'test_clean_sent_mediapi/465a324941.vtt',
#  'test_clean_sent_mediapi/f1c48db332.vtt',
#  'test_clean_sent_mediapi/c50df9cd1b.vtt',
#  'test_clean_sent_mediapi/6776ba2cde.vtt',
#  'test_clean_sent_mediapi/bee7f98af4.vtt',
#  'test_clean_sent_mediapi/50fcb24556.vtt',
#  'test_clean_sent_mediapi/38202ef76f.vtt',
#  'test_clean_sent_mediapi/851117a952.vtt',
#  'test_clean_sent_mediapi/237a756522.vtt',
#  'test_clean_sent_mediapi/18844bd024.vtt',
#  'test_clean_sent_mediapi/359672c30c.vtt',
#  'test_clean_sent_mediapi/c40c5cce62.vtt',
#  'test_clean_sent_mediapi/75fff80619.vtt',
#  'test_clean_sent_mediapi/2ec071dc19.vtt',
#  'test_clean_sent_mediapi/970f89d01d.vtt',
#  'test_clean_sent_mediapi/f10b42a97a.vtt',
#  'test_clean_sent_mediapi/660a4436f6.vtt',
#  'test_clean_sent_mediapi/8ec5a10644.vtt',
#  'test_clean_sent_mediapi/e12bcc6268.vtt',
#  'test_clean_sent_mediapi/f9924c0357.vtt',
#  'test_clean_sent_mediapi/703e807fa9.vtt',
#  'test_clean_sent_mediapi/64a5d50769.vtt',
#  'test_clean_sent_mediapi/d0d25df866.vtt',
#  'test_clean_sent_mediapi/5f6f04ed2f.vtt',
#  'test_clean_sent_mediapi/f08bf6fffb.vtt',
#  'test_clean_sent_mediapi/630fab7050.vtt',
#  'test_clean_sent_mediapi/7aff2e5997.vtt',
#  'test_clean_sent_mediapi/c88f77f27b.vtt',
#  'test_clean_sent_mediapi/0422a33fd6.vtt',
#  'test_clean_sent_mediapi/024e1e4beb.vtt',
#  'test_clean_sent_mediapi/b505799506.vtt',
#  'test_clean_sent_mediapi/479ce05131.vtt',
#  'test_clean_sent_mediapi/09e56af09e.vtt',
#  'test_clean_sent_mediapi/f1a40cd6a4.vtt',
#  'test_clean_sent_mediapi/3ffc340a29.vtt',
#  'test_clean_sent_mediapi/ba0e817586.vtt',
#  'test_clean_sent_mediapi/16833af47a.vtt',
#  'test_clean_sent_mediapi/8416c37a49.vtt',
#  'test_clean_sent_mediapi/8ad919dc08.vtt',
#  'test_clean_sent_mediapi/ffcc270e75.vtt',
#  'test_clean_sent_mediapi/d0b3cbccd3.vtt',
#  'test_clean_sent_mediapi/9479ab515c.vtt',
#  'test_clean_sent_mediapi/be44b82e10.vtt',
#  'test_clean_sent_mediapi/14b6db6d50.vtt',
#  'test_clean_sent_mediapi/5ccd47775a.vtt',
#  'test_clean_sent_mediapi/4abc7be8e2.vtt',
#  'test_clean_sent_mediapi/6ea6b559da.vtt',
#  'test_clean_sent_mediapi/a74d5929b7.vtt',
#  'test_clean_sent_mediapi/d8ceb8bb80.vtt',
#  'test_clean_sent_mediapi/5d686de51e.vtt',
#  'test_clean_sent_mediapi/271112375a.vtt',
#  'test_clean_sent_mediapi/90d4dcda22.vtt',
#  'test_clean_sent_mediapi/36cb6ff5ca.vtt',
#  'test_clean_sent_mediapi/66bbb5f541.vtt',
#  'test_clean_sent_mediapi/e01254488b.vtt',
#  'test_clean_sent_mediapi/b40675cb79.vtt',
#  'test_clean_sent_mediapi/949d9b46f8.vtt',
#  'test_clean_sent_mediapi/3442d011f6.vtt',
#  'test_clean_sent_mediapi/14546e7c31.vtt',
#  'test_clean_sent_mediapi/1c0ecded91.vtt',
#  'test_clean_sent_mediapi/9aaa0e038c.vtt',
#  'test_clean_sent_mediapi/11037b4757.vtt',
#  'test_clean_sent_mediapi/edd6eab05a.vtt',
#  'test_clean_sent_mediapi/e0f686963a.vtt',
#  'test_clean_sent_mediapi/9f4d5f898a.vtt',
#  'test_clean_sent_mediapi/615a53241e.vtt',
#  'test_clean_sent_mediapi/38784516fe.vtt',
#  'test_clean_sent_mediapi/88e7af4054.vtt',
#  'test_clean_sent_mediapi/e19facc031.vtt',
#  'test_clean_sent_mediapi/386bc62c25.vtt',
#  'test_clean_sent_mediapi/297c2bd10f.vtt',
#  'test_clean_sent_mediapi/9340df476f.vtt',
#  'test_clean_sent_mediapi/41be318122.vtt',
#  'test_clean_sent_mediapi/88c3d03c46.vtt',
#  'test_clean_sent_mediapi/ca37cca7de.vtt',
#  'test_clean_sent_mediapi/a4e45aa2a4.vtt',
#  'test_clean_sent_mediapi/8a6d7f5002.vtt',
#  'test_clean_sent_mediapi/10f8859418.vtt',
#  'test_clean_sent_mediapi/707744965b.vtt',
#  'test_clean_sent_mediapi/b9e908d0b5.vtt',
#  'test_clean_sent_mediapi/2cbe7d2a9f.vtt',
#  'test_clean_sent_mediapi/272d389416.vtt',
#  'test_clean_sent_mediapi/7994acc604.vtt',
#  'test_clean_sent_mediapi/22b403a6ba.vtt',
#  'test_clean_sent_mediapi/b999628114.vtt',
#  'test_clean_sent_mediapi/32d8e4cb1a.vtt',
#  'test_clean_sent_mediapi/4a5b8b88d3.vtt',
#  'test_clean_sent_mediapi/976db5c061.vtt',
#  'test_clean_sent_mediapi/b919eb82f9.vtt',
#  'test_clean_sent_mediapi/eb8d1a582f.vtt',
#  'test_clean_sent_mediapi/acf0268cfb.vtt',
#  'test_clean_sent_mediapi/1c70031f32.vtt',
#  'test_clean_sent_mediapi/b7ef5a5728.vtt',
#  'test_clean_sent_mediapi/9e4aec6d41.vtt',
#  'test_clean_sent_mediapi/765d9c5adb.vtt',
#  'test_clean_sent_mediapi/e7708e38ae.vtt',
#  'test_clean_sent_mediapi/005c1d83b5.vtt',
#  'test_clean_sent_mediapi/03a663d287.vtt',
#  'test_clean_sent_mediapi/bc3e50e582.vtt',
#  'test_clean_sent_mediapi/1fbaf3f4f6.vtt',
#  'test_clean_sent_mediapi/a6e280e756.vtt',
#  'test_clean_sent_mediapi/99fc016b5c.vtt',
#  'test_clean_sent_mediapi/95d846a441.vtt',
#  'test_clean_sent_mediapi/effdd1d4e1.vtt',
#  'test_clean_sent_mediapi/947de0ab18.vtt',
#  'test_clean_sent_mediapi/ad9f94ce37.vtt',
#  'test_clean_sent_mediapi/b04456b1fd.vtt',
#  'test_clean_sent_mediapi/84085b1bd6.vtt',
#  'test_clean_sent_mediapi/c594d9509f.vtt',
#  'test_clean_sent_mediapi/b21d98af65.vtt',
#  'test_clean_sent_mediapi/c0610253ed.vtt',
#  'test_clean_sent_mediapi/f2fe524efc.vtt',
#  'test_clean_sent_mediapi/1dcc266cc2.vtt',
#  'test_clean_sent_mediapi/8eb47e34e0.vtt',
#  'test_clean_sent_mediapi/a98b8cf2c3.vtt',
#  'test_clean_sent_mediapi/cba694874b.vtt',
#  'test_clean_sent_mediapi/25aeb2b40b.vtt',
#  'test_clean_sent_mediapi/e670e798a7.vtt',
#  'test_clean_sent_mediapi/a554388c1f.vtt',
#  'test_clean_sent_mediapi/3bc00c3615.vtt',
#  'test_clean_sent_mediapi/76677dc1f6.vtt',
#  'test_clean_sent_mediapi/0e2a1bdaf5.vtt',
#  'test_clean_sent_mediapi/65947fe1c1.vtt',
#  'test_clean_sent_mediapi/35c67ac1f7.vtt',
#  'test_clean_sent_mediapi/4e80578498.vtt',
#  'test_clean_sent_mediapi/a5b3b88bdc.vtt',
#  'test_clean_sent_mediapi/1e70ec9d20.vtt',
#  'test_clean_sent_mediapi/3e28e0e644.vtt',
#  'test_clean_sent_mediapi/230f85da51.vtt',
#  'test_clean_sent_mediapi/6117dcd7a2.vtt',
#  'test_clean_sent_mediapi/96adc457d0.vtt',
#  'test_clean_sent_mediapi/8c2b65d935.vtt',
#  'test_clean_sent_mediapi/2b6e3a9da2.vtt',
#  'test_clean_sent_mediapi/39ead9e95a.vtt',
#  'test_clean_sent_mediapi/44747be184.vtt',
#  'test_clean_sent_mediapi/8edc772a9a.vtt',
#  'test_clean_sent_mediapi/a41024bd3b.vtt',
#  'test_clean_sent_mediapi/24a2f80399.vtt',
#  'test_clean_sent_mediapi/a403b7bb54.vtt',
#  'test_clean_sent_mediapi/e59917d79e.vtt',
#  'test_clean_sent_mediapi/e43f408c99.vtt',
#  'test_clean_sent_mediapi/d0c357c68d.vtt',
#  'test_clean_sent_mediapi/57ae2510fe.vtt',
#  'test_clean_sent_mediapi/335d2d2b5c.vtt',
#  'test_clean_sent_mediapi/5c29af74aa.vtt',
#  'test_clean_sent_mediapi/8a20ab9bf6.vtt',
#  'test_clean_sent_mediapi/6301f34c78.vtt',
#  'test_clean_sent_mediapi/5f562efece.vtt',
#  'test_clean_sent_mediapi/dc1c1a52bc.vtt',
#  'test_clean_sent_mediapi/24de616d2b.vtt',
#  'test_clean_sent_mediapi/142b256d4d.vtt',
#  'test_clean_sent_mediapi/69d2ad88ba.vtt',
#  'test_clean_sent_mediapi/8359481cc4.vtt',
#  'test_clean_sent_mediapi/d2e39b6d9c.vtt',
#  'test_clean_sent_mediapi/77fee386a7.vtt',
#  'test_clean_sent_mediapi/e464d9dcc5.vtt',
#  'test_clean_sent_mediapi/07befc1812.vtt',
#  'test_clean_sent_mediapi/3c3c93c444.vtt',
#  'test_clean_sent_mediapi/2e078832df.vtt',
#  'test_clean_sent_mediapi/090d0be02e.vtt',
#  'test_clean_sent_mediapi/01dd99ecbe.vtt',
#  'test_clean_sent_mediapi/a83ab651cf.vtt',
#  'test_clean_sent_mediapi/11af6bdd76.vtt',
#  'test_clean_sent_mediapi/8e0c9606b6.vtt',
#  'test_clean_sent_mediapi/21a181e1ae.vtt',
#  'test_clean_sent_mediapi/0dcd5e10b0.vtt',
#  'test_clean_sent_mediapi/adf8fb3f23.vtt',
#  'test_clean_sent_mediapi/8d8fb3b4cd.vtt',
#  'test_clean_sent_mediapi/8642070414.vtt',
#  'test_clean_sent_mediapi/5a5a694c34.vtt',
#  'test_clean_sent_mediapi/95c12148e2.vtt',
#  'test_clean_sent_mediapi/da8eb72bc1.vtt',
#  'test_clean_sent_mediapi/a2e5d49b61.vtt',
#  'test_clean_sent_mediapi/d60ff1ef18.vtt',
#  'test_clean_sent_mediapi/e1e045ad7d.vtt',
#  'test_clean_sent_mediapi/efc93baeb2.vtt',
#  'test_clean_sent_mediapi/43f582c164.vtt',
#  'test_clean_sent_mediapi/81ca26f220.vtt',
#  'test_clean_sent_mediapi/4daaf2c66f.vtt',
#  'test_clean_sent_mediapi/e19a9925b1.vtt',
#  'test_clean_sent_mediapi/2c3e419f2b.vtt',
#  'test_clean_sent_mediapi/45d6cf7828.vtt',
#  'test_clean_sent_mediapi/dd5b0e331a.vtt',
#  'test_clean_sent_mediapi/77f261808f.vtt',
#  'test_clean_sent_mediapi/866c289c93.vtt',
#  'test_clean_sent_mediapi/a224f59ad6.vtt',
#  'test_clean_sent_mediapi/c8c66bdd6f.vtt',
#  'test_clean_sent_mediapi/19a1bba43b.vtt',
#  'test_clean_sent_mediapi/d8bbccd121.vtt',
#  'test_clean_sent_mediapi/5004a94819.vtt',
#  'test_clean_sent_mediapi/82c624dbaf.vtt',
#  'test_clean_sent_mediapi/c22c376d52.vtt',
#  'test_clean_sent_mediapi/ade0ef2c55.vtt',
#  'test_clean_sent_mediapi/e30a464eee.vtt',
#  'test_clean_sent_mediapi/7f3beb2d58.vtt',
#  'test_clean_sent_mediapi/3359f1be56.vtt',
#  'test_clean_sent_mediapi/c1f430c2f0.vtt',
#  'test_clean_sent_mediapi/d44180b637.vtt',
#  'test_clean_sent_mediapi/ee9b3a1e3e.vtt',
#  'test_clean_sent_mediapi/0f1051cb25.vtt',
#  'test_clean_sent_mediapi/48f549652e.vtt',
#  'test_clean_sent_mediapi/7505042632.vtt',
#  'test_clean_sent_mediapi/6e6af002ad.vtt',
#  'test_clean_sent_mediapi/89489be991.vtt',
#  'test_clean_sent_mediapi/1d745d545b.vtt',
#  'test_clean_sent_mediapi/2228305d06.vtt',
#  'test_clean_sent_mediapi/74ae0ed0a5.vtt',
#  'test_clean_sent_mediapi/eba92cae3d.vtt',
#  'test_clean_sent_mediapi/563676970c.vtt',
#  'test_clean_sent_mediapi/6f90984e91.vtt',
#  'test_clean_sent_mediapi/cc35f77853.vtt',
#  'test_clean_sent_mediapi/7864c44ef3.vtt',
#  'test_clean_sent_mediapi/53368e68f9.vtt',
#  'test_clean_sent_mediapi/cde20f4012.vtt',
#  'test_clean_sent_mediapi/c13dd9f62c.vtt',
#  'test_clean_sent_mediapi/9176874f0e.vtt',
#  'test_clean_sent_mediapi/5a1ce9d645.vtt',
#  'test_clean_sent_mediapi/55d31feed0.vtt',
#  'test_clean_sent_mediapi/b1483e5350.vtt',
#  'test_clean_sent_mediapi/8669cf38d8.vtt',
#  'test_clean_sent_mediapi/31a057a3a5.vtt',
#  'test_clean_sent_mediapi/1c88ec3e06.vtt',
#  'test_clean_sent_mediapi/dfbdc630e8.vtt',
#  'test_clean_sent_mediapi/8c2e52e760.vtt',
#  'test_clean_sent_mediapi/36fdaab1d9.vtt',
#  'test_clean_sent_mediapi/c67b4711f0.vtt',
#  'test_clean_sent_mediapi/81ac1c0dbf.vtt',
#  'test_clean_sent_mediapi/4acb37ab13.vtt',
#  'test_clean_sent_mediapi/d1f07ae7be.vtt',
#  'test_clean_sent_mediapi/dc185a226a.vtt',
#  'test_clean_sent_mediapi/9bb0f3568a.vtt',
#  'test_clean_sent_mediapi/09d9fd8274.vtt',
#  'test_clean_sent_mediapi/68d6ea066e.vtt',
#  'test_clean_sent_mediapi/0d7eab9559.vtt',
#  'test_clean_sent_mediapi/4e4f33a56c.vtt',
#  'test_clean_sent_mediapi/2c3e431912.vtt',
#  'test_clean_sent_mediapi/4b55cb4b47.vtt',
#  'test_clean_sent_mediapi/b0c699509f.vtt',
#  'test_clean_sent_mediapi/158512e90e.vtt',
#  'test_clean_sent_mediapi/bf961c01d4.vtt',
#  'test_clean_sent_mediapi/dd42853f7f.vtt',
#  'test_clean_sent_mediapi/dbedbbb968.vtt',
#  'test_clean_sent_mediapi/bf2a32e353.vtt',
#  'test_clean_sent_mediapi/6f2c5e8b83.vtt',
#  'test_clean_sent_mediapi/b66ce7f665.vtt',
#  'test_clean_sent_mediapi/6393749f81.vtt',
#  'test_clean_sent_mediapi/9ed39ce7f5.vtt',
#  'test_clean_sent_mediapi/6792e8ffe5.vtt',
#  'test_clean_sent_mediapi/b7324e955e.vtt',
#  'test_clean_sent_mediapi/ed1ed9215f.vtt',
#  'test_clean_sent_mediapi/87e499e7d6.vtt',
#  'test_clean_sent_mediapi/4b75fc29cc.vtt',
#  'test_clean_sent_mediapi/d034fc5d24.vtt',
#  'test_clean_sent_mediapi/879211e014.vtt',
#  'test_clean_sent_mediapi/4fbfd0f4d8.vtt',
#  'test_clean_sent_mediapi/a05bf5591e.vtt',
#  'test_clean_sent_mediapi/c0df314bc4.vtt',
#  'test_clean_sent_mediapi/007e93fe10.vtt',
#  'test_clean_sent_mediapi/f809b59df3.vtt',
#  'test_clean_sent_mediapi/e368178763.vtt',
#  'test_clean_sent_mediapi/1ddacc21a0.vtt',
#  'test_clean_sent_mediapi/c4d00ff49a.vtt',
#  'test_clean_sent_mediapi/7fc84d9a5a.vtt',
#  'test_clean_sent_mediapi/db44861992.vtt',
#  'test_clean_sent_mediapi/8d2df25953.vtt',
#  'test_clean_sent_mediapi/77ecdba15d.vtt',
#  'test_clean_sent_mediapi/c9953b740c.vtt',
#  'test_clean_sent_mediapi/c3f983e868.vtt',
#  'test_clean_sent_mediapi/097a4fef22.vtt',
#  'test_clean_sent_mediapi/66ebb89c4c.vtt',
#  'test_clean_sent_mediapi/e95a567a09.vtt',
#  'test_clean_sent_mediapi/989a1835fe.vtt',
#  'test_clean_sent_mediapi/c34ffa64e0.vtt',
#  'test_clean_sent_mediapi/1889b75efa.vtt',
#  'test_clean_sent_mediapi/6712d91613.vtt',
#  'test_clean_sent_mediapi/594611e383.vtt',
#  'test_clean_sent_mediapi/3353a269d2.vtt',
#  'test_clean_sent_mediapi/d52cf3dcd1.vtt',
#  'test_clean_sent_mediapi/8798b0daac.vtt',
#  'test_clean_sent_mediapi/a96eb76066.vtt',
#  'test_clean_sent_mediapi/d3a8db7edc.vtt',
#  'test_clean_sent_mediapi/e33dc93738.vtt',
#  'test_clean_sent_mediapi/61c5ab3727.vtt',
#  'test_clean_sent_mediapi/8887fb224c.vtt',
#  'test_clean_sent_mediapi/c227ed8574.vtt',
#  'test_clean_sent_mediapi/2fda2f3c58.vtt',
#  'test_clean_sent_mediapi/2e8beb516a.vtt',
#  'test_clean_sent_mediapi/2d7c91971e.vtt',
#  'test_clean_sent_mediapi/707ec17828.vtt',
#  'test_clean_sent_mediapi/400d74e17c.vtt',
#  'test_clean_sent_mediapi/d4257e9a67.vtt',
#  'test_clean_sent_mediapi/80e3770f7a.vtt',
#  'test_clean_sent_mediapi/e2579db45f.vtt',
#  'test_clean_sent_mediapi/2105272292.vtt',
#  'test_clean_sent_mediapi/06bd1b1086.vtt',
#  'test_clean_sent_mediapi/90e3f2e10d.vtt',
#  'test_clean_sent_mediapi/61c4591cc4.vtt',
#  'test_clean_sent_mediapi/1075c6bd0d.vtt',
#  'test_clean_sent_mediapi/e86049976c.vtt',
#  'test_clean_sent_mediapi/ca66f9d3a4.vtt',
#  'test_clean_sent_mediapi/4ad7c1e022.vtt',
#  'test_clean_sent_mediapi/6a81037850.vtt',
#  'test_clean_sent_mediapi/a5e77d9fa0.vtt',
#  'test_clean_sent_mediapi/ff4fce1cea.vtt',
#  'test_clean_sent_mediapi/123a1b5841.vtt',
#  'test_clean_sent_mediapi/cb84e53bae.vtt',
#  'test_clean_sent_mediapi/2e3e2c8edd.vtt',
#  'test_clean_sent_mediapi/bcf9c6c740.vtt',
#  'test_clean_sent_mediapi/7e8367dedc.vtt',
#  'test_clean_sent_mediapi/b755b0b8e2.vtt',
#  'test_clean_sent_mediapi/b0c397bea1.vtt',
#  'test_clean_sent_mediapi/a98727918a.vtt',
#  'test_clean_sent_mediapi/42c0f86874.vtt',
#  'test_clean_sent_mediapi/540d68480b.vtt',
#  'test_clean_sent_mediapi/12e80c1738.vtt',
#  'test_clean_sent_mediapi/29ccad584f.vtt',
#  'test_clean_sent_mediapi/fdbd52af78.vtt',
#  'test_clean_sent_mediapi/80f0119bfc.vtt',
#  'test_clean_sent_mediapi/2e7bce1ed4.vtt',
#  'test_clean_sent_mediapi/1f8375ce7c.vtt',
#  'test_clean_sent_mediapi/8b83f9214e.vtt',
#  'test_clean_sent_mediapi/8766a6d6de.vtt',
#  'test_clean_sent_mediapi/cc00634e86.vtt',
#  'test_clean_sent_mediapi/d95ab8bdab.vtt',
#  'test_clean_sent_mediapi/d8a9599586.vtt',
#  'test_clean_sent_mediapi/bfb2a15e14.vtt',
#  'test_clean_sent_mediapi/49caa465d3.vtt',
#  'test_clean_sent_mediapi/4699dc221b.vtt',
#  'test_clean_sent_mediapi/72ceebd88e.vtt',
#  'test_clean_sent_mediapi/20cf216ad7.vtt',
#  'test_clean_sent_mediapi/b4c9e8385b.vtt',
#  'test_clean_sent_mediapi/eb77b5308c.vtt',
#  'test_clean_sent_mediapi/2618677de2.vtt',
#  'test_clean_sent_mediapi/0ad3102bff.vtt',
#  'test_clean_sent_mediapi/7960117bbf.vtt',
#  'test_clean_sent_mediapi/29b4b507f2.vtt',
#  'test_clean_sent_mediapi/313f76e7c3.vtt',
#  'test_clean_sent_mediapi/dccdecda4e.vtt',
#  'test_clean_sent_mediapi/aaf27b88b4.vtt',
#  'test_clean_sent_mediapi/ce5d5018fd.vtt',
#  'test_clean_sent_mediapi/7b3f88ddd2.vtt',
#  'test_clean_sent_mediapi/4e31163122.vtt',
#  'test_clean_sent_mediapi/734390434c.vtt',
#  'test_clean_sent_mediapi/bd9e379d2a.vtt',
#  'test_clean_sent_mediapi/ad6110f483.vtt',
#  'test_clean_sent_mediapi/4768569d45.vtt',
#  'test_clean_sent_mediapi/7e44de75cd.vtt',
#  'test_clean_sent_mediapi/394f28da6d.vtt',
#  'test_clean_sent_mediapi/3021b49a67.vtt',
#  'test_clean_sent_mediapi/b342c8a1aa.vtt',
#  'test_clean_sent_mediapi/bfff04a4a5.vtt',
#  'test_clean_sent_mediapi/d825b2c63b.vtt',
#  'test_clean_sent_mediapi/2bb2f10521.vtt',
#  'test_clean_sent_mediapi/f34e489689.vtt',
#  'test_clean_sent_mediapi/db0657fe2d.vtt',
#  'test_clean_sent_mediapi/382e80de8e.vtt',
#  'test_clean_sent_mediapi/c7abaa3eec.vtt',
#  'test_clean_sent_mediapi/2f3e563b8a.vtt',
#  'test_clean_sent_mediapi/c701ca2185.vtt',
#  'test_clean_sent_mediapi/4908681725.vtt',
#  'test_clean_sent_mediapi/5646a154f8.vtt',
#  'test_clean_sent_mediapi/05b2391c69.vtt',
#  'test_clean_sent_mediapi/229d83b08d.vtt',
#  'test_clean_sent_mediapi/4eb6737c5e.vtt',
#  'test_clean_sent_mediapi/fe7620b018.vtt',
#  'test_clean_sent_mediapi/af53f5f1b5.vtt',
#  'test_clean_sent_mediapi/2a82fefa67.vtt',
#  'test_clean_sent_mediapi/0bc405ea52.vtt',
#  'test_clean_sent_mediapi/e4479999e0.vtt',
#  'test_clean_sent_mediapi/73a7632c39.vtt',
#  'test_clean_sent_mediapi/7e92fc992c.vtt',
#  'test_clean_sent_mediapi/5691b6660e.vtt',
#  'test_clean_sent_mediapi/2ed4d01376.vtt',
#  'test_clean_sent_mediapi/36b0bdaedd.vtt',
#  'test_clean_sent_mediapi/d56bb29d5a.vtt',
#  'test_clean_sent_mediapi/4b7075153d.vtt',
#  'test_clean_sent_mediapi/74493084b4.vtt',
#  'test_clean_sent_mediapi/c3bbbe3ed6.vtt',
#  'test_clean_sent_mediapi/d497ab281a.vtt',
#  'test_clean_sent_mediapi/4ac466ae53.vtt',
#  'test_clean_sent_mediapi/626d031ee1.vtt',
#  'test_clean_sent_mediapi/6a298953f1.vtt',
#  'test_clean_sent_mediapi/b79d4431f4.vtt',
#  'test_clean_sent_mediapi/064c29757d.vtt',
#  'test_clean_sent_mediapi/aecfacc5d8.vtt',
#  'test_clean_sent_mediapi/c3cd5979fc.vtt',
#  'test_clean_sent_mediapi/e4706995b4.vtt',
#  'test_clean_sent_mediapi/37565c45b8.vtt',
#  'test_clean_sent_mediapi/7b7a12d16a.vtt',
#  'test_clean_sent_mediapi/83a3280632.vtt',
#  'test_clean_sent_mediapi/e230e106ef.vtt',
#  'test_clean_sent_mediapi/62be27fbdf.vtt',
#  'test_clean_sent_mediapi/37649fe849.vtt',
#  'test_clean_sent_mediapi/55640c76bc.vtt',
#  'test_clean_sent_mediapi/97008f55fe.vtt',
#  'test_clean_sent_mediapi/9cf248b494.vtt',
#  'test_clean_sent_mediapi/54f0b235d2.vtt',
#  'test_clean_sent_mediapi/39296e7eeb.vtt',
#  'test_clean_sent_mediapi/7aad4499ce.vtt',
#  'test_clean_sent_mediapi/0765d24a4b.vtt',
#  'test_clean_sent_mediapi/18c81f1726.vtt',
#  'test_clean_sent_mediapi/9fc61f22f8.vtt',
#  'test_clean_sent_mediapi/66abe05bf2.vtt',
#  'test_clean_sent_mediapi/6690aa372a.vtt',
#  'test_clean_sent_mediapi/76527ca4a1.vtt',
#  'test_clean_sent_mediapi/ed5fc55af8.vtt',
#  'test_clean_sent_mediapi/162f0a069d.vtt',
#  'test_clean_sent_mediapi/e8f32b5aec.vtt',
#  'test_clean_sent_mediapi/305ece2b43.vtt',
#  'test_clean_sent_mediapi/7a470b0584.vtt',
#  'test_clean_sent_mediapi/7965914d3c.vtt',
#  'test_clean_sent_mediapi/0e4b9b61cd.vtt',
#  'test_clean_sent_mediapi/cf0560302a.vtt',
#  'test_clean_sent_mediapi/c541fe2f8f.vtt',
#  'test_clean_sent_mediapi/c6fa62301e.vtt',
#  'test_clean_sent_mediapi/a866723238.vtt',
#  'test_clean_sent_mediapi/0d443f2a98.vtt',
#  'test_clean_sent_mediapi/f6e5c0c26a.vtt',
#  'test_clean_sent_mediapi/45b9ad5268.vtt',
#  'test_clean_sent_mediapi/a696bb71a9.vtt',
#  'test_clean_sent_mediapi/7c37473c3c.vtt',
#  'test_clean_sent_mediapi/e66392581f.vtt',
#  'test_clean_sent_mediapi/ecc5a3942b.vtt',
#  'test_clean_sent_mediapi/0115c2b09b.vtt',
#  'test_clean_sent_mediapi/a641f42166.vtt',
#  'test_clean_sent_mediapi/3b79decbc9.vtt',
#  'test_clean_sent_mediapi/a280ff1c53.vtt',
#  'test_clean_sent_mediapi/3ffa63d75a.vtt',
#  'test_clean_sent_mediapi/c363cbfd61.vtt',
#  'test_clean_sent_mediapi/8138a541a5.vtt',
#  'test_clean_sent_mediapi/8ea183f1f5.vtt',
#  'test_clean_sent_mediapi/feca49cbaa.vtt',
#  'test_clean_sent_mediapi/d425fce2da.vtt',
#  'test_clean_sent_mediapi/326141f1f4.vtt',
#  'test_clean_sent_mediapi/33a54cbee5.vtt',
#  'test_clean_sent_mediapi/6af24e6b9c.vtt',
#  'test_clean_sent_mediapi/ddeb744c53.vtt',
#  'test_clean_sent_mediapi/99ae96b29c.vtt',
#  'test_clean_sent_mediapi/e57e8b7c37.vtt',
#  'test_clean_sent_mediapi/62276f91e1.vtt',
#  'test_clean_sent_mediapi/8d0823d738.vtt',
#  'test_clean_sent_mediapi/b429f5a759.vtt',
#  'test_clean_sent_mediapi/b6cc4945b6.vtt',
#  'test_clean_sent_mediapi/55d08c6fc4.vtt',
#  'test_clean_sent_mediapi/3fa25c7095.vtt',
#  'test_clean_sent_mediapi/4a252ec277.vtt',
#  'test_clean_sent_mediapi/22a16b62bc.vtt',
#  'test_clean_sent_mediapi/31dad5f98a.vtt',
#  'test_clean_sent_mediapi/615add5cf4.vtt',
#  'test_clean_sent_mediapi/b250e47b2b.vtt',
#  'test_clean_sent_mediapi/b6054bc6bb.vtt',
#  'test_clean_sent_mediapi/d48237606a.vtt',
#  'test_clean_sent_mediapi/c8b833afd7.vtt',
#  'test_clean_sent_mediapi/758bf7e8ed.vtt',
#  'test_clean_sent_mediapi/3eb3ab1fef.vtt',
#  'test_clean_sent_mediapi/f7caaffe1d.vtt',
#  'test_clean_sent_mediapi/46350d187b.vtt',
#  'test_clean_sent_mediapi/f97fcf5a4d.vtt',
#  'test_clean_sent_mediapi/8301b184e8.vtt',
#  'test_clean_sent_mediapi/5735a80004.vtt',
#  'test_clean_sent_mediapi/a8f13856bf.vtt',
#  'test_clean_sent_mediapi/607e9ca2bb.vtt',
#  'test_clean_sent_mediapi/e0b70c1082.vtt',
#  'test_clean_sent_mediapi/ce9de8b930.vtt',
#  'test_clean_sent_mediapi/4fa6604d53.vtt',
#  'test_clean_sent_mediapi/8c91275c23.vtt',
#  'test_clean_sent_mediapi/5932420960.vtt',
#  'test_clean_sent_mediapi/006c967985.vtt',
#  'test_clean_sent_mediapi/830786537d.vtt',
#  'test_clean_sent_mediapi/50d8874b8e.vtt',
#  'test_clean_sent_mediapi/d36f5cd4e6.vtt',
#  'test_clean_sent_mediapi/fd7a4fe996.vtt',
#  'test_clean_sent_mediapi/83da8d7784.vtt',
#  'test_clean_sent_mediapi/9e61943819.vtt',
#  'test_clean_sent_mediapi/135ea78eca.vtt',
#  'test_clean_sent_mediapi/93d9ee7e54.vtt',
#  'test_clean_sent_mediapi/d90dab344d.vtt',
#  'test_clean_sent_mediapi/5145aec988.vtt',
#  'test_clean_sent_mediapi/b012d51af2.vtt',
#  'test_clean_sent_mediapi/4332f75660.vtt',
#  'test_clean_sent_mediapi/5280b59cb0.vtt',
#  'test_clean_sent_mediapi/edbb2048f4.vtt',
#  'test_clean_sent_mediapi/31c07b40cc.vtt',
#  'test_clean_sent_mediapi/a654767845.vtt',
#  'test_clean_sent_mediapi/622637d921.vtt',
#  'test_clean_sent_mediapi/5f489e079c.vtt',
#  'test_clean_sent_mediapi/e39c1f06da.vtt',
#  'test_clean_sent_mediapi/31df3a7cc2.vtt',
#  'test_clean_sent_mediapi/cb0a0e3426.vtt',
#  'test_clean_sent_mediapi/7252beee04.vtt',
#  'test_clean_sent_mediapi/6ad1e621d4.vtt',
#  'test_clean_sent_mediapi/56930435ad.vtt',
#  'test_clean_sent_mediapi/989d6ae384.vtt',
#  'test_clean_sent_mediapi/39ab15057b.vtt',
#  'test_clean_sent_mediapi/8b80603b23.vtt',
#  'test_clean_sent_mediapi/9af48150cf.vtt',
#  'test_clean_sent_mediapi/eff81d1cb1.vtt',
#  'test_clean_sent_mediapi/80c46d83c7.vtt',
#  'test_clean_sent_mediapi/ec05292732.vtt',
#  'test_clean_sent_mediapi/d39619177e.vtt',
#  'test_clean_sent_mediapi/df61458799.vtt',
#  'test_clean_sent_mediapi/3ee0d4448a.vtt',
#  'test_clean_sent_mediapi/50ec46349b.vtt',
#  'test_clean_sent_mediapi/3b6845a06e.vtt',
#  'test_clean_sent_mediapi/c60c8a0e59.vtt',
#  'test_clean_sent_mediapi/397be9d7c6.vtt',
#  'test_clean_sent_mediapi/306fd536fe.vtt',
#  'test_clean_sent_mediapi/1c542bb920.vtt',
#  'test_clean_sent_mediapi/0b4178c4c4.vtt',
#  'test_clean_sent_mediapi/168e1273c7.vtt',
#  'test_clean_sent_mediapi/0886667473.vtt',
#  'test_clean_sent_mediapi/54470ab13c.vtt',
#  'test_clean_sent_mediapi/bfa29bd364.vtt',
#  'test_clean_sent_mediapi/2649c342ba.vtt',
#  'test_clean_sent_mediapi/0e952f39b4.vtt',
#  'test_clean_sent_mediapi/fd506a56e0.vtt',
#  'test_clean_sent_mediapi/ebfe6998b2.vtt',
#  'test_clean_sent_mediapi/5d53d87a06.vtt',
#  'test_clean_sent_mediapi/6d8b8acd55.vtt',
#  'test_clean_sent_mediapi/57fdf7fb9d.vtt',
#  'test_clean_sent_mediapi/25153274a8.vtt',
#  'test_clean_sent_mediapi/32db6c4841.vtt',
#  'test_clean_sent_mediapi/417889b119.vtt',
#  'test_clean_sent_mediapi/15c7c92075.vtt',
#  'test_clean_sent_mediapi/4e5f470a82.vtt',
#  'test_clean_sent_mediapi/3ff09d96dd.vtt',
#  'test_clean_sent_mediapi/04d9d598d3.vtt',
#  'test_clean_sent_mediapi/03f29e747a.vtt',
#  'test_clean_sent_mediapi/2326ffa6ce.vtt',
#  'test_clean_sent_mediapi/09eb6e0d52.vtt',
#  'test_clean_sent_mediapi/245b9b71f7.vtt',
#  'test_clean_sent_mediapi/0d5cdb2c2a.vtt',
#  'test_clean_sent_mediapi/88c50beee2.vtt',
#  'test_clean_sent_mediapi/29842ed9ec.vtt',
#  'test_clean_sent_mediapi/5cb50877f4.vtt',
#  'test_clean_sent_mediapi/065ea6e5bf.vtt',
#  'test_clean_sent_mediapi/bdb59d67ef.vtt',
#  'test_clean_sent_mediapi/b3960358e1.vtt',
#  'test_clean_sent_mediapi/a22f6a6312.vtt',
#  'test_clean_sent_mediapi/9681ad041c.vtt',
#  'test_clean_sent_mediapi/d31e97577f.vtt',
#  'test_clean_sent_mediapi/bc0260a7ca.vtt',
#  'test_clean_sent_mediapi/dad834a042.vtt',
#  'test_clean_sent_mediapi/b1336e9183.vtt',
#  'test_clean_sent_mediapi/ba03c6187d.vtt',
#  'test_clean_sent_mediapi/d5ef6a969d.vtt',
#  'test_clean_sent_mediapi/9f9b911c45.vtt',
#  'test_clean_sent_mediapi/4e23d74fb5.vtt',
#  'test_clean_sent_mediapi/8cd104ba92.vtt',
#  'test_clean_sent_mediapi/698754af6f.vtt',
#  'test_clean_sent_mediapi/803566e63f.vtt',
#  'test_clean_sent_mediapi/f8efa537a4.vtt',
#  'test_clean_sent_mediapi/7d4b94b1b8.vtt',
#  'test_clean_sent_mediapi/6a9b844506.vtt',
#  'test_clean_sent_mediapi/a754297727.vtt',
#  'test_clean_sent_mediapi/857cdae196.vtt',
#  'test_clean_sent_mediapi/a7cda633b7.vtt',
#  'test_clean_sent_mediapi/7baac95df4.vtt',
#  'test_clean_sent_mediapi/b7b2b2aaa6.vtt',
#  'test_clean_sent_mediapi/43e7bee91c.vtt',
#  'test_clean_sent_mediapi/130817bfd6.vtt',
#  'test_clean_sent_mediapi/e240fee64a.vtt',
#  'test_clean_sent_mediapi/7b90788a67.vtt',
#  'test_clean_sent_mediapi/620d38721f.vtt',
#  'test_clean_sent_mediapi/a070f05a21.vtt',
#  'test_clean_sent_mediapi/6c450e66ea.vtt',
#  'test_clean_sent_mediapi/0643216cf1.vtt',
#  'test_clean_sent_mediapi/79e0b54a84.vtt',
#  'test_clean_sent_mediapi/0609375190.vtt',
#  'test_clean_sent_mediapi/29944461b4.vtt',
#  'test_clean_sent_mediapi/ba055a3460.vtt',
#  'test_clean_sent_mediapi/274d19924a.vtt',
#  'test_clean_sent_mediapi/a8f20e0935.vtt',
#  'test_clean_sent_mediapi/c5c018814c.vtt',
#  'test_clean_sent_mediapi/fc5562f5f4.vtt',
#  'test_clean_sent_mediapi/0a8eed3371.vtt',
#  'test_clean_sent_mediapi/16f8f3e4f3.vtt',
#  'test_clean_sent_mediapi/3878bf6a4b.vtt',
#  'test_clean_sent_mediapi/dbe8fe3cd8.vtt',
#  'test_clean_sent_mediapi/b190a8fcf3.vtt',
#  'test_clean_sent_mediapi/91f7602dd7.vtt',
#  'test_clean_sent_mediapi/7eb31feb7b.vtt',
#  'test_clean_sent_mediapi/0d4eb20351.vtt',
#  'test_clean_sent_mediapi/08833bc0f6.vtt',
#  'test_clean_sent_mediapi/e704e87b4e.vtt',
#  'test_clean_sent_mediapi/27041103dd.vtt',
#  'test_clean_sent_mediapi/0470c7f913.vtt',
#  'test_clean_sent_mediapi/e5fbe410e6.vtt',
#  'test_clean_sent_mediapi/13e4e917e1.vtt',
#  'test_clean_sent_mediapi/0b4ce617de.vtt',
#  'test_clean_sent_mediapi/a6d38e5bdb.vtt',
#  'test_clean_sent_mediapi/e148dfeb65.vtt',
#  'test_clean_sent_mediapi/f2f7d8d5f8.vtt',
#  'test_clean_sent_mediapi/8df5d27beb.vtt',
#  'test_clean_sent_mediapi/6e8700e1ae.vtt',
#  'test_clean_sent_mediapi/1b820316ba.vtt',
#  'test_clean_sent_mediapi/b5cda239b9.vtt',
#  'test_clean_sent_mediapi/53460aff7b.vtt',
#  'test_clean_sent_mediapi/66c4c805b1.vtt',
#  'test_clean_sent_mediapi/43802ca36d.vtt',
#  'test_clean_sent_mediapi/6639a5e1cc.vtt',
#  'test_clean_sent_mediapi/f148c7a6e3.vtt',
#  'test_clean_sent_mediapi/9f1510e3bf.vtt',
#  'test_clean_sent_mediapi/02454a574c.vtt',
#  'test_clean_sent_mediapi/4a3cf6910c.vtt',
#  'test_clean_sent_mediapi/62b65369f4.vtt',
#  'test_clean_sent_mediapi/aae77ee509.vtt',
#  'test_clean_sent_mediapi/dd4a18210b.vtt',
#  'test_clean_sent_mediapi/94c8044c4d.vtt',
#  'test_clean_sent_mediapi/5e773ff027.vtt',
#  'test_clean_sent_mediapi/76ac6bd7eb.vtt',
#  'test_clean_sent_mediapi/de9aeb3d1c.vtt',
#  'test_clean_sent_mediapi/22219f1214.vtt',
#  'test_clean_sent_mediapi/a313560383.vtt',
#  'test_clean_sent_mediapi/980e043757.vtt',
#  'test_clean_sent_mediapi/0ecd091d66.vtt',
#  'test_clean_sent_mediapi/b12b5cb8d2.vtt',
#  'test_clean_sent_mediapi/c76bd2fa97.vtt',
#  'test_clean_sent_mediapi/303c2ebc1c.vtt',
#  'test_clean_sent_mediapi/1bf7ca7f7a.vtt',
#  'test_clean_sent_mediapi/080cef75a5.vtt',
#  'test_clean_sent_mediapi/28450633f3.vtt',
#  'test_clean_sent_mediapi/f1c5933e60.vtt',
#  'test_clean_sent_mediapi/0ddc51381c.vtt',
#  'test_clean_sent_mediapi/444eb064b8.vtt',
#  'test_clean_sent_mediapi/ce13093e98.vtt',
#  'test_clean_sent_mediapi/36d9b7f468.vtt',
#  'test_clean_sent_mediapi/2e4792ecf5.vtt',
#  'test_clean_sent_mediapi/2351782cb1.vtt',
#  'test_clean_sent_mediapi/971c724c90.vtt',
#  'test_clean_sent_mediapi/e554b40322.vtt',
#  'test_clean_sent_mediapi/871a2fa2a3.vtt',
#  'test_clean_sent_mediapi/b6d8438015.vtt',
#  'test_clean_sent_mediapi/516c601ede.vtt',
#  'test_clean_sent_mediapi/e1568c64a1.vtt',
#  'test_clean_sent_mediapi/a510e54dbf.vtt',
#  'test_clean_sent_mediapi/0a6241dd8c.vtt',
#  'test_clean_sent_mediapi/5463ff64ee.vtt',
#  'test_clean_sent_mediapi/3e015a14dd.vtt',
#  'test_clean_sent_mediapi/882604ad5f.vtt',
#  'test_clean_sent_mediapi/1e65785dc0.vtt',
#  'test_clean_sent_mediapi/4fde20cbae.vtt',
#  'test_clean_sent_mediapi/7c0156e7b3.vtt',
#  'test_clean_sent_mediapi/bd53cb1f5c.vtt',
#  'test_clean_sent_mediapi/87bcbad202.vtt',
#  'test_clean_sent_mediapi/e5046eb518.vtt',
#  'test_clean_sent_mediapi/c9188f102a.vtt',
#  'test_clean_sent_mediapi/86004d509b.vtt',
#  'test_clean_sent_mediapi/904eb89776.vtt',
#  'test_clean_sent_mediapi/7c8deafb0b.vtt',
#  'test_clean_sent_mediapi/3ff6d701ae.vtt',
#  'test_clean_sent_mediapi/fc45e23df6.vtt',
#  'test_clean_sent_mediapi/22bf8a6ef4.vtt',
#  'test_clean_sent_mediapi/50dc97f5f7.vtt',
#  'test_clean_sent_mediapi/cb962659c9.vtt',
#  'test_clean_sent_mediapi/d4edb99609.vtt',
#  'test_clean_sent_mediapi/e2e372253f.vtt',
#  'test_clean_sent_mediapi/e716109270.vtt',
#  'test_clean_sent_mediapi/97547b6486.vtt',
#  'test_clean_sent_mediapi/e27fcfc001.vtt',
#  'test_clean_sent_mediapi/67d76c2ebb.vtt',
#  'test_clean_sent_mediapi/27792377b0.vtt',
#  'test_clean_sent_mediapi/693fba67d5.vtt',
#  'test_clean_sent_mediapi/58aac62109.vtt',
#  'test_clean_sent_mediapi/9f0c335f6e.vtt',
#  'test_clean_sent_mediapi/ebe0f6eae0.vtt',
#  'test_clean_sent_mediapi/ad327ce1d4.vtt',
#  'test_clean_sent_mediapi/a3f25cb374.vtt',
#  'test_clean_sent_mediapi/df379c2a7f.vtt',
#  'test_clean_sent_mediapi/a8ce431845.vtt',
#  'test_clean_sent_mediapi/f7190538c0.vtt',
#  'test_clean_sent_mediapi/0f1dec5f45.vtt',
#  'test_clean_sent_mediapi/80f90d59ef.vtt',
#  'test_clean_sent_mediapi/9db791e8d6.vtt',
#  'test_clean_sent_mediapi/4625530392.vtt',
#  'test_clean_sent_mediapi/a1fd06e90a.vtt',
#  'test_clean_sent_mediapi/91f5041a73.vtt',
#  'test_clean_sent_mediapi/cfaa71738f.vtt',
#  'test_clean_sent_mediapi/2e04c8d141.vtt',
#  'test_clean_sent_mediapi/9d00a9404f.vtt',
#  'test_clean_sent_mediapi/763ff23db6.vtt',
#  'test_clean_sent_mediapi/87cbe14986.vtt',
#  'test_clean_sent_mediapi/35d0453ab7.vtt',
#  'test_clean_sent_mediapi/72728a4a6f.vtt',
#  'test_clean_sent_mediapi/053c8df6ce.vtt',
#  'test_clean_sent_mediapi/10603cbcf6.vtt',
#  'test_clean_sent_mediapi/50f92872ae.vtt',
#  'test_clean_sent_mediapi/a950829bf8.vtt',
#  'test_clean_sent_mediapi/9473529513.vtt',
#  'test_clean_sent_mediapi/49101cd1b2.vtt',
#  'test_clean_sent_mediapi/f5972347f4.vtt',
#  'test_clean_sent_mediapi/ef92a98157.vtt',
#  'test_clean_sent_mediapi/ddc83f4224.vtt',
#  'test_clean_sent_mediapi/25e056ece5.vtt',
#  'test_clean_sent_mediapi/4184d3d4df.vtt',
#  'test_clean_sent_mediapi/bfe1e71c08.vtt',
#  'test_clean_sent_mediapi/a15127e89b.vtt',
#  'test_clean_sent_mediapi/a2a69a013d.vtt',
#  'test_clean_sent_mediapi/bd62962446.vtt',
#  'test_clean_sent_mediapi/3f01669782.vtt',
#  'test_clean_sent_mediapi/ee0e21e91c.vtt',
#  'test_clean_sent_mediapi/924cacaba2.vtt',
#  'test_clean_sent_mediapi/2d4da5eb35.vtt',
#  'test_clean_sent_mediapi/4c2e89b00b.vtt',
#  'test_clean_sent_mediapi/f14107b372.vtt',
#  'test_clean_sent_mediapi/134f0719e2.vtt',
#  'test_clean_sent_mediapi/f5de80f176.vtt',
#  'test_clean_sent_mediapi/7ec9f59c86.vtt',
#  'test_clean_sent_mediapi/ec7d9c3ce3.vtt',
#  'test_clean_sent_mediapi/ba457b68ef.vtt',
#  'test_clean_sent_mediapi/37d9782273.vtt',
#  'test_clean_sent_mediapi/d62d4d6258.vtt',
#  'test_clean_sent_mediapi/6e6b0ab4c6.vtt',
#  'test_clean_sent_mediapi/348b16c789.vtt',
#  'test_clean_sent_mediapi/911e468394.vtt',
#  'test_clean_sent_mediapi/19017f7505.vtt',
#  'test_clean_sent_mediapi/de35ab9c5b.vtt',
#  'test_clean_sent_mediapi/f7a90779bc.vtt',
#  'test_clean_sent_mediapi/b74bbb42a9.vtt',
#  'test_clean_sent_mediapi/2a1adda19f.vtt',
#  'test_clean_sent_mediapi/85c2c056e6.vtt',
#  'test_clean_sent_mediapi/4138b5b69e.vtt',
#  'test_clean_sent_mediapi/f4ef94bd1f.vtt',
#  'test_clean_sent_mediapi/0dea50e738.vtt',
#  'test_clean_sent_mediapi/a5eb8162d1.vtt',
#  'test_clean_sent_mediapi/dda86a5da7.vtt',
#  'test_clean_sent_mediapi/fe057d9f9f.vtt',
#  'test_clean_sent_mediapi/0e3388eb36.vtt',
#  'test_clean_sent_mediapi/1fdc547be2.vtt',
#  'test_clean_sent_mediapi/daa31bf7c1.vtt',
#  'test_clean_sent_mediapi/d5cb8c430d.vtt',
#  'test_clean_sent_mediapi/0958edc330.vtt',
#  'test_clean_sent_mediapi/3adcab9aa3.vtt',
#  'test_clean_sent_mediapi/bcf3072975.vtt',
#  'test_clean_sent_mediapi/458db448ae.vtt',
#  'test_clean_sent_mediapi/80c28b903d.vtt',
#  ...]

# %%
def get_dict_vtt(input):
    with open(input,encoding="utf-8") as f:
        lines = f.readlines()

    dict_sub = {}
    i = 0
    j = 0  

    while j < len(lines): 
        element = lines[j]
        if element.startswith("00:") or element.startswith("01:") or element.startswith("02:"):
            # Extraire le temps de début et de fin
            timing_line = element.strip().split(' --> ')
            start_time, end_time = timing_line

            text = ""
            while j + 1 < len(lines) and not lines[j + 1].startswith("00:") and not lines[j+1].startswith("01:") and not lines[j+1].startswith("02:"):
                j += 1
                content = lines[j]
                text = text + " " + content.strip()

            dict_sub[i] = {'start': start_time, 'end': end_time, 'text': text.strip()}
            i += 1

        j += 1

    return dict_sub

# %%
ponctuations = {"!", ".", "?", "....", "...",'"',":"}

for file in files:
    with open(file, 'r', encoding="utf-8") as f:
        print(f"Traitement de {file}")
        ligne_precedente = ""
        liste_sent = f.readlines()
        if len(liste_sent) > 3:
            print(f"File long enough, traitement : {file} --- {len(liste_sent)}")
            i = 0
            txt = ""
            while i < len(liste_sent):
                if i < len(liste_sent) - 1:
                    if liste_sent[i + 1].strip() in ponctuations or liste_sent[i+1].startswith(","):
                        txt = txt + liste_sent[i].strip() + liste_sent[i + 1]
                        i = i + 2
                        var = True
                    else:
                        txt = txt + liste_sent[i]
                        i = i + 1
                        var = False
                else:
                    if var == False:
                        txt = txt + liste_sent[i]
                        i = i + 1
                    else:
                        i = i +1

            with open(file, "w", encoding="utf-8") as f:
                print(f"Ecriture du nouveau fichier {file}")
                f.write(txt)

            print(f"{file} done")
            i = 0
        else:
            print(f"not long enough : {file}")
# Out:
# Traitement de test_clean_sent_mediapi/b7f2d8f0c3.vtt
# not long enough : test_clean_sent_mediapi/b7f2d8f0c3.vtt
# Traitement de test_clean_sent_mediapi/3d0b82b459.vtt
# File long enough, traitement : test_clean_sent_mediapi/3d0b82b459.vtt --- 61
# Ecriture du nouveau fichier test_clean_sent_mediapi/3d0b82b459.vtt
# test_clean_sent_mediapi/3d0b82b459.vtt done
# Traitement de test_clean_sent_mediapi/44f554f914.vtt
# not long enough : test_clean_sent_mediapi/44f554f914.vtt
# Traitement de test_clean_sent_mediapi/b9a51f4361.vtt
# File long enough, traitement : test_clean_sent_mediapi/b9a51f4361.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/b9a51f4361.vtt
# test_clean_sent_mediapi/b9a51f4361.vtt done
# Traitement de test_clean_sent_mediapi/4e073949b1.vtt
# not long enough : test_clean_sent_mediapi/4e073949b1.vtt
# Traitement de test_clean_sent_mediapi/0b1437bc85.vtt
# not long enough : test_clean_sent_mediapi/0b1437bc85.vtt
# Traitement de test_clean_sent_mediapi/752500b761.vtt
# File long enough, traitement : test_clean_sent_mediapi/752500b761.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/752500b761.vtt
# test_clean_sent_mediapi/752500b761.vtt done
# Traitement de test_clean_sent_mediapi/cba6cefad2.vtt
# File long enough, traitement : test_clean_sent_mediapi/cba6cefad2.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/cba6cefad2.vtt
# test_clean_sent_mediapi/cba6cefad2.vtt done
# Traitement de test_clean_sent_mediapi/41c606553f.vtt
# File long enough, traitement : test_clean_sent_mediapi/41c606553f.vtt --- 23
# Ecriture du nouveau fichier test_clean_sent_mediapi/41c606553f.vtt
# test_clean_sent_mediapi/41c606553f.vtt done
# Traitement de test_clean_sent_mediapi/3f1b2118ca.vtt
# File long enough, traitement : test_clean_sent_mediapi/3f1b2118ca.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/3f1b2118ca.vtt
# test_clean_sent_mediapi/3f1b2118ca.vtt done
# Traitement de test_clean_sent_mediapi/ed969c3e70.vtt
# File long enough, traitement : test_clean_sent_mediapi/ed969c3e70.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/ed969c3e70.vtt
# test_clean_sent_mediapi/ed969c3e70.vtt done
# Traitement de test_clean_sent_mediapi/26f1ff8385.vtt
# not long enough : test_clean_sent_mediapi/26f1ff8385.vtt
# Traitement de test_clean_sent_mediapi/2b4b33189c.vtt
# File long enough, traitement : test_clean_sent_mediapi/2b4b33189c.vtt --- 60
# Ecriture du nouveau fichier test_clean_sent_mediapi/2b4b33189c.vtt
# test_clean_sent_mediapi/2b4b33189c.vtt done
# Traitement de test_clean_sent_mediapi/ada7d10a19.vtt
# File long enough, traitement : test_clean_sent_mediapi/ada7d10a19.vtt --- 22
# Ecriture du nouveau fichier test_clean_sent_mediapi/ada7d10a19.vtt
# test_clean_sent_mediapi/ada7d10a19.vtt done
# Traitement de test_clean_sent_mediapi/fd41a24117.vtt
# File long enough, traitement : test_clean_sent_mediapi/fd41a24117.vtt --- 146
# Ecriture du nouveau fichier test_clean_sent_mediapi/fd41a24117.vtt
# test_clean_sent_mediapi/fd41a24117.vtt done
# Traitement de test_clean_sent_mediapi/15abfc95ae.vtt
# File long enough, traitement : test_clean_sent_mediapi/15abfc95ae.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/15abfc95ae.vtt
# test_clean_sent_mediapi/15abfc95ae.vtt done
# Traitement de test_clean_sent_mediapi/495145911e.vtt
# File long enough, traitement : test_clean_sent_mediapi/495145911e.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/495145911e.vtt
# test_clean_sent_mediapi/495145911e.vtt done
# Traitement de test_clean_sent_mediapi/5ef5fa319a.vtt
# File long enough, traitement : test_clean_sent_mediapi/5ef5fa319a.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/5ef5fa319a.vtt
# test_clean_sent_mediapi/5ef5fa319a.vtt done
# Traitement de test_clean_sent_mediapi/0fd91cb814.vtt
# File long enough, traitement : test_clean_sent_mediapi/0fd91cb814.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/0fd91cb814.vtt
# test_clean_sent_mediapi/0fd91cb814.vtt done
# Traitement de test_clean_sent_mediapi/9a58b08185.vtt
# File long enough, traitement : test_clean_sent_mediapi/9a58b08185.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/9a58b08185.vtt
# test_clean_sent_mediapi/9a58b08185.vtt done
# Traitement de test_clean_sent_mediapi/ac6160b61a.vtt
# not long enough : test_clean_sent_mediapi/ac6160b61a.vtt
# Traitement de test_clean_sent_mediapi/74bb642e72.vtt
# File long enough, traitement : test_clean_sent_mediapi/74bb642e72.vtt --- 64
# Ecriture du nouveau fichier test_clean_sent_mediapi/74bb642e72.vtt
# test_clean_sent_mediapi/74bb642e72.vtt done
# Traitement de test_clean_sent_mediapi/17217ca54b.vtt
# File long enough, traitement : test_clean_sent_mediapi/17217ca54b.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/17217ca54b.vtt
# test_clean_sent_mediapi/17217ca54b.vtt done
# Traitement de test_clean_sent_mediapi/928499b438.vtt
# not long enough : test_clean_sent_mediapi/928499b438.vtt
# Traitement de test_clean_sent_mediapi/8036e9b4bc.vtt
# File long enough, traitement : test_clean_sent_mediapi/8036e9b4bc.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/8036e9b4bc.vtt
# test_clean_sent_mediapi/8036e9b4bc.vtt done
# Traitement de test_clean_sent_mediapi/5dfad26566.vtt
# File long enough, traitement : test_clean_sent_mediapi/5dfad26566.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/5dfad26566.vtt
# test_clean_sent_mediapi/5dfad26566.vtt done
# Traitement de test_clean_sent_mediapi/71e94f545f.vtt
# File long enough, traitement : test_clean_sent_mediapi/71e94f545f.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/71e94f545f.vtt
# test_clean_sent_mediapi/71e94f545f.vtt done
# Traitement de test_clean_sent_mediapi/008420cac0.vtt
# File long enough, traitement : test_clean_sent_mediapi/008420cac0.vtt --- 17
# Ecriture du nouveau fichier test_clean_sent_mediapi/008420cac0.vtt
# test_clean_sent_mediapi/008420cac0.vtt done
# Traitement de test_clean_sent_mediapi/689abe06d3.vtt
# File long enough, traitement : test_clean_sent_mediapi/689abe06d3.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/689abe06d3.vtt
# test_clean_sent_mediapi/689abe06d3.vtt done
# Traitement de test_clean_sent_mediapi/870fcc2c39.vtt
# not long enough : test_clean_sent_mediapi/870fcc2c39.vtt
# Traitement de test_clean_sent_mediapi/575f99a4af.vtt
# File long enough, traitement : test_clean_sent_mediapi/575f99a4af.vtt --- 121
# Ecriture du nouveau fichier test_clean_sent_mediapi/575f99a4af.vtt
# test_clean_sent_mediapi/575f99a4af.vtt done
# Traitement de test_clean_sent_mediapi/5813b21ceb.vtt
# File long enough, traitement : test_clean_sent_mediapi/5813b21ceb.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/5813b21ceb.vtt
# test_clean_sent_mediapi/5813b21ceb.vtt done
# Traitement de test_clean_sent_mediapi/6e72821691.vtt
# File long enough, traitement : test_clean_sent_mediapi/6e72821691.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/6e72821691.vtt
# test_clean_sent_mediapi/6e72821691.vtt done
# Traitement de test_clean_sent_mediapi/cee1643fd7.vtt
# not long enough : test_clean_sent_mediapi/cee1643fd7.vtt
# Traitement de test_clean_sent_mediapi/88fb28815b.vtt
# not long enough : test_clean_sent_mediapi/88fb28815b.vtt
# Traitement de test_clean_sent_mediapi/a710e36c40.vtt
# File long enough, traitement : test_clean_sent_mediapi/a710e36c40.vtt --- 33
# Ecriture du nouveau fichier test_clean_sent_mediapi/a710e36c40.vtt
# test_clean_sent_mediapi/a710e36c40.vtt done
# Traitement de test_clean_sent_mediapi/31201b65bf.vtt
# not long enough : test_clean_sent_mediapi/31201b65bf.vtt
# Traitement de test_clean_sent_mediapi/72aeba358a.vtt
# not long enough : test_clean_sent_mediapi/72aeba358a.vtt
# Traitement de test_clean_sent_mediapi/1dd7333d1b.vtt
# not long enough : test_clean_sent_mediapi/1dd7333d1b.vtt
# Traitement de test_clean_sent_mediapi/a6a8d92675.vtt
# not long enough : test_clean_sent_mediapi/a6a8d92675.vtt
# Traitement de test_clean_sent_mediapi/bdc14ece6e.vtt
# File long enough, traitement : test_clean_sent_mediapi/bdc14ece6e.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/bdc14ece6e.vtt
# test_clean_sent_mediapi/bdc14ece6e.vtt done
# Traitement de test_clean_sent_mediapi/d9730fe376.vtt
# File long enough, traitement : test_clean_sent_mediapi/d9730fe376.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/d9730fe376.vtt
# test_clean_sent_mediapi/d9730fe376.vtt done
# Traitement de test_clean_sent_mediapi/142a8e3b5d.vtt
# File long enough, traitement : test_clean_sent_mediapi/142a8e3b5d.vtt --- 26
# Ecriture du nouveau fichier test_clean_sent_mediapi/142a8e3b5d.vtt
# test_clean_sent_mediapi/142a8e3b5d.vtt done
# Traitement de test_clean_sent_mediapi/383f2888b6.vtt
# not long enough : test_clean_sent_mediapi/383f2888b6.vtt
# Traitement de test_clean_sent_mediapi/b72ca1fa4f.vtt
# File long enough, traitement : test_clean_sent_mediapi/b72ca1fa4f.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/b72ca1fa4f.vtt
# test_clean_sent_mediapi/b72ca1fa4f.vtt done
# Traitement de test_clean_sent_mediapi/3adc6931bf.vtt
# File long enough, traitement : test_clean_sent_mediapi/3adc6931bf.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/3adc6931bf.vtt
# test_clean_sent_mediapi/3adc6931bf.vtt done
# Traitement de test_clean_sent_mediapi/7a7a8be63d.vtt
# File long enough, traitement : test_clean_sent_mediapi/7a7a8be63d.vtt --- 65
# Ecriture du nouveau fichier test_clean_sent_mediapi/7a7a8be63d.vtt
# test_clean_sent_mediapi/7a7a8be63d.vtt done
# Traitement de test_clean_sent_mediapi/8da1b28015.vtt
# File long enough, traitement : test_clean_sent_mediapi/8da1b28015.vtt --- 49
# Ecriture du nouveau fichier test_clean_sent_mediapi/8da1b28015.vtt
# test_clean_sent_mediapi/8da1b28015.vtt done
# Traitement de test_clean_sent_mediapi/b6c03b60b7.vtt
# File long enough, traitement : test_clean_sent_mediapi/b6c03b60b7.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/b6c03b60b7.vtt
# test_clean_sent_mediapi/b6c03b60b7.vtt done
# Traitement de test_clean_sent_mediapi/e3edfd09b6.vtt
# not long enough : test_clean_sent_mediapi/e3edfd09b6.vtt
# Traitement de test_clean_sent_mediapi/3013321813.vtt
# not long enough : test_clean_sent_mediapi/3013321813.vtt
# Traitement de test_clean_sent_mediapi/88d76860dd.vtt
# not long enough : test_clean_sent_mediapi/88d76860dd.vtt
# Traitement de test_clean_sent_mediapi/f49546dd7d.vtt
# not long enough : test_clean_sent_mediapi/f49546dd7d.vtt
# Traitement de test_clean_sent_mediapi/34210d5c72.vtt
# File long enough, traitement : test_clean_sent_mediapi/34210d5c72.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/34210d5c72.vtt
# test_clean_sent_mediapi/34210d5c72.vtt done
# Traitement de test_clean_sent_mediapi/099c404cc1.vtt
# File long enough, traitement : test_clean_sent_mediapi/099c404cc1.vtt --- 35
# Ecriture du nouveau fichier test_clean_sent_mediapi/099c404cc1.vtt
# test_clean_sent_mediapi/099c404cc1.vtt done
# Traitement de test_clean_sent_mediapi/bfcd06419a.vtt
# File long enough, traitement : test_clean_sent_mediapi/bfcd06419a.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/bfcd06419a.vtt
# test_clean_sent_mediapi/bfcd06419a.vtt done
# Traitement de test_clean_sent_mediapi/f978fa2dea.vtt
# not long enough : test_clean_sent_mediapi/f978fa2dea.vtt
# Traitement de test_clean_sent_mediapi/4151b008b6.vtt
# File long enough, traitement : test_clean_sent_mediapi/4151b008b6.vtt --- 55
# Ecriture du nouveau fichier test_clean_sent_mediapi/4151b008b6.vtt
# test_clean_sent_mediapi/4151b008b6.vtt done
# Traitement de test_clean_sent_mediapi/bc3726d559.vtt
# File long enough, traitement : test_clean_sent_mediapi/bc3726d559.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/bc3726d559.vtt
# test_clean_sent_mediapi/bc3726d559.vtt done
# Traitement de test_clean_sent_mediapi/6706655430.vtt
# not long enough : test_clean_sent_mediapi/6706655430.vtt
# Traitement de test_clean_sent_mediapi/2b38719c3e.vtt
# File long enough, traitement : test_clean_sent_mediapi/2b38719c3e.vtt --- 30
# Ecriture du nouveau fichier test_clean_sent_mediapi/2b38719c3e.vtt
# test_clean_sent_mediapi/2b38719c3e.vtt done
# Traitement de test_clean_sent_mediapi/a0ec06d1d3.vtt
# File long enough, traitement : test_clean_sent_mediapi/a0ec06d1d3.vtt --- 46
# Ecriture du nouveau fichier test_clean_sent_mediapi/a0ec06d1d3.vtt
# test_clean_sent_mediapi/a0ec06d1d3.vtt done
# Traitement de test_clean_sent_mediapi/29a437b7e7.vtt
# File long enough, traitement : test_clean_sent_mediapi/29a437b7e7.vtt --- 60
# Ecriture du nouveau fichier test_clean_sent_mediapi/29a437b7e7.vtt
# test_clean_sent_mediapi/29a437b7e7.vtt done
# Traitement de test_clean_sent_mediapi/c90bbbf71e.vtt
# File long enough, traitement : test_clean_sent_mediapi/c90bbbf71e.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/c90bbbf71e.vtt
# test_clean_sent_mediapi/c90bbbf71e.vtt done
# Traitement de test_clean_sent_mediapi/a6de2b7652.vtt
# File long enough, traitement : test_clean_sent_mediapi/a6de2b7652.vtt --- 47
# Ecriture du nouveau fichier test_clean_sent_mediapi/a6de2b7652.vtt
# test_clean_sent_mediapi/a6de2b7652.vtt done
# Traitement de test_clean_sent_mediapi/38e41f547d.vtt
# File long enough, traitement : test_clean_sent_mediapi/38e41f547d.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/38e41f547d.vtt
# test_clean_sent_mediapi/38e41f547d.vtt done
# Traitement de test_clean_sent_mediapi/13a80ac2d1.vtt
# File long enough, traitement : test_clean_sent_mediapi/13a80ac2d1.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/13a80ac2d1.vtt
# test_clean_sent_mediapi/13a80ac2d1.vtt done
# Traitement de test_clean_sent_mediapi/ad79e17356.vtt
# File long enough, traitement : test_clean_sent_mediapi/ad79e17356.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/ad79e17356.vtt
# test_clean_sent_mediapi/ad79e17356.vtt done
# Traitement de test_clean_sent_mediapi/b28f6ce507.vtt
# File long enough, traitement : test_clean_sent_mediapi/b28f6ce507.vtt --- 59
# Ecriture du nouveau fichier test_clean_sent_mediapi/b28f6ce507.vtt
# test_clean_sent_mediapi/b28f6ce507.vtt done
# Traitement de test_clean_sent_mediapi/6cf26927ca.vtt
# File long enough, traitement : test_clean_sent_mediapi/6cf26927ca.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/6cf26927ca.vtt
# test_clean_sent_mediapi/6cf26927ca.vtt done
# Traitement de test_clean_sent_mediapi/c3258a13e3.vtt
# File long enough, traitement : test_clean_sent_mediapi/c3258a13e3.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/c3258a13e3.vtt
# test_clean_sent_mediapi/c3258a13e3.vtt done
# Traitement de test_clean_sent_mediapi/1992ebbd09.vtt
# File long enough, traitement : test_clean_sent_mediapi/1992ebbd09.vtt --- 103
# Ecriture du nouveau fichier test_clean_sent_mediapi/1992ebbd09.vtt
# test_clean_sent_mediapi/1992ebbd09.vtt done
# Traitement de test_clean_sent_mediapi/d92e970202.vtt
# File long enough, traitement : test_clean_sent_mediapi/d92e970202.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/d92e970202.vtt
# test_clean_sent_mediapi/d92e970202.vtt done
# Traitement de test_clean_sent_mediapi/dcd9053975.vtt
# File long enough, traitement : test_clean_sent_mediapi/dcd9053975.vtt --- 37
# Ecriture du nouveau fichier test_clean_sent_mediapi/dcd9053975.vtt
# test_clean_sent_mediapi/dcd9053975.vtt done
# Traitement de test_clean_sent_mediapi/4e92363ed6.vtt
# File long enough, traitement : test_clean_sent_mediapi/4e92363ed6.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/4e92363ed6.vtt
# test_clean_sent_mediapi/4e92363ed6.vtt done
# Traitement de test_clean_sent_mediapi/80d22962f8.vtt
# File long enough, traitement : test_clean_sent_mediapi/80d22962f8.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/80d22962f8.vtt
# test_clean_sent_mediapi/80d22962f8.vtt done
# Traitement de test_clean_sent_mediapi/0eb1494855.vtt
# not long enough : test_clean_sent_mediapi/0eb1494855.vtt
# Traitement de test_clean_sent_mediapi/a8d35c1600.vtt
# File long enough, traitement : test_clean_sent_mediapi/a8d35c1600.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/a8d35c1600.vtt
# test_clean_sent_mediapi/a8d35c1600.vtt done
# Traitement de test_clean_sent_mediapi/608fc0be13.vtt
# File long enough, traitement : test_clean_sent_mediapi/608fc0be13.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/608fc0be13.vtt
# test_clean_sent_mediapi/608fc0be13.vtt done
# Traitement de test_clean_sent_mediapi/c11e5da161.vtt
# File long enough, traitement : test_clean_sent_mediapi/c11e5da161.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/c11e5da161.vtt
# test_clean_sent_mediapi/c11e5da161.vtt done
# Traitement de test_clean_sent_mediapi/4b51501587.vtt
# File long enough, traitement : test_clean_sent_mediapi/4b51501587.vtt --- 29
# Ecriture du nouveau fichier test_clean_sent_mediapi/4b51501587.vtt
# test_clean_sent_mediapi/4b51501587.vtt done
# Traitement de test_clean_sent_mediapi/0bfab1c3b4.vtt
# File long enough, traitement : test_clean_sent_mediapi/0bfab1c3b4.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/0bfab1c3b4.vtt
# test_clean_sent_mediapi/0bfab1c3b4.vtt done
# Traitement de test_clean_sent_mediapi/12b9062560.vtt
# not long enough : test_clean_sent_mediapi/12b9062560.vtt
# Traitement de test_clean_sent_mediapi/eb7811a094.vtt
# not long enough : test_clean_sent_mediapi/eb7811a094.vtt
# Traitement de test_clean_sent_mediapi/491aadc1cf.vtt
# File long enough, traitement : test_clean_sent_mediapi/491aadc1cf.vtt --- 31
# Ecriture du nouveau fichier test_clean_sent_mediapi/491aadc1cf.vtt
# test_clean_sent_mediapi/491aadc1cf.vtt done
# Traitement de test_clean_sent_mediapi/eea98dceef.vtt
# File long enough, traitement : test_clean_sent_mediapi/eea98dceef.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/eea98dceef.vtt
# test_clean_sent_mediapi/eea98dceef.vtt done
# Traitement de test_clean_sent_mediapi/11b9db4892.vtt
# not long enough : test_clean_sent_mediapi/11b9db4892.vtt
# Traitement de test_clean_sent_mediapi/9f59e3b226.vtt
# not long enough : test_clean_sent_mediapi/9f59e3b226.vtt
# Traitement de test_clean_sent_mediapi/82ee104b19.vtt
# File long enough, traitement : test_clean_sent_mediapi/82ee104b19.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/82ee104b19.vtt
# test_clean_sent_mediapi/82ee104b19.vtt done
# Traitement de test_clean_sent_mediapi/14a49c07ef.vtt
# File long enough, traitement : test_clean_sent_mediapi/14a49c07ef.vtt --- 92
# Ecriture du nouveau fichier test_clean_sent_mediapi/14a49c07ef.vtt
# test_clean_sent_mediapi/14a49c07ef.vtt done
# Traitement de test_clean_sent_mediapi/7631f48964.vtt
# File long enough, traitement : test_clean_sent_mediapi/7631f48964.vtt --- 68
# Ecriture du nouveau fichier test_clean_sent_mediapi/7631f48964.vtt
# test_clean_sent_mediapi/7631f48964.vtt done
# Traitement de test_clean_sent_mediapi/e597c8cd01.vtt
# File long enough, traitement : test_clean_sent_mediapi/e597c8cd01.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/e597c8cd01.vtt
# test_clean_sent_mediapi/e597c8cd01.vtt done
# Traitement de test_clean_sent_mediapi/fad6c87636.vtt
# File long enough, traitement : test_clean_sent_mediapi/fad6c87636.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/fad6c87636.vtt
# test_clean_sent_mediapi/fad6c87636.vtt done
# Traitement de test_clean_sent_mediapi/d3a84a8ccd.vtt
# not long enough : test_clean_sent_mediapi/d3a84a8ccd.vtt
# Traitement de test_clean_sent_mediapi/e1f484b5f8.vtt
# File long enough, traitement : test_clean_sent_mediapi/e1f484b5f8.vtt --- 64
# Ecriture du nouveau fichier test_clean_sent_mediapi/e1f484b5f8.vtt
# test_clean_sent_mediapi/e1f484b5f8.vtt done
# Traitement de test_clean_sent_mediapi/ac9ff299f9.vtt
# not long enough : test_clean_sent_mediapi/ac9ff299f9.vtt
# Traitement de test_clean_sent_mediapi/1371e28e24.vtt
# File long enough, traitement : test_clean_sent_mediapi/1371e28e24.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/1371e28e24.vtt
# test_clean_sent_mediapi/1371e28e24.vtt done
# Traitement de test_clean_sent_mediapi/dd977a1f2a.vtt
# File long enough, traitement : test_clean_sent_mediapi/dd977a1f2a.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/dd977a1f2a.vtt
# test_clean_sent_mediapi/dd977a1f2a.vtt done
# Traitement de test_clean_sent_mediapi/2a6ad1a50a.vtt
# File long enough, traitement : test_clean_sent_mediapi/2a6ad1a50a.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/2a6ad1a50a.vtt
# test_clean_sent_mediapi/2a6ad1a50a.vtt done
# Traitement de test_clean_sent_mediapi/1ff266482c.vtt
# File long enough, traitement : test_clean_sent_mediapi/1ff266482c.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/1ff266482c.vtt
# test_clean_sent_mediapi/1ff266482c.vtt done
# Traitement de test_clean_sent_mediapi/2a59b007d4.vtt
# File long enough, traitement : test_clean_sent_mediapi/2a59b007d4.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/2a59b007d4.vtt
# test_clean_sent_mediapi/2a59b007d4.vtt done
# Traitement de test_clean_sent_mediapi/7093118618.vtt
# not long enough : test_clean_sent_mediapi/7093118618.vtt
# Traitement de test_clean_sent_mediapi/6648393ad0.vtt
# File long enough, traitement : test_clean_sent_mediapi/6648393ad0.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/6648393ad0.vtt
# test_clean_sent_mediapi/6648393ad0.vtt done
# Traitement de test_clean_sent_mediapi/042af81098.vtt
# not long enough : test_clean_sent_mediapi/042af81098.vtt
# Traitement de test_clean_sent_mediapi/8c26149486.vtt
# File long enough, traitement : test_clean_sent_mediapi/8c26149486.vtt --- 40
# Ecriture du nouveau fichier test_clean_sent_mediapi/8c26149486.vtt
# test_clean_sent_mediapi/8c26149486.vtt done
# Traitement de test_clean_sent_mediapi/ef4b03eab2.vtt
# File long enough, traitement : test_clean_sent_mediapi/ef4b03eab2.vtt --- 79
# Ecriture du nouveau fichier test_clean_sent_mediapi/ef4b03eab2.vtt
# test_clean_sent_mediapi/ef4b03eab2.vtt done
# Traitement de test_clean_sent_mediapi/826afd29f8.vtt
# File long enough, traitement : test_clean_sent_mediapi/826afd29f8.vtt --- 87
# Ecriture du nouveau fichier test_clean_sent_mediapi/826afd29f8.vtt
# test_clean_sent_mediapi/826afd29f8.vtt done
# Traitement de test_clean_sent_mediapi/040fde163f.vtt
# File long enough, traitement : test_clean_sent_mediapi/040fde163f.vtt --- 26
# Ecriture du nouveau fichier test_clean_sent_mediapi/040fde163f.vtt
# test_clean_sent_mediapi/040fde163f.vtt done
# Traitement de test_clean_sent_mediapi/4cc54e86f5.vtt
# File long enough, traitement : test_clean_sent_mediapi/4cc54e86f5.vtt --- 51
# Ecriture du nouveau fichier test_clean_sent_mediapi/4cc54e86f5.vtt
# test_clean_sent_mediapi/4cc54e86f5.vtt done
# Traitement de test_clean_sent_mediapi/2fee0f7592.vtt
# File long enough, traitement : test_clean_sent_mediapi/2fee0f7592.vtt --- 88
# Ecriture du nouveau fichier test_clean_sent_mediapi/2fee0f7592.vtt
# test_clean_sent_mediapi/2fee0f7592.vtt done
# Traitement de test_clean_sent_mediapi/9e5e128447.vtt
# not long enough : test_clean_sent_mediapi/9e5e128447.vtt
# Traitement de test_clean_sent_mediapi/c407147f2f.vtt
# not long enough : test_clean_sent_mediapi/c407147f2f.vtt
# Traitement de test_clean_sent_mediapi/8d58d72944.vtt
# File long enough, traitement : test_clean_sent_mediapi/8d58d72944.vtt --- 110
# Ecriture du nouveau fichier test_clean_sent_mediapi/8d58d72944.vtt
# test_clean_sent_mediapi/8d58d72944.vtt done
# Traitement de test_clean_sent_mediapi/05211c15bf.vtt
# File long enough, traitement : test_clean_sent_mediapi/05211c15bf.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/05211c15bf.vtt
# test_clean_sent_mediapi/05211c15bf.vtt done
# Traitement de test_clean_sent_mediapi/5351d97f20.vtt
# not long enough : test_clean_sent_mediapi/5351d97f20.vtt
# Traitement de test_clean_sent_mediapi/d1636da393.vtt
# File long enough, traitement : test_clean_sent_mediapi/d1636da393.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/d1636da393.vtt
# test_clean_sent_mediapi/d1636da393.vtt done
# Traitement de test_clean_sent_mediapi/28420f7cbe.vtt
# File long enough, traitement : test_clean_sent_mediapi/28420f7cbe.vtt --- 82
# Ecriture du nouveau fichier test_clean_sent_mediapi/28420f7cbe.vtt
# test_clean_sent_mediapi/28420f7cbe.vtt done
# Traitement de test_clean_sent_mediapi/e21f0e23a7.vtt
# File long enough, traitement : test_clean_sent_mediapi/e21f0e23a7.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/e21f0e23a7.vtt
# test_clean_sent_mediapi/e21f0e23a7.vtt done
# Traitement de test_clean_sent_mediapi/a588a2cf33.vtt
# File long enough, traitement : test_clean_sent_mediapi/a588a2cf33.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/a588a2cf33.vtt
# test_clean_sent_mediapi/a588a2cf33.vtt done
# Traitement de test_clean_sent_mediapi/33c47d59d2.vtt
# File long enough, traitement : test_clean_sent_mediapi/33c47d59d2.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/33c47d59d2.vtt
# test_clean_sent_mediapi/33c47d59d2.vtt done
# Traitement de test_clean_sent_mediapi/8a6b2fb0ce.vtt
# File long enough, traitement : test_clean_sent_mediapi/8a6b2fb0ce.vtt --- 27
# Ecriture du nouveau fichier test_clean_sent_mediapi/8a6b2fb0ce.vtt
# test_clean_sent_mediapi/8a6b2fb0ce.vtt done
# Traitement de test_clean_sent_mediapi/1cb5e71134.vtt
# File long enough, traitement : test_clean_sent_mediapi/1cb5e71134.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/1cb5e71134.vtt
# test_clean_sent_mediapi/1cb5e71134.vtt done
# Traitement de test_clean_sent_mediapi/b07ede0159.vtt
# File long enough, traitement : test_clean_sent_mediapi/b07ede0159.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/b07ede0159.vtt
# test_clean_sent_mediapi/b07ede0159.vtt done
# Traitement de test_clean_sent_mediapi/6c7ce53264.vtt
# File long enough, traitement : test_clean_sent_mediapi/6c7ce53264.vtt --- 88
# Ecriture du nouveau fichier test_clean_sent_mediapi/6c7ce53264.vtt
# test_clean_sent_mediapi/6c7ce53264.vtt done
# Traitement de test_clean_sent_mediapi/d2de84864b.vtt
# File long enough, traitement : test_clean_sent_mediapi/d2de84864b.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/d2de84864b.vtt
# test_clean_sent_mediapi/d2de84864b.vtt done
# Traitement de test_clean_sent_mediapi/9498b85b5b.vtt
# not long enough : test_clean_sent_mediapi/9498b85b5b.vtt
# Traitement de test_clean_sent_mediapi/13d32c0f21.vtt
# File long enough, traitement : test_clean_sent_mediapi/13d32c0f21.vtt --- 66
# Ecriture du nouveau fichier test_clean_sent_mediapi/13d32c0f21.vtt
# test_clean_sent_mediapi/13d32c0f21.vtt done
# Traitement de test_clean_sent_mediapi/e95f4949ed.vtt
# not long enough : test_clean_sent_mediapi/e95f4949ed.vtt
# Traitement de test_clean_sent_mediapi/de31ed9096.vtt
# File long enough, traitement : test_clean_sent_mediapi/de31ed9096.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/de31ed9096.vtt
# test_clean_sent_mediapi/de31ed9096.vtt done
# Traitement de test_clean_sent_mediapi/ba24810c74.vtt
# File long enough, traitement : test_clean_sent_mediapi/ba24810c74.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/ba24810c74.vtt
# test_clean_sent_mediapi/ba24810c74.vtt done
# Traitement de test_clean_sent_mediapi/458237489a.vtt
# File long enough, traitement : test_clean_sent_mediapi/458237489a.vtt --- 17
# Ecriture du nouveau fichier test_clean_sent_mediapi/458237489a.vtt
# test_clean_sent_mediapi/458237489a.vtt done
# Traitement de test_clean_sent_mediapi/a1c9365f5d.vtt
# File long enough, traitement : test_clean_sent_mediapi/a1c9365f5d.vtt --- 70
# Ecriture du nouveau fichier test_clean_sent_mediapi/a1c9365f5d.vtt
# test_clean_sent_mediapi/a1c9365f5d.vtt done
# Traitement de test_clean_sent_mediapi/5f10aa9293.vtt
# File long enough, traitement : test_clean_sent_mediapi/5f10aa9293.vtt --- 89
# Ecriture du nouveau fichier test_clean_sent_mediapi/5f10aa9293.vtt
# test_clean_sent_mediapi/5f10aa9293.vtt done
# Traitement de test_clean_sent_mediapi/5e678b4eb7.vtt
# not long enough : test_clean_sent_mediapi/5e678b4eb7.vtt
# Traitement de test_clean_sent_mediapi/17e4f7380a.vtt
# not long enough : test_clean_sent_mediapi/17e4f7380a.vtt
# Traitement de test_clean_sent_mediapi/207c2f7171.vtt
# File long enough, traitement : test_clean_sent_mediapi/207c2f7171.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/207c2f7171.vtt
# test_clean_sent_mediapi/207c2f7171.vtt done
# Traitement de test_clean_sent_mediapi/f981fbe6af.vtt
# not long enough : test_clean_sent_mediapi/f981fbe6af.vtt
# Traitement de test_clean_sent_mediapi/2af7497055.vtt
# File long enough, traitement : test_clean_sent_mediapi/2af7497055.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/2af7497055.vtt
# test_clean_sent_mediapi/2af7497055.vtt done
# Traitement de test_clean_sent_mediapi/1bf9bf7cec.vtt
# File long enough, traitement : test_clean_sent_mediapi/1bf9bf7cec.vtt --- 21
# Ecriture du nouveau fichier test_clean_sent_mediapi/1bf9bf7cec.vtt
# test_clean_sent_mediapi/1bf9bf7cec.vtt done
# Traitement de test_clean_sent_mediapi/9ae39abf0b.vtt
# File long enough, traitement : test_clean_sent_mediapi/9ae39abf0b.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/9ae39abf0b.vtt
# test_clean_sent_mediapi/9ae39abf0b.vtt done
# Traitement de test_clean_sent_mediapi/5481e47a19.vtt
# not long enough : test_clean_sent_mediapi/5481e47a19.vtt
# Traitement de test_clean_sent_mediapi/a4064555c2.vtt
# File long enough, traitement : test_clean_sent_mediapi/a4064555c2.vtt --- 76
# Ecriture du nouveau fichier test_clean_sent_mediapi/a4064555c2.vtt
# test_clean_sent_mediapi/a4064555c2.vtt done
# Traitement de test_clean_sent_mediapi/14cf31e15f.vtt
# File long enough, traitement : test_clean_sent_mediapi/14cf31e15f.vtt --- 72
# Ecriture du nouveau fichier test_clean_sent_mediapi/14cf31e15f.vtt
# test_clean_sent_mediapi/14cf31e15f.vtt done
# Traitement de test_clean_sent_mediapi/09c5b8a52b.vtt
# not long enough : test_clean_sent_mediapi/09c5b8a52b.vtt
# Traitement de test_clean_sent_mediapi/1926b5a3cd.vtt
# File long enough, traitement : test_clean_sent_mediapi/1926b5a3cd.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/1926b5a3cd.vtt
# test_clean_sent_mediapi/1926b5a3cd.vtt done
# Traitement de test_clean_sent_mediapi/3010fa2532.vtt
# File long enough, traitement : test_clean_sent_mediapi/3010fa2532.vtt --- 63
# Ecriture du nouveau fichier test_clean_sent_mediapi/3010fa2532.vtt
# test_clean_sent_mediapi/3010fa2532.vtt done
# Traitement de test_clean_sent_mediapi/5edd365f55.vtt
# File long enough, traitement : test_clean_sent_mediapi/5edd365f55.vtt --- 47
# Ecriture du nouveau fichier test_clean_sent_mediapi/5edd365f55.vtt
# test_clean_sent_mediapi/5edd365f55.vtt done
# Traitement de test_clean_sent_mediapi/ad86de5a8c.vtt
# File long enough, traitement : test_clean_sent_mediapi/ad86de5a8c.vtt --- 54
# Ecriture du nouveau fichier test_clean_sent_mediapi/ad86de5a8c.vtt
# test_clean_sent_mediapi/ad86de5a8c.vtt done
# Traitement de test_clean_sent_mediapi/457a01b248.vtt
# File long enough, traitement : test_clean_sent_mediapi/457a01b248.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/457a01b248.vtt
# test_clean_sent_mediapi/457a01b248.vtt done
# Traitement de test_clean_sent_mediapi/110092623c.vtt
# File long enough, traitement : test_clean_sent_mediapi/110092623c.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/110092623c.vtt
# test_clean_sent_mediapi/110092623c.vtt done
# Traitement de test_clean_sent_mediapi/3879c2ece5.vtt
# not long enough : test_clean_sent_mediapi/3879c2ece5.vtt
# Traitement de test_clean_sent_mediapi/e408818334.vtt
# File long enough, traitement : test_clean_sent_mediapi/e408818334.vtt --- 19
# Ecriture du nouveau fichier test_clean_sent_mediapi/e408818334.vtt
# test_clean_sent_mediapi/e408818334.vtt done
# Traitement de test_clean_sent_mediapi/163b0c88eb.vtt
# File long enough, traitement : test_clean_sent_mediapi/163b0c88eb.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/163b0c88eb.vtt
# test_clean_sent_mediapi/163b0c88eb.vtt done
# Traitement de test_clean_sent_mediapi/252c04af8c.vtt
# File long enough, traitement : test_clean_sent_mediapi/252c04af8c.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/252c04af8c.vtt
# test_clean_sent_mediapi/252c04af8c.vtt done
# Traitement de test_clean_sent_mediapi/48be2d5494.vtt
# File long enough, traitement : test_clean_sent_mediapi/48be2d5494.vtt --- 70
# Ecriture du nouveau fichier test_clean_sent_mediapi/48be2d5494.vtt
# test_clean_sent_mediapi/48be2d5494.vtt done
# Traitement de test_clean_sent_mediapi/2c7dd7d7a0.vtt
# not long enough : test_clean_sent_mediapi/2c7dd7d7a0.vtt
# Traitement de test_clean_sent_mediapi/648f2d616a.vtt
# File long enough, traitement : test_clean_sent_mediapi/648f2d616a.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/648f2d616a.vtt
# test_clean_sent_mediapi/648f2d616a.vtt done
# Traitement de test_clean_sent_mediapi/d1a36bfbad.vtt
# not long enough : test_clean_sent_mediapi/d1a36bfbad.vtt
# Traitement de test_clean_sent_mediapi/75f0bcdd54.vtt
# File long enough, traitement : test_clean_sent_mediapi/75f0bcdd54.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/75f0bcdd54.vtt
# test_clean_sent_mediapi/75f0bcdd54.vtt done
# Traitement de test_clean_sent_mediapi/bbfaf1ee13.vtt
# File long enough, traitement : test_clean_sent_mediapi/bbfaf1ee13.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/bbfaf1ee13.vtt
# test_clean_sent_mediapi/bbfaf1ee13.vtt done
# Traitement de test_clean_sent_mediapi/f18b71d989.vtt
# File long enough, traitement : test_clean_sent_mediapi/f18b71d989.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/f18b71d989.vtt
# test_clean_sent_mediapi/f18b71d989.vtt done
# Traitement de test_clean_sent_mediapi/2f1e1d3af4.vtt
# File long enough, traitement : test_clean_sent_mediapi/2f1e1d3af4.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/2f1e1d3af4.vtt
# test_clean_sent_mediapi/2f1e1d3af4.vtt done
# Traitement de test_clean_sent_mediapi/7932f9a3de.vtt
# not long enough : test_clean_sent_mediapi/7932f9a3de.vtt
# Traitement de test_clean_sent_mediapi/2f82f046d5.vtt
# File long enough, traitement : test_clean_sent_mediapi/2f82f046d5.vtt --- 23
# Ecriture du nouveau fichier test_clean_sent_mediapi/2f82f046d5.vtt
# test_clean_sent_mediapi/2f82f046d5.vtt done
# Traitement de test_clean_sent_mediapi/4d9577ab24.vtt
# File long enough, traitement : test_clean_sent_mediapi/4d9577ab24.vtt --- 69
# Ecriture du nouveau fichier test_clean_sent_mediapi/4d9577ab24.vtt
# test_clean_sent_mediapi/4d9577ab24.vtt done
# Traitement de test_clean_sent_mediapi/7e4dc844f4.vtt
# File long enough, traitement : test_clean_sent_mediapi/7e4dc844f4.vtt --- 58
# Ecriture du nouveau fichier test_clean_sent_mediapi/7e4dc844f4.vtt
# test_clean_sent_mediapi/7e4dc844f4.vtt done
# Traitement de test_clean_sent_mediapi/061183eb54.vtt
# File long enough, traitement : test_clean_sent_mediapi/061183eb54.vtt --- 81
# Ecriture du nouveau fichier test_clean_sent_mediapi/061183eb54.vtt
# test_clean_sent_mediapi/061183eb54.vtt done
# Traitement de test_clean_sent_mediapi/9398a7ed45.vtt
# File long enough, traitement : test_clean_sent_mediapi/9398a7ed45.vtt --- 73
# Ecriture du nouveau fichier test_clean_sent_mediapi/9398a7ed45.vtt
# test_clean_sent_mediapi/9398a7ed45.vtt done
# Traitement de test_clean_sent_mediapi/530970ed94.vtt
# not long enough : test_clean_sent_mediapi/530970ed94.vtt
# Traitement de test_clean_sent_mediapi/657dca485a.vtt
# File long enough, traitement : test_clean_sent_mediapi/657dca485a.vtt --- 24
# Ecriture du nouveau fichier test_clean_sent_mediapi/657dca485a.vtt
# test_clean_sent_mediapi/657dca485a.vtt done
# Traitement de test_clean_sent_mediapi/2c0e5e2432.vtt
# not long enough : test_clean_sent_mediapi/2c0e5e2432.vtt
# Traitement de test_clean_sent_mediapi/1283dc2bc6.vtt
# File long enough, traitement : test_clean_sent_mediapi/1283dc2bc6.vtt --- 37
# Ecriture du nouveau fichier test_clean_sent_mediapi/1283dc2bc6.vtt
# test_clean_sent_mediapi/1283dc2bc6.vtt done
# Traitement de test_clean_sent_mediapi/55b79b1f96.vtt
# not long enough : test_clean_sent_mediapi/55b79b1f96.vtt
# Traitement de test_clean_sent_mediapi/36129e8e7e.vtt
# File long enough, traitement : test_clean_sent_mediapi/36129e8e7e.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/36129e8e7e.vtt
# test_clean_sent_mediapi/36129e8e7e.vtt done
# Traitement de test_clean_sent_mediapi/66b8ddb330.vtt
# not long enough : test_clean_sent_mediapi/66b8ddb330.vtt
# Traitement de test_clean_sent_mediapi/8fc0505a8e.vtt
# File long enough, traitement : test_clean_sent_mediapi/8fc0505a8e.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/8fc0505a8e.vtt
# test_clean_sent_mediapi/8fc0505a8e.vtt done
# Traitement de test_clean_sent_mediapi/91c3a16492.vtt
# not long enough : test_clean_sent_mediapi/91c3a16492.vtt
# Traitement de test_clean_sent_mediapi/87f4b77d47.vtt
# File long enough, traitement : test_clean_sent_mediapi/87f4b77d47.vtt --- 87
# Ecriture du nouveau fichier test_clean_sent_mediapi/87f4b77d47.vtt
# test_clean_sent_mediapi/87f4b77d47.vtt done
# Traitement de test_clean_sent_mediapi/a8318f25e7.vtt
# not long enough : test_clean_sent_mediapi/a8318f25e7.vtt
# Traitement de test_clean_sent_mediapi/b4ce85fbf7.vtt
# File long enough, traitement : test_clean_sent_mediapi/b4ce85fbf7.vtt --- 44
# Ecriture du nouveau fichier test_clean_sent_mediapi/b4ce85fbf7.vtt
# test_clean_sent_mediapi/b4ce85fbf7.vtt done
# Traitement de test_clean_sent_mediapi/647638a97c.vtt
# File long enough, traitement : test_clean_sent_mediapi/647638a97c.vtt --- 45
# Ecriture du nouveau fichier test_clean_sent_mediapi/647638a97c.vtt
# test_clean_sent_mediapi/647638a97c.vtt done
# Traitement de test_clean_sent_mediapi/3c9c76395a.vtt
# not long enough : test_clean_sent_mediapi/3c9c76395a.vtt
# Traitement de test_clean_sent_mediapi/493574a037.vtt
# File long enough, traitement : test_clean_sent_mediapi/493574a037.vtt --- 93
# Ecriture du nouveau fichier test_clean_sent_mediapi/493574a037.vtt
# test_clean_sent_mediapi/493574a037.vtt done
# Traitement de test_clean_sent_mediapi/db1ee8312d.vtt
# File long enough, traitement : test_clean_sent_mediapi/db1ee8312d.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/db1ee8312d.vtt
# test_clean_sent_mediapi/db1ee8312d.vtt done
# Traitement de test_clean_sent_mediapi/3d1087ebe4.vtt
# not long enough : test_clean_sent_mediapi/3d1087ebe4.vtt
# Traitement de test_clean_sent_mediapi/3f62714c82.vtt
# File long enough, traitement : test_clean_sent_mediapi/3f62714c82.vtt --- 34
# Ecriture du nouveau fichier test_clean_sent_mediapi/3f62714c82.vtt
# test_clean_sent_mediapi/3f62714c82.vtt done
# Traitement de test_clean_sent_mediapi/1b4b91655b.vtt
# File long enough, traitement : test_clean_sent_mediapi/1b4b91655b.vtt --- 60
# Ecriture du nouveau fichier test_clean_sent_mediapi/1b4b91655b.vtt
# test_clean_sent_mediapi/1b4b91655b.vtt done
# Traitement de test_clean_sent_mediapi/78d0acb6e7.vtt
# File long enough, traitement : test_clean_sent_mediapi/78d0acb6e7.vtt --- 17
# Ecriture du nouveau fichier test_clean_sent_mediapi/78d0acb6e7.vtt
# test_clean_sent_mediapi/78d0acb6e7.vtt done
# Traitement de test_clean_sent_mediapi/245a286c8e.vtt
# File long enough, traitement : test_clean_sent_mediapi/245a286c8e.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/245a286c8e.vtt
# test_clean_sent_mediapi/245a286c8e.vtt done
# Traitement de test_clean_sent_mediapi/13adb98a30.vtt
# not long enough : test_clean_sent_mediapi/13adb98a30.vtt
# Traitement de test_clean_sent_mediapi/9088be11a1.vtt
# File long enough, traitement : test_clean_sent_mediapi/9088be11a1.vtt --- 41
# Ecriture du nouveau fichier test_clean_sent_mediapi/9088be11a1.vtt
# test_clean_sent_mediapi/9088be11a1.vtt done
# Traitement de test_clean_sent_mediapi/cb28f32304.vtt
# File long enough, traitement : test_clean_sent_mediapi/cb28f32304.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/cb28f32304.vtt
# test_clean_sent_mediapi/cb28f32304.vtt done
# Traitement de test_clean_sent_mediapi/d8687ad02b.vtt
# File long enough, traitement : test_clean_sent_mediapi/d8687ad02b.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/d8687ad02b.vtt
# test_clean_sent_mediapi/d8687ad02b.vtt done
# Traitement de test_clean_sent_mediapi/b58d9b077e.vtt
# not long enough : test_clean_sent_mediapi/b58d9b077e.vtt
# Traitement de test_clean_sent_mediapi/1cb22a2279.vtt
# File long enough, traitement : test_clean_sent_mediapi/1cb22a2279.vtt --- 38
# Ecriture du nouveau fichier test_clean_sent_mediapi/1cb22a2279.vtt
# test_clean_sent_mediapi/1cb22a2279.vtt done
# Traitement de test_clean_sent_mediapi/2fc7967195.vtt
# not long enough : test_clean_sent_mediapi/2fc7967195.vtt
# Traitement de test_clean_sent_mediapi/14595aa066.vtt
# not long enough : test_clean_sent_mediapi/14595aa066.vtt
# Traitement de test_clean_sent_mediapi/879dece3e4.vtt
# not long enough : test_clean_sent_mediapi/879dece3e4.vtt
# Traitement de test_clean_sent_mediapi/0408ad5430.vtt
# File long enough, traitement : test_clean_sent_mediapi/0408ad5430.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/0408ad5430.vtt
# test_clean_sent_mediapi/0408ad5430.vtt done
# Traitement de test_clean_sent_mediapi/7c92a479c2.vtt
# File long enough, traitement : test_clean_sent_mediapi/7c92a479c2.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/7c92a479c2.vtt
# test_clean_sent_mediapi/7c92a479c2.vtt done
# Traitement de test_clean_sent_mediapi/49c7c0f2b7.vtt
# File long enough, traitement : test_clean_sent_mediapi/49c7c0f2b7.vtt --- 52
# Ecriture du nouveau fichier test_clean_sent_mediapi/49c7c0f2b7.vtt
# test_clean_sent_mediapi/49c7c0f2b7.vtt done
# Traitement de test_clean_sent_mediapi/91900415b1.vtt
# not long enough : test_clean_sent_mediapi/91900415b1.vtt
# Traitement de test_clean_sent_mediapi/611cd8bac1.vtt
# File long enough, traitement : test_clean_sent_mediapi/611cd8bac1.vtt --- 53
# Ecriture du nouveau fichier test_clean_sent_mediapi/611cd8bac1.vtt
# test_clean_sent_mediapi/611cd8bac1.vtt done
# Traitement de test_clean_sent_mediapi/1f963b12c6.vtt
# File long enough, traitement : test_clean_sent_mediapi/1f963b12c6.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/1f963b12c6.vtt
# test_clean_sent_mediapi/1f963b12c6.vtt done
# Traitement de test_clean_sent_mediapi/b5af2cb79d.vtt
# File long enough, traitement : test_clean_sent_mediapi/b5af2cb79d.vtt --- 33
# Ecriture du nouveau fichier test_clean_sent_mediapi/b5af2cb79d.vtt
# test_clean_sent_mediapi/b5af2cb79d.vtt done
# Traitement de test_clean_sent_mediapi/938d9996d9.vtt
# not long enough : test_clean_sent_mediapi/938d9996d9.vtt
# Traitement de test_clean_sent_mediapi/4ae8b991ee.vtt
# not long enough : test_clean_sent_mediapi/4ae8b991ee.vtt
# Traitement de test_clean_sent_mediapi/b03e954ae1.vtt
# File long enough, traitement : test_clean_sent_mediapi/b03e954ae1.vtt --- 50
# Ecriture du nouveau fichier test_clean_sent_mediapi/b03e954ae1.vtt
# test_clean_sent_mediapi/b03e954ae1.vtt done
# Traitement de test_clean_sent_mediapi/2a3064d64a.vtt
# File long enough, traitement : test_clean_sent_mediapi/2a3064d64a.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/2a3064d64a.vtt
# test_clean_sent_mediapi/2a3064d64a.vtt done
# Traitement de test_clean_sent_mediapi/0b2e490c12.vtt
# File long enough, traitement : test_clean_sent_mediapi/0b2e490c12.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/0b2e490c12.vtt
# test_clean_sent_mediapi/0b2e490c12.vtt done
# Traitement de test_clean_sent_mediapi/d1f4036e1d.vtt
# File long enough, traitement : test_clean_sent_mediapi/d1f4036e1d.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/d1f4036e1d.vtt
# test_clean_sent_mediapi/d1f4036e1d.vtt done
# Traitement de test_clean_sent_mediapi/d36b54adb5.vtt
# File long enough, traitement : test_clean_sent_mediapi/d36b54adb5.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/d36b54adb5.vtt
# test_clean_sent_mediapi/d36b54adb5.vtt done
# Traitement de test_clean_sent_mediapi/c810f8ff26.vtt
# File long enough, traitement : test_clean_sent_mediapi/c810f8ff26.vtt --- 29
# Ecriture du nouveau fichier test_clean_sent_mediapi/c810f8ff26.vtt
# test_clean_sent_mediapi/c810f8ff26.vtt done
# Traitement de test_clean_sent_mediapi/7b59ef6cd5.vtt
# File long enough, traitement : test_clean_sent_mediapi/7b59ef6cd5.vtt --- 33
# Ecriture du nouveau fichier test_clean_sent_mediapi/7b59ef6cd5.vtt
# test_clean_sent_mediapi/7b59ef6cd5.vtt done
# Traitement de test_clean_sent_mediapi/3d0f798301.vtt
# File long enough, traitement : test_clean_sent_mediapi/3d0f798301.vtt --- 51
# Ecriture du nouveau fichier test_clean_sent_mediapi/3d0f798301.vtt
# test_clean_sent_mediapi/3d0f798301.vtt done
# Traitement de test_clean_sent_mediapi/f73744b1d5.vtt
# File long enough, traitement : test_clean_sent_mediapi/f73744b1d5.vtt --- 63
# Ecriture du nouveau fichier test_clean_sent_mediapi/f73744b1d5.vtt
# test_clean_sent_mediapi/f73744b1d5.vtt done
# Traitement de test_clean_sent_mediapi/b2803a42cb.vtt
# File long enough, traitement : test_clean_sent_mediapi/b2803a42cb.vtt --- 72
# Ecriture du nouveau fichier test_clean_sent_mediapi/b2803a42cb.vtt
# test_clean_sent_mediapi/b2803a42cb.vtt done
# Traitement de test_clean_sent_mediapi/3614c300a2.vtt
# File long enough, traitement : test_clean_sent_mediapi/3614c300a2.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/3614c300a2.vtt
# test_clean_sent_mediapi/3614c300a2.vtt done
# Traitement de test_clean_sent_mediapi/83ea4b70b9.vtt
# not long enough : test_clean_sent_mediapi/83ea4b70b9.vtt
# Traitement de test_clean_sent_mediapi/29afc9b364.vtt
# File long enough, traitement : test_clean_sent_mediapi/29afc9b364.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/29afc9b364.vtt
# test_clean_sent_mediapi/29afc9b364.vtt done
# Traitement de test_clean_sent_mediapi/82c3c558d8.vtt
# not long enough : test_clean_sent_mediapi/82c3c558d8.vtt
# Traitement de test_clean_sent_mediapi/a835c5a096.vtt
# File long enough, traitement : test_clean_sent_mediapi/a835c5a096.vtt --- 20
# Ecriture du nouveau fichier test_clean_sent_mediapi/a835c5a096.vtt
# test_clean_sent_mediapi/a835c5a096.vtt done
# Traitement de test_clean_sent_mediapi/596653a27e.vtt
# File long enough, traitement : test_clean_sent_mediapi/596653a27e.vtt --- 50
# Ecriture du nouveau fichier test_clean_sent_mediapi/596653a27e.vtt
# test_clean_sent_mediapi/596653a27e.vtt done
# Traitement de test_clean_sent_mediapi/baf83ae145.vtt
# File long enough, traitement : test_clean_sent_mediapi/baf83ae145.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/baf83ae145.vtt
# test_clean_sent_mediapi/baf83ae145.vtt done
# Traitement de test_clean_sent_mediapi/2c5fca9371.vtt
# not long enough : test_clean_sent_mediapi/2c5fca9371.vtt
# Traitement de test_clean_sent_mediapi/6462ce3913.vtt
# File long enough, traitement : test_clean_sent_mediapi/6462ce3913.vtt --- 39
# Ecriture du nouveau fichier test_clean_sent_mediapi/6462ce3913.vtt
# test_clean_sent_mediapi/6462ce3913.vtt done
# Traitement de test_clean_sent_mediapi/581d5c3587.vtt
# not long enough : test_clean_sent_mediapi/581d5c3587.vtt
# Traitement de test_clean_sent_mediapi/50d53eca84.vtt
# File long enough, traitement : test_clean_sent_mediapi/50d53eca84.vtt --- 49
# Ecriture du nouveau fichier test_clean_sent_mediapi/50d53eca84.vtt
# test_clean_sent_mediapi/50d53eca84.vtt done
# Traitement de test_clean_sent_mediapi/b28b182a5e.vtt
# File long enough, traitement : test_clean_sent_mediapi/b28b182a5e.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/b28b182a5e.vtt
# test_clean_sent_mediapi/b28b182a5e.vtt done
# Traitement de test_clean_sent_mediapi/4836a95980.vtt
# File long enough, traitement : test_clean_sent_mediapi/4836a95980.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/4836a95980.vtt
# test_clean_sent_mediapi/4836a95980.vtt done
# Traitement de test_clean_sent_mediapi/02eb959bf5.vtt
# not long enough : test_clean_sent_mediapi/02eb959bf5.vtt
# Traitement de test_clean_sent_mediapi/3f8f90ad63.vtt
# not long enough : test_clean_sent_mediapi/3f8f90ad63.vtt
# Traitement de test_clean_sent_mediapi/a7b7ca660a.vtt
# File long enough, traitement : test_clean_sent_mediapi/a7b7ca660a.vtt --- 37
# Ecriture du nouveau fichier test_clean_sent_mediapi/a7b7ca660a.vtt
# test_clean_sent_mediapi/a7b7ca660a.vtt done
# Traitement de test_clean_sent_mediapi/b79a744ad3.vtt
# File long enough, traitement : test_clean_sent_mediapi/b79a744ad3.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/b79a744ad3.vtt
# test_clean_sent_mediapi/b79a744ad3.vtt done
# Traitement de test_clean_sent_mediapi/56fa0513af.vtt
# not long enough : test_clean_sent_mediapi/56fa0513af.vtt
# Traitement de test_clean_sent_mediapi/ecc384c1fb.vtt
# not long enough : test_clean_sent_mediapi/ecc384c1fb.vtt
# Traitement de test_clean_sent_mediapi/079f72dc4a.vtt
# ...
# not long enough : test_clean_sent_mediapi/9be12b63e7.vtt
# Traitement de test_clean_sent_mediapi/1597d882e3.vtt
# File long enough, traitement : test_clean_sent_mediapi/1597d882e3.vtt --- 33
# Ecriture du nouveau fichier test_clean_sent_mediapi/1597d882e3.vtt
# test_clean_sent_mediapi/1597d882e3.vtt done
# Traitement de test_clean_sent_mediapi/1900d28353.vtt
# File long enough, traitement : test_clean_sent_mediapi/1900d28353.vtt --- 26
# Ecriture du nouveau fichier test_clean_sent_mediapi/1900d28353.vtt
# test_clean_sent_mediapi/1900d28353.vtt done
# Traitement de test_clean_sent_mediapi/7c3f48aedd.vtt
# File long enough, traitement : test_clean_sent_mediapi/7c3f48aedd.vtt --- 31
# Ecriture du nouveau fichier test_clean_sent_mediapi/7c3f48aedd.vtt
# test_clean_sent_mediapi/7c3f48aedd.vtt done
# Traitement de test_clean_sent_mediapi/a6403d2fdb.vtt
# File long enough, traitement : test_clean_sent_mediapi/a6403d2fdb.vtt --- 106
# Ecriture du nouveau fichier test_clean_sent_mediapi/a6403d2fdb.vtt
# test_clean_sent_mediapi/a6403d2fdb.vtt done
# Traitement de test_clean_sent_mediapi/cb1c85e9b1.vtt
# not long enough : test_clean_sent_mediapi/cb1c85e9b1.vtt
# Traitement de test_clean_sent_mediapi/1f910187a6.vtt
# File long enough, traitement : test_clean_sent_mediapi/1f910187a6.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/1f910187a6.vtt
# test_clean_sent_mediapi/1f910187a6.vtt done
# Traitement de test_clean_sent_mediapi/5aa593b3d8.vtt
# File long enough, traitement : test_clean_sent_mediapi/5aa593b3d8.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/5aa593b3d8.vtt
# test_clean_sent_mediapi/5aa593b3d8.vtt done
# Traitement de test_clean_sent_mediapi/11cf125577.vtt
# File long enough, traitement : test_clean_sent_mediapi/11cf125577.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/11cf125577.vtt
# test_clean_sent_mediapi/11cf125577.vtt done
# Traitement de test_clean_sent_mediapi/401daa4e94.vtt
# File long enough, traitement : test_clean_sent_mediapi/401daa4e94.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/401daa4e94.vtt
# test_clean_sent_mediapi/401daa4e94.vtt done
# Traitement de test_clean_sent_mediapi/11d2454505.vtt
# File long enough, traitement : test_clean_sent_mediapi/11d2454505.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/11d2454505.vtt
# test_clean_sent_mediapi/11d2454505.vtt done
# Traitement de test_clean_sent_mediapi/e1426c448b.vtt
# File long enough, traitement : test_clean_sent_mediapi/e1426c448b.vtt --- 55
# Ecriture du nouveau fichier test_clean_sent_mediapi/e1426c448b.vtt
# test_clean_sent_mediapi/e1426c448b.vtt done
# Traitement de test_clean_sent_mediapi/10c33b8224.vtt
# File long enough, traitement : test_clean_sent_mediapi/10c33b8224.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/10c33b8224.vtt
# test_clean_sent_mediapi/10c33b8224.vtt done
# Traitement de test_clean_sent_mediapi/11c134b52a.vtt
# File long enough, traitement : test_clean_sent_mediapi/11c134b52a.vtt --- 19
# Ecriture du nouveau fichier test_clean_sent_mediapi/11c134b52a.vtt
# test_clean_sent_mediapi/11c134b52a.vtt done
# Traitement de test_clean_sent_mediapi/b54a4872f1.vtt
# File long enough, traitement : test_clean_sent_mediapi/b54a4872f1.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/b54a4872f1.vtt
# test_clean_sent_mediapi/b54a4872f1.vtt done
# Traitement de test_clean_sent_mediapi/bf7a8e3536.vtt
# not long enough : test_clean_sent_mediapi/bf7a8e3536.vtt
# Traitement de test_clean_sent_mediapi/71956066fb.vtt
# not long enough : test_clean_sent_mediapi/71956066fb.vtt
# Traitement de test_clean_sent_mediapi/aa652b7e98.vtt
# File long enough, traitement : test_clean_sent_mediapi/aa652b7e98.vtt --- 31
# Ecriture du nouveau fichier test_clean_sent_mediapi/aa652b7e98.vtt
# test_clean_sent_mediapi/aa652b7e98.vtt done
# Traitement de test_clean_sent_mediapi/c89d4e9e51.vtt
# File long enough, traitement : test_clean_sent_mediapi/c89d4e9e51.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/c89d4e9e51.vtt
# test_clean_sent_mediapi/c89d4e9e51.vtt done
# Traitement de test_clean_sent_mediapi/a7bc181f15.vtt
# not long enough : test_clean_sent_mediapi/a7bc181f15.vtt
# Traitement de test_clean_sent_mediapi/b1b658bc7d.vtt
# File long enough, traitement : test_clean_sent_mediapi/b1b658bc7d.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/b1b658bc7d.vtt
# test_clean_sent_mediapi/b1b658bc7d.vtt done
# Traitement de test_clean_sent_mediapi/fa49778534.vtt
# not long enough : test_clean_sent_mediapi/fa49778534.vtt
# Traitement de test_clean_sent_mediapi/8ff5cdd8d1.vtt
# not long enough : test_clean_sent_mediapi/8ff5cdd8d1.vtt
# Traitement de test_clean_sent_mediapi/e3348417a4.vtt
# File long enough, traitement : test_clean_sent_mediapi/e3348417a4.vtt --- 56
# Ecriture du nouveau fichier test_clean_sent_mediapi/e3348417a4.vtt
# test_clean_sent_mediapi/e3348417a4.vtt done
# Traitement de test_clean_sent_mediapi/6d7058d758.vtt
# File long enough, traitement : test_clean_sent_mediapi/6d7058d758.vtt --- 48
# Ecriture du nouveau fichier test_clean_sent_mediapi/6d7058d758.vtt
# test_clean_sent_mediapi/6d7058d758.vtt done
# Traitement de test_clean_sent_mediapi/6c868284a0.vtt
# File long enough, traitement : test_clean_sent_mediapi/6c868284a0.vtt --- 70
# Ecriture du nouveau fichier test_clean_sent_mediapi/6c868284a0.vtt
# test_clean_sent_mediapi/6c868284a0.vtt done
# Traitement de test_clean_sent_mediapi/22339d12cd.vtt
# File long enough, traitement : test_clean_sent_mediapi/22339d12cd.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/22339d12cd.vtt
# test_clean_sent_mediapi/22339d12cd.vtt done
# Traitement de test_clean_sent_mediapi/9aa4bdc1e9.vtt
# File long enough, traitement : test_clean_sent_mediapi/9aa4bdc1e9.vtt --- 39
# Ecriture du nouveau fichier test_clean_sent_mediapi/9aa4bdc1e9.vtt
# test_clean_sent_mediapi/9aa4bdc1e9.vtt done
# Traitement de test_clean_sent_mediapi/94b345cd57.vtt
# File long enough, traitement : test_clean_sent_mediapi/94b345cd57.vtt --- 22
# Ecriture du nouveau fichier test_clean_sent_mediapi/94b345cd57.vtt
# test_clean_sent_mediapi/94b345cd57.vtt done
# Traitement de test_clean_sent_mediapi/bdad34a29b.vtt
# File long enough, traitement : test_clean_sent_mediapi/bdad34a29b.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/bdad34a29b.vtt
# test_clean_sent_mediapi/bdad34a29b.vtt done
# Traitement de test_clean_sent_mediapi/bb09c5688c.vtt
# File long enough, traitement : test_clean_sent_mediapi/bb09c5688c.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/bb09c5688c.vtt
# test_clean_sent_mediapi/bb09c5688c.vtt done
# Traitement de test_clean_sent_mediapi/b102a1e163.vtt
# File long enough, traitement : test_clean_sent_mediapi/b102a1e163.vtt --- 110
# Ecriture du nouveau fichier test_clean_sent_mediapi/b102a1e163.vtt
# test_clean_sent_mediapi/b102a1e163.vtt done
# Traitement de test_clean_sent_mediapi/81d3ca0ba7.vtt
# File long enough, traitement : test_clean_sent_mediapi/81d3ca0ba7.vtt --- 88
# Ecriture du nouveau fichier test_clean_sent_mediapi/81d3ca0ba7.vtt
# test_clean_sent_mediapi/81d3ca0ba7.vtt done
# Traitement de test_clean_sent_mediapi/5f586b7c7d.vtt
# not long enough : test_clean_sent_mediapi/5f586b7c7d.vtt
# Traitement de test_clean_sent_mediapi/8d6dcc66f1.vtt
# not long enough : test_clean_sent_mediapi/8d6dcc66f1.vtt
# Traitement de test_clean_sent_mediapi/798bb4ecf4.vtt
# File long enough, traitement : test_clean_sent_mediapi/798bb4ecf4.vtt --- 27
# Ecriture du nouveau fichier test_clean_sent_mediapi/798bb4ecf4.vtt
# test_clean_sent_mediapi/798bb4ecf4.vtt done
# Traitement de test_clean_sent_mediapi/4d7c882a41.vtt
# not long enough : test_clean_sent_mediapi/4d7c882a41.vtt
# Traitement de test_clean_sent_mediapi/0be0cf2056.vtt
# File long enough, traitement : test_clean_sent_mediapi/0be0cf2056.vtt --- 73
# Ecriture du nouveau fichier test_clean_sent_mediapi/0be0cf2056.vtt
# test_clean_sent_mediapi/0be0cf2056.vtt done
# Traitement de test_clean_sent_mediapi/c02ca8a63b.vtt
# not long enough : test_clean_sent_mediapi/c02ca8a63b.vtt
# Traitement de test_clean_sent_mediapi/6e81b7d1cf.vtt
# File long enough, traitement : test_clean_sent_mediapi/6e81b7d1cf.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/6e81b7d1cf.vtt
# test_clean_sent_mediapi/6e81b7d1cf.vtt done
# Traitement de test_clean_sent_mediapi/20f4ef55ef.vtt
# File long enough, traitement : test_clean_sent_mediapi/20f4ef55ef.vtt --- 66
# Ecriture du nouveau fichier test_clean_sent_mediapi/20f4ef55ef.vtt
# test_clean_sent_mediapi/20f4ef55ef.vtt done
# Traitement de test_clean_sent_mediapi/7d3673c879.vtt
# not long enough : test_clean_sent_mediapi/7d3673c879.vtt
# Traitement de test_clean_sent_mediapi/3e2d70b57f.vtt
# File long enough, traitement : test_clean_sent_mediapi/3e2d70b57f.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/3e2d70b57f.vtt
# test_clean_sent_mediapi/3e2d70b57f.vtt done
# Traitement de test_clean_sent_mediapi/4a6ad3be05.vtt
# not long enough : test_clean_sent_mediapi/4a6ad3be05.vtt
# Traitement de test_clean_sent_mediapi/29c70e05fd.vtt
# not long enough : test_clean_sent_mediapi/29c70e05fd.vtt
# Traitement de test_clean_sent_mediapi/2e445f0c29.vtt
# File long enough, traitement : test_clean_sent_mediapi/2e445f0c29.vtt --- 63
# Ecriture du nouveau fichier test_clean_sent_mediapi/2e445f0c29.vtt
# test_clean_sent_mediapi/2e445f0c29.vtt done
# Traitement de test_clean_sent_mediapi/034e97db12.vtt
# not long enough : test_clean_sent_mediapi/034e97db12.vtt
# Traitement de test_clean_sent_mediapi/f25b099f70.vtt
# File long enough, traitement : test_clean_sent_mediapi/f25b099f70.vtt --- 45
# Ecriture du nouveau fichier test_clean_sent_mediapi/f25b099f70.vtt
# test_clean_sent_mediapi/f25b099f70.vtt done
# Traitement de test_clean_sent_mediapi/840a9ef102.vtt
# File long enough, traitement : test_clean_sent_mediapi/840a9ef102.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/840a9ef102.vtt
# test_clean_sent_mediapi/840a9ef102.vtt done
# Traitement de test_clean_sent_mediapi/2486641c7f.vtt
# not long enough : test_clean_sent_mediapi/2486641c7f.vtt
# Traitement de test_clean_sent_mediapi/26e86eed1d.vtt
# File long enough, traitement : test_clean_sent_mediapi/26e86eed1d.vtt --- 76
# Ecriture du nouveau fichier test_clean_sent_mediapi/26e86eed1d.vtt
# test_clean_sent_mediapi/26e86eed1d.vtt done
# Traitement de test_clean_sent_mediapi/5c91a69806.vtt
# File long enough, traitement : test_clean_sent_mediapi/5c91a69806.vtt --- 54
# Ecriture du nouveau fichier test_clean_sent_mediapi/5c91a69806.vtt
# test_clean_sent_mediapi/5c91a69806.vtt done
# Traitement de test_clean_sent_mediapi/a6751ed1ac.vtt
# not long enough : test_clean_sent_mediapi/a6751ed1ac.vtt
# Traitement de test_clean_sent_mediapi/bfcef7c2b3.vtt
# File long enough, traitement : test_clean_sent_mediapi/bfcef7c2b3.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/bfcef7c2b3.vtt
# test_clean_sent_mediapi/bfcef7c2b3.vtt done
# Traitement de test_clean_sent_mediapi/6fe1be8eeb.vtt
# File long enough, traitement : test_clean_sent_mediapi/6fe1be8eeb.vtt --- 52
# Ecriture du nouveau fichier test_clean_sent_mediapi/6fe1be8eeb.vtt
# test_clean_sent_mediapi/6fe1be8eeb.vtt done
# Traitement de test_clean_sent_mediapi/2c2dfd3fc9.vtt
# File long enough, traitement : test_clean_sent_mediapi/2c2dfd3fc9.vtt --- 63
# Ecriture du nouveau fichier test_clean_sent_mediapi/2c2dfd3fc9.vtt
# test_clean_sent_mediapi/2c2dfd3fc9.vtt done
# Traitement de test_clean_sent_mediapi/9648e8f26c.vtt
# File long enough, traitement : test_clean_sent_mediapi/9648e8f26c.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/9648e8f26c.vtt
# test_clean_sent_mediapi/9648e8f26c.vtt done
# Traitement de test_clean_sent_mediapi/c5f16d8593.vtt
# not long enough : test_clean_sent_mediapi/c5f16d8593.vtt
# Traitement de test_clean_sent_mediapi/81dadd7460.vtt
# not long enough : test_clean_sent_mediapi/81dadd7460.vtt
# Traitement de test_clean_sent_mediapi/5461b5bde9.vtt
# File long enough, traitement : test_clean_sent_mediapi/5461b5bde9.vtt --- 62
# Ecriture du nouveau fichier test_clean_sent_mediapi/5461b5bde9.vtt
# test_clean_sent_mediapi/5461b5bde9.vtt done
# Traitement de test_clean_sent_mediapi/8c5bc3ccfb.vtt
# File long enough, traitement : test_clean_sent_mediapi/8c5bc3ccfb.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/8c5bc3ccfb.vtt
# test_clean_sent_mediapi/8c5bc3ccfb.vtt done
# Traitement de test_clean_sent_mediapi/3cdedd9322.vtt
# File long enough, traitement : test_clean_sent_mediapi/3cdedd9322.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/3cdedd9322.vtt
# test_clean_sent_mediapi/3cdedd9322.vtt done
# Traitement de test_clean_sent_mediapi/9d6d788d6f.vtt
# not long enough : test_clean_sent_mediapi/9d6d788d6f.vtt
# Traitement de test_clean_sent_mediapi/29b3d8f02f.vtt
# not long enough : test_clean_sent_mediapi/29b3d8f02f.vtt
# Traitement de test_clean_sent_mediapi/0adba1635f.vtt
# File long enough, traitement : test_clean_sent_mediapi/0adba1635f.vtt --- 38
# Ecriture du nouveau fichier test_clean_sent_mediapi/0adba1635f.vtt
# test_clean_sent_mediapi/0adba1635f.vtt done
# Traitement de test_clean_sent_mediapi/da4deaad0b.vtt
# File long enough, traitement : test_clean_sent_mediapi/da4deaad0b.vtt --- 34
# Ecriture du nouveau fichier test_clean_sent_mediapi/da4deaad0b.vtt
# test_clean_sent_mediapi/da4deaad0b.vtt done
# Traitement de test_clean_sent_mediapi/32dcb171f1.vtt
# File long enough, traitement : test_clean_sent_mediapi/32dcb171f1.vtt --- 41
# Ecriture du nouveau fichier test_clean_sent_mediapi/32dcb171f1.vtt
# test_clean_sent_mediapi/32dcb171f1.vtt done
# Traitement de test_clean_sent_mediapi/b5e53a7d55.vtt
# File long enough, traitement : test_clean_sent_mediapi/b5e53a7d55.vtt --- 68
# Ecriture du nouveau fichier test_clean_sent_mediapi/b5e53a7d55.vtt
# test_clean_sent_mediapi/b5e53a7d55.vtt done
# Traitement de test_clean_sent_mediapi/3bfd5a2d10.vtt
# File long enough, traitement : test_clean_sent_mediapi/3bfd5a2d10.vtt --- 19
# Ecriture du nouveau fichier test_clean_sent_mediapi/3bfd5a2d10.vtt
# test_clean_sent_mediapi/3bfd5a2d10.vtt done
# Traitement de test_clean_sent_mediapi/1ee409d870.vtt
# File long enough, traitement : test_clean_sent_mediapi/1ee409d870.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/1ee409d870.vtt
# test_clean_sent_mediapi/1ee409d870.vtt done
# Traitement de test_clean_sent_mediapi/5626f0426c.vtt
# File long enough, traitement : test_clean_sent_mediapi/5626f0426c.vtt --- 71
# Ecriture du nouveau fichier test_clean_sent_mediapi/5626f0426c.vtt
# test_clean_sent_mediapi/5626f0426c.vtt done
# Traitement de test_clean_sent_mediapi/bcc5f33667.vtt
# File long enough, traitement : test_clean_sent_mediapi/bcc5f33667.vtt --- 71
# Ecriture du nouveau fichier test_clean_sent_mediapi/bcc5f33667.vtt
# test_clean_sent_mediapi/bcc5f33667.vtt done
# Traitement de test_clean_sent_mediapi/3de1279be3.vtt
# File long enough, traitement : test_clean_sent_mediapi/3de1279be3.vtt --- 300
# Ecriture du nouveau fichier test_clean_sent_mediapi/3de1279be3.vtt
# test_clean_sent_mediapi/3de1279be3.vtt done
# Traitement de test_clean_sent_mediapi/1f84300c69.vtt
# File long enough, traitement : test_clean_sent_mediapi/1f84300c69.vtt --- 77
# Ecriture du nouveau fichier test_clean_sent_mediapi/1f84300c69.vtt
# test_clean_sent_mediapi/1f84300c69.vtt done
# Traitement de test_clean_sent_mediapi/7cfbe856ee.vtt
# File long enough, traitement : test_clean_sent_mediapi/7cfbe856ee.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/7cfbe856ee.vtt
# test_clean_sent_mediapi/7cfbe856ee.vtt done
# Traitement de test_clean_sent_mediapi/5d458bfe95.vtt
# File long enough, traitement : test_clean_sent_mediapi/5d458bfe95.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/5d458bfe95.vtt
# test_clean_sent_mediapi/5d458bfe95.vtt done
# Traitement de test_clean_sent_mediapi/9dd9c62411.vtt
# not long enough : test_clean_sent_mediapi/9dd9c62411.vtt
# Traitement de test_clean_sent_mediapi/a7c3a0d03b.vtt
# not long enough : test_clean_sent_mediapi/a7c3a0d03b.vtt
# Traitement de test_clean_sent_mediapi/5bf0f577d3.vtt
# File long enough, traitement : test_clean_sent_mediapi/5bf0f577d3.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/5bf0f577d3.vtt
# test_clean_sent_mediapi/5bf0f577d3.vtt done

# %% [markdown]
# - remonter ce qu'il y a après ":" si c'est isolée de la phrase sur la ligne suivante

# %%
ponctuations = {":"}

# Ouvrez le fichier en mode lecture
for file in files:
    with open(file,"r",encoding="utf-8") as f:
        print(f"Traitement de {file}")
        ligne_precedente = ""
        liste_sent = f.readlines()
        if len(liste_sent) > 3:
            print(f"File long enough, traitement : {file} --- {len(liste_sent)}")
            i=0
            txt=""
            while i < len(liste_sent):
                if i < len(liste_sent)-1:
                    if liste_sent[i].strip().endswith(":"):
                        txt = txt + liste_sent[i].strip() + " " + liste_sent[i+1]
                        i = i+2
                        var = True
                    else:
                        txt = txt + liste_sent[i]
                        i = i +1
                        var = False
                else:
                    if var == False:
                        txt = txt + liste_sent[i]
                        i = i +1
                    else:
                        i = i +1
            with open(file,"w",encoding="utf-8") as f:
                print(f"Ecriture du nouveau fichier {file}")
                f.write(txt)
            print(f"{file} done")
            i = 0
        else:
            print(f"not long enough : {file}")
# Out:
# Traitement de test_clean_sent_mediapi/b7f2d8f0c3.vtt
# not long enough : test_clean_sent_mediapi/b7f2d8f0c3.vtt
# Traitement de test_clean_sent_mediapi/3d0b82b459.vtt
# File long enough, traitement : test_clean_sent_mediapi/3d0b82b459.vtt --- 61
# Ecriture du nouveau fichier test_clean_sent_mediapi/3d0b82b459.vtt
# test_clean_sent_mediapi/3d0b82b459.vtt done
# Traitement de test_clean_sent_mediapi/44f554f914.vtt
# not long enough : test_clean_sent_mediapi/44f554f914.vtt
# Traitement de test_clean_sent_mediapi/b9a51f4361.vtt
# File long enough, traitement : test_clean_sent_mediapi/b9a51f4361.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/b9a51f4361.vtt
# test_clean_sent_mediapi/b9a51f4361.vtt done
# Traitement de test_clean_sent_mediapi/4e073949b1.vtt
# not long enough : test_clean_sent_mediapi/4e073949b1.vtt
# Traitement de test_clean_sent_mediapi/0b1437bc85.vtt
# not long enough : test_clean_sent_mediapi/0b1437bc85.vtt
# Traitement de test_clean_sent_mediapi/752500b761.vtt
# File long enough, traitement : test_clean_sent_mediapi/752500b761.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/752500b761.vtt
# test_clean_sent_mediapi/752500b761.vtt done
# Traitement de test_clean_sent_mediapi/cba6cefad2.vtt
# File long enough, traitement : test_clean_sent_mediapi/cba6cefad2.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/cba6cefad2.vtt
# test_clean_sent_mediapi/cba6cefad2.vtt done
# Traitement de test_clean_sent_mediapi/41c606553f.vtt
# File long enough, traitement : test_clean_sent_mediapi/41c606553f.vtt --- 23
# Ecriture du nouveau fichier test_clean_sent_mediapi/41c606553f.vtt
# test_clean_sent_mediapi/41c606553f.vtt done
# Traitement de test_clean_sent_mediapi/3f1b2118ca.vtt
# File long enough, traitement : test_clean_sent_mediapi/3f1b2118ca.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/3f1b2118ca.vtt
# test_clean_sent_mediapi/3f1b2118ca.vtt done
# Traitement de test_clean_sent_mediapi/ed969c3e70.vtt
# File long enough, traitement : test_clean_sent_mediapi/ed969c3e70.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/ed969c3e70.vtt
# test_clean_sent_mediapi/ed969c3e70.vtt done
# Traitement de test_clean_sent_mediapi/26f1ff8385.vtt
# not long enough : test_clean_sent_mediapi/26f1ff8385.vtt
# Traitement de test_clean_sent_mediapi/2b4b33189c.vtt
# File long enough, traitement : test_clean_sent_mediapi/2b4b33189c.vtt --- 59
# Ecriture du nouveau fichier test_clean_sent_mediapi/2b4b33189c.vtt
# test_clean_sent_mediapi/2b4b33189c.vtt done
# Traitement de test_clean_sent_mediapi/ada7d10a19.vtt
# File long enough, traitement : test_clean_sent_mediapi/ada7d10a19.vtt --- 22
# Ecriture du nouveau fichier test_clean_sent_mediapi/ada7d10a19.vtt
# test_clean_sent_mediapi/ada7d10a19.vtt done
# Traitement de test_clean_sent_mediapi/fd41a24117.vtt
# File long enough, traitement : test_clean_sent_mediapi/fd41a24117.vtt --- 145
# Ecriture du nouveau fichier test_clean_sent_mediapi/fd41a24117.vtt
# test_clean_sent_mediapi/fd41a24117.vtt done
# Traitement de test_clean_sent_mediapi/15abfc95ae.vtt
# File long enough, traitement : test_clean_sent_mediapi/15abfc95ae.vtt --- 17
# Ecriture du nouveau fichier test_clean_sent_mediapi/15abfc95ae.vtt
# test_clean_sent_mediapi/15abfc95ae.vtt done
# Traitement de test_clean_sent_mediapi/495145911e.vtt
# File long enough, traitement : test_clean_sent_mediapi/495145911e.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/495145911e.vtt
# test_clean_sent_mediapi/495145911e.vtt done
# Traitement de test_clean_sent_mediapi/5ef5fa319a.vtt
# File long enough, traitement : test_clean_sent_mediapi/5ef5fa319a.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/5ef5fa319a.vtt
# test_clean_sent_mediapi/5ef5fa319a.vtt done
# Traitement de test_clean_sent_mediapi/0fd91cb814.vtt
# File long enough, traitement : test_clean_sent_mediapi/0fd91cb814.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/0fd91cb814.vtt
# test_clean_sent_mediapi/0fd91cb814.vtt done
# Traitement de test_clean_sent_mediapi/9a58b08185.vtt
# File long enough, traitement : test_clean_sent_mediapi/9a58b08185.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/9a58b08185.vtt
# test_clean_sent_mediapi/9a58b08185.vtt done
# Traitement de test_clean_sent_mediapi/ac6160b61a.vtt
# not long enough : test_clean_sent_mediapi/ac6160b61a.vtt
# Traitement de test_clean_sent_mediapi/74bb642e72.vtt
# File long enough, traitement : test_clean_sent_mediapi/74bb642e72.vtt --- 64
# Ecriture du nouveau fichier test_clean_sent_mediapi/74bb642e72.vtt
# test_clean_sent_mediapi/74bb642e72.vtt done
# Traitement de test_clean_sent_mediapi/17217ca54b.vtt
# File long enough, traitement : test_clean_sent_mediapi/17217ca54b.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/17217ca54b.vtt
# test_clean_sent_mediapi/17217ca54b.vtt done
# Traitement de test_clean_sent_mediapi/928499b438.vtt
# not long enough : test_clean_sent_mediapi/928499b438.vtt
# Traitement de test_clean_sent_mediapi/8036e9b4bc.vtt
# File long enough, traitement : test_clean_sent_mediapi/8036e9b4bc.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/8036e9b4bc.vtt
# test_clean_sent_mediapi/8036e9b4bc.vtt done
# Traitement de test_clean_sent_mediapi/5dfad26566.vtt
# File long enough, traitement : test_clean_sent_mediapi/5dfad26566.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/5dfad26566.vtt
# test_clean_sent_mediapi/5dfad26566.vtt done
# Traitement de test_clean_sent_mediapi/71e94f545f.vtt
# File long enough, traitement : test_clean_sent_mediapi/71e94f545f.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/71e94f545f.vtt
# test_clean_sent_mediapi/71e94f545f.vtt done
# Traitement de test_clean_sent_mediapi/008420cac0.vtt
# File long enough, traitement : test_clean_sent_mediapi/008420cac0.vtt --- 17
# Ecriture du nouveau fichier test_clean_sent_mediapi/008420cac0.vtt
# test_clean_sent_mediapi/008420cac0.vtt done
# Traitement de test_clean_sent_mediapi/689abe06d3.vtt
# File long enough, traitement : test_clean_sent_mediapi/689abe06d3.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/689abe06d3.vtt
# test_clean_sent_mediapi/689abe06d3.vtt done
# Traitement de test_clean_sent_mediapi/870fcc2c39.vtt
# not long enough : test_clean_sent_mediapi/870fcc2c39.vtt
# Traitement de test_clean_sent_mediapi/575f99a4af.vtt
# File long enough, traitement : test_clean_sent_mediapi/575f99a4af.vtt --- 119
# Ecriture du nouveau fichier test_clean_sent_mediapi/575f99a4af.vtt
# test_clean_sent_mediapi/575f99a4af.vtt done
# Traitement de test_clean_sent_mediapi/5813b21ceb.vtt
# File long enough, traitement : test_clean_sent_mediapi/5813b21ceb.vtt --- 23
# Ecriture du nouveau fichier test_clean_sent_mediapi/5813b21ceb.vtt
# test_clean_sent_mediapi/5813b21ceb.vtt done
# Traitement de test_clean_sent_mediapi/6e72821691.vtt
# File long enough, traitement : test_clean_sent_mediapi/6e72821691.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/6e72821691.vtt
# test_clean_sent_mediapi/6e72821691.vtt done
# Traitement de test_clean_sent_mediapi/cee1643fd7.vtt
# not long enough : test_clean_sent_mediapi/cee1643fd7.vtt
# Traitement de test_clean_sent_mediapi/88fb28815b.vtt
# not long enough : test_clean_sent_mediapi/88fb28815b.vtt
# Traitement de test_clean_sent_mediapi/a710e36c40.vtt
# File long enough, traitement : test_clean_sent_mediapi/a710e36c40.vtt --- 33
# Ecriture du nouveau fichier test_clean_sent_mediapi/a710e36c40.vtt
# test_clean_sent_mediapi/a710e36c40.vtt done
# Traitement de test_clean_sent_mediapi/31201b65bf.vtt
# not long enough : test_clean_sent_mediapi/31201b65bf.vtt
# Traitement de test_clean_sent_mediapi/72aeba358a.vtt
# not long enough : test_clean_sent_mediapi/72aeba358a.vtt
# Traitement de test_clean_sent_mediapi/1dd7333d1b.vtt
# not long enough : test_clean_sent_mediapi/1dd7333d1b.vtt
# Traitement de test_clean_sent_mediapi/a6a8d92675.vtt
# not long enough : test_clean_sent_mediapi/a6a8d92675.vtt
# Traitement de test_clean_sent_mediapi/bdc14ece6e.vtt
# File long enough, traitement : test_clean_sent_mediapi/bdc14ece6e.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/bdc14ece6e.vtt
# test_clean_sent_mediapi/bdc14ece6e.vtt done
# Traitement de test_clean_sent_mediapi/d9730fe376.vtt
# File long enough, traitement : test_clean_sent_mediapi/d9730fe376.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/d9730fe376.vtt
# test_clean_sent_mediapi/d9730fe376.vtt done
# Traitement de test_clean_sent_mediapi/142a8e3b5d.vtt
# File long enough, traitement : test_clean_sent_mediapi/142a8e3b5d.vtt --- 26
# Ecriture du nouveau fichier test_clean_sent_mediapi/142a8e3b5d.vtt
# test_clean_sent_mediapi/142a8e3b5d.vtt done
# Traitement de test_clean_sent_mediapi/383f2888b6.vtt
# not long enough : test_clean_sent_mediapi/383f2888b6.vtt
# Traitement de test_clean_sent_mediapi/b72ca1fa4f.vtt
# not long enough : test_clean_sent_mediapi/b72ca1fa4f.vtt
# Traitement de test_clean_sent_mediapi/3adc6931bf.vtt
# File long enough, traitement : test_clean_sent_mediapi/3adc6931bf.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/3adc6931bf.vtt
# test_clean_sent_mediapi/3adc6931bf.vtt done
# Traitement de test_clean_sent_mediapi/7a7a8be63d.vtt
# File long enough, traitement : test_clean_sent_mediapi/7a7a8be63d.vtt --- 65
# Ecriture du nouveau fichier test_clean_sent_mediapi/7a7a8be63d.vtt
# test_clean_sent_mediapi/7a7a8be63d.vtt done
# Traitement de test_clean_sent_mediapi/8da1b28015.vtt
# File long enough, traitement : test_clean_sent_mediapi/8da1b28015.vtt --- 49
# Ecriture du nouveau fichier test_clean_sent_mediapi/8da1b28015.vtt
# test_clean_sent_mediapi/8da1b28015.vtt done
# Traitement de test_clean_sent_mediapi/b6c03b60b7.vtt
# File long enough, traitement : test_clean_sent_mediapi/b6c03b60b7.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/b6c03b60b7.vtt
# test_clean_sent_mediapi/b6c03b60b7.vtt done
# Traitement de test_clean_sent_mediapi/e3edfd09b6.vtt
# not long enough : test_clean_sent_mediapi/e3edfd09b6.vtt
# Traitement de test_clean_sent_mediapi/3013321813.vtt
# not long enough : test_clean_sent_mediapi/3013321813.vtt
# Traitement de test_clean_sent_mediapi/88d76860dd.vtt
# not long enough : test_clean_sent_mediapi/88d76860dd.vtt
# Traitement de test_clean_sent_mediapi/f49546dd7d.vtt
# not long enough : test_clean_sent_mediapi/f49546dd7d.vtt
# Traitement de test_clean_sent_mediapi/34210d5c72.vtt
# File long enough, traitement : test_clean_sent_mediapi/34210d5c72.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/34210d5c72.vtt
# test_clean_sent_mediapi/34210d5c72.vtt done
# Traitement de test_clean_sent_mediapi/099c404cc1.vtt
# File long enough, traitement : test_clean_sent_mediapi/099c404cc1.vtt --- 35
# Ecriture du nouveau fichier test_clean_sent_mediapi/099c404cc1.vtt
# test_clean_sent_mediapi/099c404cc1.vtt done
# Traitement de test_clean_sent_mediapi/bfcd06419a.vtt
# File long enough, traitement : test_clean_sent_mediapi/bfcd06419a.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/bfcd06419a.vtt
# test_clean_sent_mediapi/bfcd06419a.vtt done
# Traitement de test_clean_sent_mediapi/f978fa2dea.vtt
# not long enough : test_clean_sent_mediapi/f978fa2dea.vtt
# Traitement de test_clean_sent_mediapi/4151b008b6.vtt
# File long enough, traitement : test_clean_sent_mediapi/4151b008b6.vtt --- 54
# Ecriture du nouveau fichier test_clean_sent_mediapi/4151b008b6.vtt
# test_clean_sent_mediapi/4151b008b6.vtt done
# Traitement de test_clean_sent_mediapi/bc3726d559.vtt
# File long enough, traitement : test_clean_sent_mediapi/bc3726d559.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/bc3726d559.vtt
# test_clean_sent_mediapi/bc3726d559.vtt done
# Traitement de test_clean_sent_mediapi/6706655430.vtt
# not long enough : test_clean_sent_mediapi/6706655430.vtt
# Traitement de test_clean_sent_mediapi/2b38719c3e.vtt
# File long enough, traitement : test_clean_sent_mediapi/2b38719c3e.vtt --- 30
# Ecriture du nouveau fichier test_clean_sent_mediapi/2b38719c3e.vtt
# test_clean_sent_mediapi/2b38719c3e.vtt done
# Traitement de test_clean_sent_mediapi/a0ec06d1d3.vtt
# File long enough, traitement : test_clean_sent_mediapi/a0ec06d1d3.vtt --- 46
# Ecriture du nouveau fichier test_clean_sent_mediapi/a0ec06d1d3.vtt
# test_clean_sent_mediapi/a0ec06d1d3.vtt done
# Traitement de test_clean_sent_mediapi/29a437b7e7.vtt
# File long enough, traitement : test_clean_sent_mediapi/29a437b7e7.vtt --- 60
# Ecriture du nouveau fichier test_clean_sent_mediapi/29a437b7e7.vtt
# test_clean_sent_mediapi/29a437b7e7.vtt done
# Traitement de test_clean_sent_mediapi/c90bbbf71e.vtt
# File long enough, traitement : test_clean_sent_mediapi/c90bbbf71e.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/c90bbbf71e.vtt
# test_clean_sent_mediapi/c90bbbf71e.vtt done
# Traitement de test_clean_sent_mediapi/a6de2b7652.vtt
# File long enough, traitement : test_clean_sent_mediapi/a6de2b7652.vtt --- 47
# Ecriture du nouveau fichier test_clean_sent_mediapi/a6de2b7652.vtt
# test_clean_sent_mediapi/a6de2b7652.vtt done
# Traitement de test_clean_sent_mediapi/38e41f547d.vtt
# File long enough, traitement : test_clean_sent_mediapi/38e41f547d.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/38e41f547d.vtt
# test_clean_sent_mediapi/38e41f547d.vtt done
# Traitement de test_clean_sent_mediapi/13a80ac2d1.vtt
# File long enough, traitement : test_clean_sent_mediapi/13a80ac2d1.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/13a80ac2d1.vtt
# test_clean_sent_mediapi/13a80ac2d1.vtt done
# Traitement de test_clean_sent_mediapi/ad79e17356.vtt
# File long enough, traitement : test_clean_sent_mediapi/ad79e17356.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/ad79e17356.vtt
# test_clean_sent_mediapi/ad79e17356.vtt done
# Traitement de test_clean_sent_mediapi/b28f6ce507.vtt
# File long enough, traitement : test_clean_sent_mediapi/b28f6ce507.vtt --- 59
# Ecriture du nouveau fichier test_clean_sent_mediapi/b28f6ce507.vtt
# test_clean_sent_mediapi/b28f6ce507.vtt done
# Traitement de test_clean_sent_mediapi/6cf26927ca.vtt
# File long enough, traitement : test_clean_sent_mediapi/6cf26927ca.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/6cf26927ca.vtt
# test_clean_sent_mediapi/6cf26927ca.vtt done
# Traitement de test_clean_sent_mediapi/c3258a13e3.vtt
# File long enough, traitement : test_clean_sent_mediapi/c3258a13e3.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/c3258a13e3.vtt
# test_clean_sent_mediapi/c3258a13e3.vtt done
# Traitement de test_clean_sent_mediapi/1992ebbd09.vtt
# File long enough, traitement : test_clean_sent_mediapi/1992ebbd09.vtt --- 103
# Ecriture du nouveau fichier test_clean_sent_mediapi/1992ebbd09.vtt
# test_clean_sent_mediapi/1992ebbd09.vtt done
# Traitement de test_clean_sent_mediapi/d92e970202.vtt
# File long enough, traitement : test_clean_sent_mediapi/d92e970202.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/d92e970202.vtt
# test_clean_sent_mediapi/d92e970202.vtt done
# Traitement de test_clean_sent_mediapi/dcd9053975.vtt
# File long enough, traitement : test_clean_sent_mediapi/dcd9053975.vtt --- 37
# Ecriture du nouveau fichier test_clean_sent_mediapi/dcd9053975.vtt
# test_clean_sent_mediapi/dcd9053975.vtt done
# Traitement de test_clean_sent_mediapi/4e92363ed6.vtt
# File long enough, traitement : test_clean_sent_mediapi/4e92363ed6.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/4e92363ed6.vtt
# test_clean_sent_mediapi/4e92363ed6.vtt done
# Traitement de test_clean_sent_mediapi/80d22962f8.vtt
# File long enough, traitement : test_clean_sent_mediapi/80d22962f8.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/80d22962f8.vtt
# test_clean_sent_mediapi/80d22962f8.vtt done
# Traitement de test_clean_sent_mediapi/0eb1494855.vtt
# not long enough : test_clean_sent_mediapi/0eb1494855.vtt
# Traitement de test_clean_sent_mediapi/a8d35c1600.vtt
# File long enough, traitement : test_clean_sent_mediapi/a8d35c1600.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/a8d35c1600.vtt
# test_clean_sent_mediapi/a8d35c1600.vtt done
# Traitement de test_clean_sent_mediapi/608fc0be13.vtt
# File long enough, traitement : test_clean_sent_mediapi/608fc0be13.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/608fc0be13.vtt
# test_clean_sent_mediapi/608fc0be13.vtt done
# Traitement de test_clean_sent_mediapi/c11e5da161.vtt
# File long enough, traitement : test_clean_sent_mediapi/c11e5da161.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/c11e5da161.vtt
# test_clean_sent_mediapi/c11e5da161.vtt done
# Traitement de test_clean_sent_mediapi/4b51501587.vtt
# File long enough, traitement : test_clean_sent_mediapi/4b51501587.vtt --- 29
# Ecriture du nouveau fichier test_clean_sent_mediapi/4b51501587.vtt
# test_clean_sent_mediapi/4b51501587.vtt done
# Traitement de test_clean_sent_mediapi/0bfab1c3b4.vtt
# File long enough, traitement : test_clean_sent_mediapi/0bfab1c3b4.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/0bfab1c3b4.vtt
# test_clean_sent_mediapi/0bfab1c3b4.vtt done
# Traitement de test_clean_sent_mediapi/12b9062560.vtt
# not long enough : test_clean_sent_mediapi/12b9062560.vtt
# Traitement de test_clean_sent_mediapi/eb7811a094.vtt
# not long enough : test_clean_sent_mediapi/eb7811a094.vtt
# Traitement de test_clean_sent_mediapi/491aadc1cf.vtt
# File long enough, traitement : test_clean_sent_mediapi/491aadc1cf.vtt --- 31
# Ecriture du nouveau fichier test_clean_sent_mediapi/491aadc1cf.vtt
# test_clean_sent_mediapi/491aadc1cf.vtt done
# Traitement de test_clean_sent_mediapi/eea98dceef.vtt
# File long enough, traitement : test_clean_sent_mediapi/eea98dceef.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/eea98dceef.vtt
# test_clean_sent_mediapi/eea98dceef.vtt done
# Traitement de test_clean_sent_mediapi/11b9db4892.vtt
# not long enough : test_clean_sent_mediapi/11b9db4892.vtt
# Traitement de test_clean_sent_mediapi/9f59e3b226.vtt
# not long enough : test_clean_sent_mediapi/9f59e3b226.vtt
# Traitement de test_clean_sent_mediapi/82ee104b19.vtt
# not long enough : test_clean_sent_mediapi/82ee104b19.vtt
# Traitement de test_clean_sent_mediapi/14a49c07ef.vtt
# File long enough, traitement : test_clean_sent_mediapi/14a49c07ef.vtt --- 91
# Ecriture du nouveau fichier test_clean_sent_mediapi/14a49c07ef.vtt
# test_clean_sent_mediapi/14a49c07ef.vtt done
# Traitement de test_clean_sent_mediapi/7631f48964.vtt
# File long enough, traitement : test_clean_sent_mediapi/7631f48964.vtt --- 66
# Ecriture du nouveau fichier test_clean_sent_mediapi/7631f48964.vtt
# test_clean_sent_mediapi/7631f48964.vtt done
# Traitement de test_clean_sent_mediapi/e597c8cd01.vtt
# File long enough, traitement : test_clean_sent_mediapi/e597c8cd01.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/e597c8cd01.vtt
# test_clean_sent_mediapi/e597c8cd01.vtt done
# Traitement de test_clean_sent_mediapi/fad6c87636.vtt
# File long enough, traitement : test_clean_sent_mediapi/fad6c87636.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/fad6c87636.vtt
# test_clean_sent_mediapi/fad6c87636.vtt done
# Traitement de test_clean_sent_mediapi/d3a84a8ccd.vtt
# not long enough : test_clean_sent_mediapi/d3a84a8ccd.vtt
# Traitement de test_clean_sent_mediapi/e1f484b5f8.vtt
# File long enough, traitement : test_clean_sent_mediapi/e1f484b5f8.vtt --- 64
# Ecriture du nouveau fichier test_clean_sent_mediapi/e1f484b5f8.vtt
# test_clean_sent_mediapi/e1f484b5f8.vtt done
# Traitement de test_clean_sent_mediapi/ac9ff299f9.vtt
# not long enough : test_clean_sent_mediapi/ac9ff299f9.vtt
# Traitement de test_clean_sent_mediapi/1371e28e24.vtt
# File long enough, traitement : test_clean_sent_mediapi/1371e28e24.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/1371e28e24.vtt
# test_clean_sent_mediapi/1371e28e24.vtt done
# Traitement de test_clean_sent_mediapi/dd977a1f2a.vtt
# File long enough, traitement : test_clean_sent_mediapi/dd977a1f2a.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/dd977a1f2a.vtt
# test_clean_sent_mediapi/dd977a1f2a.vtt done
# Traitement de test_clean_sent_mediapi/2a6ad1a50a.vtt
# File long enough, traitement : test_clean_sent_mediapi/2a6ad1a50a.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/2a6ad1a50a.vtt
# test_clean_sent_mediapi/2a6ad1a50a.vtt done
# Traitement de test_clean_sent_mediapi/1ff266482c.vtt
# File long enough, traitement : test_clean_sent_mediapi/1ff266482c.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/1ff266482c.vtt
# test_clean_sent_mediapi/1ff266482c.vtt done
# Traitement de test_clean_sent_mediapi/2a59b007d4.vtt
# File long enough, traitement : test_clean_sent_mediapi/2a59b007d4.vtt --- 13
# Ecriture du nouveau fichier test_clean_sent_mediapi/2a59b007d4.vtt
# test_clean_sent_mediapi/2a59b007d4.vtt done
# Traitement de test_clean_sent_mediapi/7093118618.vtt
# not long enough : test_clean_sent_mediapi/7093118618.vtt
# Traitement de test_clean_sent_mediapi/6648393ad0.vtt
# File long enough, traitement : test_clean_sent_mediapi/6648393ad0.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/6648393ad0.vtt
# test_clean_sent_mediapi/6648393ad0.vtt done
# Traitement de test_clean_sent_mediapi/042af81098.vtt
# not long enough : test_clean_sent_mediapi/042af81098.vtt
# Traitement de test_clean_sent_mediapi/8c26149486.vtt
# File long enough, traitement : test_clean_sent_mediapi/8c26149486.vtt --- 40
# Ecriture du nouveau fichier test_clean_sent_mediapi/8c26149486.vtt
# test_clean_sent_mediapi/8c26149486.vtt done
# Traitement de test_clean_sent_mediapi/ef4b03eab2.vtt
# File long enough, traitement : test_clean_sent_mediapi/ef4b03eab2.vtt --- 79
# Ecriture du nouveau fichier test_clean_sent_mediapi/ef4b03eab2.vtt
# test_clean_sent_mediapi/ef4b03eab2.vtt done
# Traitement de test_clean_sent_mediapi/826afd29f8.vtt
# File long enough, traitement : test_clean_sent_mediapi/826afd29f8.vtt --- 86
# Ecriture du nouveau fichier test_clean_sent_mediapi/826afd29f8.vtt
# test_clean_sent_mediapi/826afd29f8.vtt done
# Traitement de test_clean_sent_mediapi/040fde163f.vtt
# File long enough, traitement : test_clean_sent_mediapi/040fde163f.vtt --- 26
# Ecriture du nouveau fichier test_clean_sent_mediapi/040fde163f.vtt
# test_clean_sent_mediapi/040fde163f.vtt done
# Traitement de test_clean_sent_mediapi/4cc54e86f5.vtt
# File long enough, traitement : test_clean_sent_mediapi/4cc54e86f5.vtt --- 50
# Ecriture du nouveau fichier test_clean_sent_mediapi/4cc54e86f5.vtt
# test_clean_sent_mediapi/4cc54e86f5.vtt done
# Traitement de test_clean_sent_mediapi/2fee0f7592.vtt
# File long enough, traitement : test_clean_sent_mediapi/2fee0f7592.vtt --- 88
# Ecriture du nouveau fichier test_clean_sent_mediapi/2fee0f7592.vtt
# test_clean_sent_mediapi/2fee0f7592.vtt done
# Traitement de test_clean_sent_mediapi/9e5e128447.vtt
# not long enough : test_clean_sent_mediapi/9e5e128447.vtt
# Traitement de test_clean_sent_mediapi/c407147f2f.vtt
# not long enough : test_clean_sent_mediapi/c407147f2f.vtt
# Traitement de test_clean_sent_mediapi/8d58d72944.vtt
# File long enough, traitement : test_clean_sent_mediapi/8d58d72944.vtt --- 109
# Ecriture du nouveau fichier test_clean_sent_mediapi/8d58d72944.vtt
# test_clean_sent_mediapi/8d58d72944.vtt done
# Traitement de test_clean_sent_mediapi/05211c15bf.vtt
# File long enough, traitement : test_clean_sent_mediapi/05211c15bf.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/05211c15bf.vtt
# test_clean_sent_mediapi/05211c15bf.vtt done
# Traitement de test_clean_sent_mediapi/5351d97f20.vtt
# not long enough : test_clean_sent_mediapi/5351d97f20.vtt
# Traitement de test_clean_sent_mediapi/d1636da393.vtt
# File long enough, traitement : test_clean_sent_mediapi/d1636da393.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/d1636da393.vtt
# test_clean_sent_mediapi/d1636da393.vtt done
# Traitement de test_clean_sent_mediapi/28420f7cbe.vtt
# File long enough, traitement : test_clean_sent_mediapi/28420f7cbe.vtt --- 82
# Ecriture du nouveau fichier test_clean_sent_mediapi/28420f7cbe.vtt
# test_clean_sent_mediapi/28420f7cbe.vtt done
# Traitement de test_clean_sent_mediapi/e21f0e23a7.vtt
# File long enough, traitement : test_clean_sent_mediapi/e21f0e23a7.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/e21f0e23a7.vtt
# test_clean_sent_mediapi/e21f0e23a7.vtt done
# Traitement de test_clean_sent_mediapi/a588a2cf33.vtt
# not long enough : test_clean_sent_mediapi/a588a2cf33.vtt
# Traitement de test_clean_sent_mediapi/33c47d59d2.vtt
# File long enough, traitement : test_clean_sent_mediapi/33c47d59d2.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/33c47d59d2.vtt
# test_clean_sent_mediapi/33c47d59d2.vtt done
# Traitement de test_clean_sent_mediapi/8a6b2fb0ce.vtt
# File long enough, traitement : test_clean_sent_mediapi/8a6b2fb0ce.vtt --- 27
# Ecriture du nouveau fichier test_clean_sent_mediapi/8a6b2fb0ce.vtt
# test_clean_sent_mediapi/8a6b2fb0ce.vtt done
# Traitement de test_clean_sent_mediapi/1cb5e71134.vtt
# File long enough, traitement : test_clean_sent_mediapi/1cb5e71134.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/1cb5e71134.vtt
# test_clean_sent_mediapi/1cb5e71134.vtt done
# Traitement de test_clean_sent_mediapi/b07ede0159.vtt
# File long enough, traitement : test_clean_sent_mediapi/b07ede0159.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/b07ede0159.vtt
# test_clean_sent_mediapi/b07ede0159.vtt done
# Traitement de test_clean_sent_mediapi/6c7ce53264.vtt
# File long enough, traitement : test_clean_sent_mediapi/6c7ce53264.vtt --- 87
# Ecriture du nouveau fichier test_clean_sent_mediapi/6c7ce53264.vtt
# test_clean_sent_mediapi/6c7ce53264.vtt done
# Traitement de test_clean_sent_mediapi/d2de84864b.vtt
# File long enough, traitement : test_clean_sent_mediapi/d2de84864b.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/d2de84864b.vtt
# test_clean_sent_mediapi/d2de84864b.vtt done
# Traitement de test_clean_sent_mediapi/9498b85b5b.vtt
# not long enough : test_clean_sent_mediapi/9498b85b5b.vtt
# Traitement de test_clean_sent_mediapi/13d32c0f21.vtt
# File long enough, traitement : test_clean_sent_mediapi/13d32c0f21.vtt --- 66
# Ecriture du nouveau fichier test_clean_sent_mediapi/13d32c0f21.vtt
# test_clean_sent_mediapi/13d32c0f21.vtt done
# Traitement de test_clean_sent_mediapi/e95f4949ed.vtt
# not long enough : test_clean_sent_mediapi/e95f4949ed.vtt
# Traitement de test_clean_sent_mediapi/de31ed9096.vtt
# File long enough, traitement : test_clean_sent_mediapi/de31ed9096.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/de31ed9096.vtt
# test_clean_sent_mediapi/de31ed9096.vtt done
# Traitement de test_clean_sent_mediapi/ba24810c74.vtt
# File long enough, traitement : test_clean_sent_mediapi/ba24810c74.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/ba24810c74.vtt
# test_clean_sent_mediapi/ba24810c74.vtt done
# Traitement de test_clean_sent_mediapi/458237489a.vtt
# File long enough, traitement : test_clean_sent_mediapi/458237489a.vtt --- 17
# Ecriture du nouveau fichier test_clean_sent_mediapi/458237489a.vtt
# test_clean_sent_mediapi/458237489a.vtt done
# Traitement de test_clean_sent_mediapi/a1c9365f5d.vtt
# File long enough, traitement : test_clean_sent_mediapi/a1c9365f5d.vtt --- 70
# Ecriture du nouveau fichier test_clean_sent_mediapi/a1c9365f5d.vtt
# test_clean_sent_mediapi/a1c9365f5d.vtt done
# Traitement de test_clean_sent_mediapi/5f10aa9293.vtt
# File long enough, traitement : test_clean_sent_mediapi/5f10aa9293.vtt --- 89
# Ecriture du nouveau fichier test_clean_sent_mediapi/5f10aa9293.vtt
# test_clean_sent_mediapi/5f10aa9293.vtt done
# Traitement de test_clean_sent_mediapi/5e678b4eb7.vtt
# not long enough : test_clean_sent_mediapi/5e678b4eb7.vtt
# Traitement de test_clean_sent_mediapi/17e4f7380a.vtt
# not long enough : test_clean_sent_mediapi/17e4f7380a.vtt
# Traitement de test_clean_sent_mediapi/207c2f7171.vtt
# not long enough : test_clean_sent_mediapi/207c2f7171.vtt
# Traitement de test_clean_sent_mediapi/f981fbe6af.vtt
# not long enough : test_clean_sent_mediapi/f981fbe6af.vtt
# Traitement de test_clean_sent_mediapi/2af7497055.vtt
# File long enough, traitement : test_clean_sent_mediapi/2af7497055.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/2af7497055.vtt
# test_clean_sent_mediapi/2af7497055.vtt done
# Traitement de test_clean_sent_mediapi/1bf9bf7cec.vtt
# File long enough, traitement : test_clean_sent_mediapi/1bf9bf7cec.vtt --- 20
# Ecriture du nouveau fichier test_clean_sent_mediapi/1bf9bf7cec.vtt
# test_clean_sent_mediapi/1bf9bf7cec.vtt done
# Traitement de test_clean_sent_mediapi/9ae39abf0b.vtt
# File long enough, traitement : test_clean_sent_mediapi/9ae39abf0b.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/9ae39abf0b.vtt
# test_clean_sent_mediapi/9ae39abf0b.vtt done
# Traitement de test_clean_sent_mediapi/5481e47a19.vtt
# not long enough : test_clean_sent_mediapi/5481e47a19.vtt
# Traitement de test_clean_sent_mediapi/a4064555c2.vtt
# File long enough, traitement : test_clean_sent_mediapi/a4064555c2.vtt --- 75
# Ecriture du nouveau fichier test_clean_sent_mediapi/a4064555c2.vtt
# test_clean_sent_mediapi/a4064555c2.vtt done
# Traitement de test_clean_sent_mediapi/14cf31e15f.vtt
# File long enough, traitement : test_clean_sent_mediapi/14cf31e15f.vtt --- 71
# Ecriture du nouveau fichier test_clean_sent_mediapi/14cf31e15f.vtt
# test_clean_sent_mediapi/14cf31e15f.vtt done
# Traitement de test_clean_sent_mediapi/09c5b8a52b.vtt
# not long enough : test_clean_sent_mediapi/09c5b8a52b.vtt
# Traitement de test_clean_sent_mediapi/1926b5a3cd.vtt
# File long enough, traitement : test_clean_sent_mediapi/1926b5a3cd.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/1926b5a3cd.vtt
# test_clean_sent_mediapi/1926b5a3cd.vtt done
# Traitement de test_clean_sent_mediapi/3010fa2532.vtt
# File long enough, traitement : test_clean_sent_mediapi/3010fa2532.vtt --- 62
# Ecriture du nouveau fichier test_clean_sent_mediapi/3010fa2532.vtt
# test_clean_sent_mediapi/3010fa2532.vtt done
# Traitement de test_clean_sent_mediapi/5edd365f55.vtt
# File long enough, traitement : test_clean_sent_mediapi/5edd365f55.vtt --- 47
# Ecriture du nouveau fichier test_clean_sent_mediapi/5edd365f55.vtt
# test_clean_sent_mediapi/5edd365f55.vtt done
# Traitement de test_clean_sent_mediapi/ad86de5a8c.vtt
# File long enough, traitement : test_clean_sent_mediapi/ad86de5a8c.vtt --- 54
# Ecriture du nouveau fichier test_clean_sent_mediapi/ad86de5a8c.vtt
# test_clean_sent_mediapi/ad86de5a8c.vtt done
# Traitement de test_clean_sent_mediapi/457a01b248.vtt
# File long enough, traitement : test_clean_sent_mediapi/457a01b248.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/457a01b248.vtt
# test_clean_sent_mediapi/457a01b248.vtt done
# Traitement de test_clean_sent_mediapi/110092623c.vtt
# File long enough, traitement : test_clean_sent_mediapi/110092623c.vtt --- 18
# Ecriture du nouveau fichier test_clean_sent_mediapi/110092623c.vtt
# test_clean_sent_mediapi/110092623c.vtt done
# Traitement de test_clean_sent_mediapi/3879c2ece5.vtt
# not long enough : test_clean_sent_mediapi/3879c2ece5.vtt
# Traitement de test_clean_sent_mediapi/e408818334.vtt
# File long enough, traitement : test_clean_sent_mediapi/e408818334.vtt --- 19
# Ecriture du nouveau fichier test_clean_sent_mediapi/e408818334.vtt
# test_clean_sent_mediapi/e408818334.vtt done
# Traitement de test_clean_sent_mediapi/163b0c88eb.vtt
# File long enough, traitement : test_clean_sent_mediapi/163b0c88eb.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/163b0c88eb.vtt
# test_clean_sent_mediapi/163b0c88eb.vtt done
# Traitement de test_clean_sent_mediapi/252c04af8c.vtt
# File long enough, traitement : test_clean_sent_mediapi/252c04af8c.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/252c04af8c.vtt
# test_clean_sent_mediapi/252c04af8c.vtt done
# Traitement de test_clean_sent_mediapi/48be2d5494.vtt
# File long enough, traitement : test_clean_sent_mediapi/48be2d5494.vtt --- 69
# Ecriture du nouveau fichier test_clean_sent_mediapi/48be2d5494.vtt
# test_clean_sent_mediapi/48be2d5494.vtt done
# Traitement de test_clean_sent_mediapi/2c7dd7d7a0.vtt
# not long enough : test_clean_sent_mediapi/2c7dd7d7a0.vtt
# Traitement de test_clean_sent_mediapi/648f2d616a.vtt
# File long enough, traitement : test_clean_sent_mediapi/648f2d616a.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/648f2d616a.vtt
# test_clean_sent_mediapi/648f2d616a.vtt done
# Traitement de test_clean_sent_mediapi/d1a36bfbad.vtt
# not long enough : test_clean_sent_mediapi/d1a36bfbad.vtt
# Traitement de test_clean_sent_mediapi/75f0bcdd54.vtt
# File long enough, traitement : test_clean_sent_mediapi/75f0bcdd54.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/75f0bcdd54.vtt
# test_clean_sent_mediapi/75f0bcdd54.vtt done
# Traitement de test_clean_sent_mediapi/bbfaf1ee13.vtt
# File long enough, traitement : test_clean_sent_mediapi/bbfaf1ee13.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/bbfaf1ee13.vtt
# test_clean_sent_mediapi/bbfaf1ee13.vtt done
# Traitement de test_clean_sent_mediapi/f18b71d989.vtt
# File long enough, traitement : test_clean_sent_mediapi/f18b71d989.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/f18b71d989.vtt
# test_clean_sent_mediapi/f18b71d989.vtt done
# Traitement de test_clean_sent_mediapi/2f1e1d3af4.vtt
# File long enough, traitement : test_clean_sent_mediapi/2f1e1d3af4.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/2f1e1d3af4.vtt
# test_clean_sent_mediapi/2f1e1d3af4.vtt done
# Traitement de test_clean_sent_mediapi/7932f9a3de.vtt
# not long enough : test_clean_sent_mediapi/7932f9a3de.vtt
# Traitement de test_clean_sent_mediapi/2f82f046d5.vtt
# File long enough, traitement : test_clean_sent_mediapi/2f82f046d5.vtt --- 23
# Ecriture du nouveau fichier test_clean_sent_mediapi/2f82f046d5.vtt
# test_clean_sent_mediapi/2f82f046d5.vtt done
# Traitement de test_clean_sent_mediapi/4d9577ab24.vtt
# File long enough, traitement : test_clean_sent_mediapi/4d9577ab24.vtt --- 69
# Ecriture du nouveau fichier test_clean_sent_mediapi/4d9577ab24.vtt
# test_clean_sent_mediapi/4d9577ab24.vtt done
# Traitement de test_clean_sent_mediapi/7e4dc844f4.vtt
# File long enough, traitement : test_clean_sent_mediapi/7e4dc844f4.vtt --- 58
# Ecriture du nouveau fichier test_clean_sent_mediapi/7e4dc844f4.vtt
# test_clean_sent_mediapi/7e4dc844f4.vtt done
# Traitement de test_clean_sent_mediapi/061183eb54.vtt
# File long enough, traitement : test_clean_sent_mediapi/061183eb54.vtt --- 80
# Ecriture du nouveau fichier test_clean_sent_mediapi/061183eb54.vtt
# test_clean_sent_mediapi/061183eb54.vtt done
# Traitement de test_clean_sent_mediapi/9398a7ed45.vtt
# File long enough, traitement : test_clean_sent_mediapi/9398a7ed45.vtt --- 72
# Ecriture du nouveau fichier test_clean_sent_mediapi/9398a7ed45.vtt
# test_clean_sent_mediapi/9398a7ed45.vtt done
# Traitement de test_clean_sent_mediapi/530970ed94.vtt
# not long enough : test_clean_sent_mediapi/530970ed94.vtt
# Traitement de test_clean_sent_mediapi/657dca485a.vtt
# File long enough, traitement : test_clean_sent_mediapi/657dca485a.vtt --- 24
# Ecriture du nouveau fichier test_clean_sent_mediapi/657dca485a.vtt
# test_clean_sent_mediapi/657dca485a.vtt done
# Traitement de test_clean_sent_mediapi/2c0e5e2432.vtt
# not long enough : test_clean_sent_mediapi/2c0e5e2432.vtt
# Traitement de test_clean_sent_mediapi/1283dc2bc6.vtt
# File long enough, traitement : test_clean_sent_mediapi/1283dc2bc6.vtt --- 37
# Ecriture du nouveau fichier test_clean_sent_mediapi/1283dc2bc6.vtt
# test_clean_sent_mediapi/1283dc2bc6.vtt done
# Traitement de test_clean_sent_mediapi/55b79b1f96.vtt
# not long enough : test_clean_sent_mediapi/55b79b1f96.vtt
# Traitement de test_clean_sent_mediapi/36129e8e7e.vtt
# File long enough, traitement : test_clean_sent_mediapi/36129e8e7e.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/36129e8e7e.vtt
# test_clean_sent_mediapi/36129e8e7e.vtt done
# Traitement de test_clean_sent_mediapi/66b8ddb330.vtt
# not long enough : test_clean_sent_mediapi/66b8ddb330.vtt
# Traitement de test_clean_sent_mediapi/8fc0505a8e.vtt
# File long enough, traitement : test_clean_sent_mediapi/8fc0505a8e.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/8fc0505a8e.vtt
# test_clean_sent_mediapi/8fc0505a8e.vtt done
# Traitement de test_clean_sent_mediapi/91c3a16492.vtt
# not long enough : test_clean_sent_mediapi/91c3a16492.vtt
# Traitement de test_clean_sent_mediapi/87f4b77d47.vtt
# File long enough, traitement : test_clean_sent_mediapi/87f4b77d47.vtt --- 86
# Ecriture du nouveau fichier test_clean_sent_mediapi/87f4b77d47.vtt
# test_clean_sent_mediapi/87f4b77d47.vtt done
# Traitement de test_clean_sent_mediapi/a8318f25e7.vtt
# not long enough : test_clean_sent_mediapi/a8318f25e7.vtt
# Traitement de test_clean_sent_mediapi/b4ce85fbf7.vtt
# File long enough, traitement : test_clean_sent_mediapi/b4ce85fbf7.vtt --- 44
# Ecriture du nouveau fichier test_clean_sent_mediapi/b4ce85fbf7.vtt
# test_clean_sent_mediapi/b4ce85fbf7.vtt done
# Traitement de test_clean_sent_mediapi/647638a97c.vtt
# File long enough, traitement : test_clean_sent_mediapi/647638a97c.vtt --- 44
# Ecriture du nouveau fichier test_clean_sent_mediapi/647638a97c.vtt
# test_clean_sent_mediapi/647638a97c.vtt done
# Traitement de test_clean_sent_mediapi/3c9c76395a.vtt
# not long enough : test_clean_sent_mediapi/3c9c76395a.vtt
# Traitement de test_clean_sent_mediapi/493574a037.vtt
# File long enough, traitement : test_clean_sent_mediapi/493574a037.vtt --- 93
# Ecriture du nouveau fichier test_clean_sent_mediapi/493574a037.vtt
# test_clean_sent_mediapi/493574a037.vtt done
# Traitement de test_clean_sent_mediapi/db1ee8312d.vtt
# File long enough, traitement : test_clean_sent_mediapi/db1ee8312d.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/db1ee8312d.vtt
# test_clean_sent_mediapi/db1ee8312d.vtt done
# Traitement de test_clean_sent_mediapi/3d1087ebe4.vtt
# not long enough : test_clean_sent_mediapi/3d1087ebe4.vtt
# Traitement de test_clean_sent_mediapi/3f62714c82.vtt
# File long enough, traitement : test_clean_sent_mediapi/3f62714c82.vtt --- 34
# Ecriture du nouveau fichier test_clean_sent_mediapi/3f62714c82.vtt
# test_clean_sent_mediapi/3f62714c82.vtt done
# Traitement de test_clean_sent_mediapi/1b4b91655b.vtt
# File long enough, traitement : test_clean_sent_mediapi/1b4b91655b.vtt --- 60
# Ecriture du nouveau fichier test_clean_sent_mediapi/1b4b91655b.vtt
# test_clean_sent_mediapi/1b4b91655b.vtt done
# Traitement de test_clean_sent_mediapi/78d0acb6e7.vtt
# File long enough, traitement : test_clean_sent_mediapi/78d0acb6e7.vtt --- 15
# Ecriture du nouveau fichier test_clean_sent_mediapi/78d0acb6e7.vtt
# test_clean_sent_mediapi/78d0acb6e7.vtt done
# Traitement de test_clean_sent_mediapi/245a286c8e.vtt
# File long enough, traitement : test_clean_sent_mediapi/245a286c8e.vtt --- 4
# Ecriture du nouveau fichier test_clean_sent_mediapi/245a286c8e.vtt
# test_clean_sent_mediapi/245a286c8e.vtt done
# Traitement de test_clean_sent_mediapi/13adb98a30.vtt
# not long enough : test_clean_sent_mediapi/13adb98a30.vtt
# Traitement de test_clean_sent_mediapi/9088be11a1.vtt
# File long enough, traitement : test_clean_sent_mediapi/9088be11a1.vtt --- 41
# Ecriture du nouveau fichier test_clean_sent_mediapi/9088be11a1.vtt
# test_clean_sent_mediapi/9088be11a1.vtt done
# Traitement de test_clean_sent_mediapi/cb28f32304.vtt
# File long enough, traitement : test_clean_sent_mediapi/cb28f32304.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/cb28f32304.vtt
# test_clean_sent_mediapi/cb28f32304.vtt done
# Traitement de test_clean_sent_mediapi/d8687ad02b.vtt
# File long enough, traitement : test_clean_sent_mediapi/d8687ad02b.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/d8687ad02b.vtt
# test_clean_sent_mediapi/d8687ad02b.vtt done
# Traitement de test_clean_sent_mediapi/b58d9b077e.vtt
# not long enough : test_clean_sent_mediapi/b58d9b077e.vtt
# Traitement de test_clean_sent_mediapi/1cb22a2279.vtt
# File long enough, traitement : test_clean_sent_mediapi/1cb22a2279.vtt --- 38
# Ecriture du nouveau fichier test_clean_sent_mediapi/1cb22a2279.vtt
# test_clean_sent_mediapi/1cb22a2279.vtt done
# Traitement de test_clean_sent_mediapi/2fc7967195.vtt
# not long enough : test_clean_sent_mediapi/2fc7967195.vtt
# Traitement de test_clean_sent_mediapi/14595aa066.vtt
# not long enough : test_clean_sent_mediapi/14595aa066.vtt
# Traitement de test_clean_sent_mediapi/879dece3e4.vtt
# not long enough : test_clean_sent_mediapi/879dece3e4.vtt
# Traitement de test_clean_sent_mediapi/0408ad5430.vtt
# File long enough, traitement : test_clean_sent_mediapi/0408ad5430.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/0408ad5430.vtt
# test_clean_sent_mediapi/0408ad5430.vtt done
# Traitement de test_clean_sent_mediapi/7c92a479c2.vtt
# File long enough, traitement : test_clean_sent_mediapi/7c92a479c2.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/7c92a479c2.vtt
# test_clean_sent_mediapi/7c92a479c2.vtt done
# Traitement de test_clean_sent_mediapi/49c7c0f2b7.vtt
# File long enough, traitement : test_clean_sent_mediapi/49c7c0f2b7.vtt --- 52
# Ecriture du nouveau fichier test_clean_sent_mediapi/49c7c0f2b7.vtt
# test_clean_sent_mediapi/49c7c0f2b7.vtt done
# Traitement de test_clean_sent_mediapi/91900415b1.vtt
# not long enough : test_clean_sent_mediapi/91900415b1.vtt
# Traitement de test_clean_sent_mediapi/611cd8bac1.vtt
# File long enough, traitement : test_clean_sent_mediapi/611cd8bac1.vtt --- 53
# Ecriture du nouveau fichier test_clean_sent_mediapi/611cd8bac1.vtt
# test_clean_sent_mediapi/611cd8bac1.vtt done
# Traitement de test_clean_sent_mediapi/1f963b12c6.vtt
# File long enough, traitement : test_clean_sent_mediapi/1f963b12c6.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/1f963b12c6.vtt
# test_clean_sent_mediapi/1f963b12c6.vtt done
# Traitement de test_clean_sent_mediapi/b5af2cb79d.vtt
# File long enough, traitement : test_clean_sent_mediapi/b5af2cb79d.vtt --- 32
# Ecriture du nouveau fichier test_clean_sent_mediapi/b5af2cb79d.vtt
# test_clean_sent_mediapi/b5af2cb79d.vtt done
# Traitement de test_clean_sent_mediapi/938d9996d9.vtt
# not long enough : test_clean_sent_mediapi/938d9996d9.vtt
# Traitement de test_clean_sent_mediapi/4ae8b991ee.vtt
# not long enough : test_clean_sent_mediapi/4ae8b991ee.vtt
# Traitement de test_clean_sent_mediapi/b03e954ae1.vtt
# File long enough, traitement : test_clean_sent_mediapi/b03e954ae1.vtt --- 50
# Ecriture du nouveau fichier test_clean_sent_mediapi/b03e954ae1.vtt
# test_clean_sent_mediapi/b03e954ae1.vtt done
# Traitement de test_clean_sent_mediapi/2a3064d64a.vtt
# File long enough, traitement : test_clean_sent_mediapi/2a3064d64a.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/2a3064d64a.vtt
# test_clean_sent_mediapi/2a3064d64a.vtt done
# Traitement de test_clean_sent_mediapi/0b2e490c12.vtt
# File long enough, traitement : test_clean_sent_mediapi/0b2e490c12.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/0b2e490c12.vtt
# test_clean_sent_mediapi/0b2e490c12.vtt done
# Traitement de test_clean_sent_mediapi/d1f4036e1d.vtt
# File long enough, traitement : test_clean_sent_mediapi/d1f4036e1d.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/d1f4036e1d.vtt
# test_clean_sent_mediapi/d1f4036e1d.vtt done
# Traitement de test_clean_sent_mediapi/d36b54adb5.vtt
# File long enough, traitement : test_clean_sent_mediapi/d36b54adb5.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/d36b54adb5.vtt
# test_clean_sent_mediapi/d36b54adb5.vtt done
# Traitement de test_clean_sent_mediapi/c810f8ff26.vtt
# File long enough, traitement : test_clean_sent_mediapi/c810f8ff26.vtt --- 29
# Ecriture du nouveau fichier test_clean_sent_mediapi/c810f8ff26.vtt
# test_clean_sent_mediapi/c810f8ff26.vtt done
# Traitement de test_clean_sent_mediapi/7b59ef6cd5.vtt
# File long enough, traitement : test_clean_sent_mediapi/7b59ef6cd5.vtt --- 33
# Ecriture du nouveau fichier test_clean_sent_mediapi/7b59ef6cd5.vtt
# test_clean_sent_mediapi/7b59ef6cd5.vtt done
# Traitement de test_clean_sent_mediapi/3d0f798301.vtt
# File long enough, traitement : test_clean_sent_mediapi/3d0f798301.vtt --- 46
# Ecriture du nouveau fichier test_clean_sent_mediapi/3d0f798301.vtt
# test_clean_sent_mediapi/3d0f798301.vtt done
# Traitement de test_clean_sent_mediapi/f73744b1d5.vtt
# File long enough, traitement : test_clean_sent_mediapi/f73744b1d5.vtt --- 63
# Ecriture du nouveau fichier test_clean_sent_mediapi/f73744b1d5.vtt
# test_clean_sent_mediapi/f73744b1d5.vtt done
# Traitement de test_clean_sent_mediapi/b2803a42cb.vtt
# File long enough, traitement : test_clean_sent_mediapi/b2803a42cb.vtt --- 72
# Ecriture du nouveau fichier test_clean_sent_mediapi/b2803a42cb.vtt
# test_clean_sent_mediapi/b2803a42cb.vtt done
# Traitement de test_clean_sent_mediapi/3614c300a2.vtt
# File long enough, traitement : test_clean_sent_mediapi/3614c300a2.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/3614c300a2.vtt
# test_clean_sent_mediapi/3614c300a2.vtt done
# Traitement de test_clean_sent_mediapi/83ea4b70b9.vtt
# not long enough : test_clean_sent_mediapi/83ea4b70b9.vtt
# Traitement de test_clean_sent_mediapi/29afc9b364.vtt
# File long enough, traitement : test_clean_sent_mediapi/29afc9b364.vtt --- 25
# Ecriture du nouveau fichier test_clean_sent_mediapi/29afc9b364.vtt
# test_clean_sent_mediapi/29afc9b364.vtt done
# Traitement de test_clean_sent_mediapi/82c3c558d8.vtt
# not long enough : test_clean_sent_mediapi/82c3c558d8.vtt
# Traitement de test_clean_sent_mediapi/a835c5a096.vtt
# File long enough, traitement : test_clean_sent_mediapi/a835c5a096.vtt --- 20
# Ecriture du nouveau fichier test_clean_sent_mediapi/a835c5a096.vtt
# test_clean_sent_mediapi/a835c5a096.vtt done
# Traitement de test_clean_sent_mediapi/596653a27e.vtt
# File long enough, traitement : test_clean_sent_mediapi/596653a27e.vtt --- 50
# Ecriture du nouveau fichier test_clean_sent_mediapi/596653a27e.vtt
# test_clean_sent_mediapi/596653a27e.vtt done
# Traitement de test_clean_sent_mediapi/baf83ae145.vtt
# File long enough, traitement : test_clean_sent_mediapi/baf83ae145.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/baf83ae145.vtt
# test_clean_sent_mediapi/baf83ae145.vtt done
# Traitement de test_clean_sent_mediapi/2c5fca9371.vtt
# not long enough : test_clean_sent_mediapi/2c5fca9371.vtt
# Traitement de test_clean_sent_mediapi/6462ce3913.vtt
# File long enough, traitement : test_clean_sent_mediapi/6462ce3913.vtt --- 39
# Ecriture du nouveau fichier test_clean_sent_mediapi/6462ce3913.vtt
# test_clean_sent_mediapi/6462ce3913.vtt done
# Traitement de test_clean_sent_mediapi/581d5c3587.vtt
# not long enough : test_clean_sent_mediapi/581d5c3587.vtt
# Traitement de test_clean_sent_mediapi/50d53eca84.vtt
# File long enough, traitement : test_clean_sent_mediapi/50d53eca84.vtt --- 49
# Ecriture du nouveau fichier test_clean_sent_mediapi/50d53eca84.vtt
# test_clean_sent_mediapi/50d53eca84.vtt done
# Traitement de test_clean_sent_mediapi/b28b182a5e.vtt
# File long enough, traitement : test_clean_sent_mediapi/b28b182a5e.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/b28b182a5e.vtt
# test_clean_sent_mediapi/b28b182a5e.vtt done
# Traitement de test_clean_sent_mediapi/4836a95980.vtt
# File long enough, traitement : test_clean_sent_mediapi/4836a95980.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/4836a95980.vtt
# test_clean_sent_mediapi/4836a95980.vtt done
# Traitement de test_clean_sent_mediapi/02eb959bf5.vtt
# not long enough : test_clean_sent_mediapi/02eb959bf5.vtt
# Traitement de test_clean_sent_mediapi/3f8f90ad63.vtt
# not long enough : test_clean_sent_mediapi/3f8f90ad63.vtt
# Traitement de test_clean_sent_mediapi/a7b7ca660a.vtt
# File long enough, traitement : test_clean_sent_mediapi/a7b7ca660a.vtt --- 36
# Ecriture du nouveau fichier test_clean_sent_mediapi/a7b7ca660a.vtt
# test_clean_sent_mediapi/a7b7ca660a.vtt done
# Traitement de test_clean_sent_mediapi/b79a744ad3.vtt
# File long enough, traitement : test_clean_sent_mediapi/b79a744ad3.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/b79a744ad3.vtt
# test_clean_sent_mediapi/b79a744ad3.vtt done
# Traitement de test_clean_sent_mediapi/56fa0513af.vtt
# not long enough : test_clean_sent_mediapi/56fa0513af.vtt
# Traitement de test_clean_sent_mediapi/ecc384c1fb.vtt
# not long enough : test_clean_sent_mediapi/ecc384c1fb.vtt
# Traitement de test_clean_sent_mediapi/079f72dc4a.vtt
# File long enough, traitement : test_clean_sent_mediapi/079f72dc4a.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/079f72dc4a.vtt
# test_clean_sent_mediapi/079f72dc4a.vtt done
# Traitement de test_clean_sent_mediapi/94b2ecc091.vtt
# not long enough : test_clean_sent_mediapi/94b2ecc091.vtt
# Traitement de test_clean_sent_mediapi/22d5ed99a6.vtt
# not long enough : test_clean_sent_mediapi/22d5ed99a6.vtt
# Traitement de test_clean_sent_mediapi/4b0331f8b5.vtt
# not long enough : test_clean_sent_mediapi/4b0331f8b5.vtt
# ...
# not long enough : test_clean_sent_mediapi/9be12b63e7.vtt
# Traitement de test_clean_sent_mediapi/1597d882e3.vtt
# File long enough, traitement : test_clean_sent_mediapi/1597d882e3.vtt --- 32
# Ecriture du nouveau fichier test_clean_sent_mediapi/1597d882e3.vtt
# test_clean_sent_mediapi/1597d882e3.vtt done
# Traitement de test_clean_sent_mediapi/1900d28353.vtt
# File long enough, traitement : test_clean_sent_mediapi/1900d28353.vtt --- 26
# Ecriture du nouveau fichier test_clean_sent_mediapi/1900d28353.vtt
# test_clean_sent_mediapi/1900d28353.vtt done
# Traitement de test_clean_sent_mediapi/7c3f48aedd.vtt
# File long enough, traitement : test_clean_sent_mediapi/7c3f48aedd.vtt --- 31
# Ecriture du nouveau fichier test_clean_sent_mediapi/7c3f48aedd.vtt
# test_clean_sent_mediapi/7c3f48aedd.vtt done
# Traitement de test_clean_sent_mediapi/a6403d2fdb.vtt
# File long enough, traitement : test_clean_sent_mediapi/a6403d2fdb.vtt --- 106
# Ecriture du nouveau fichier test_clean_sent_mediapi/a6403d2fdb.vtt
# test_clean_sent_mediapi/a6403d2fdb.vtt done
# Traitement de test_clean_sent_mediapi/cb1c85e9b1.vtt
# not long enough : test_clean_sent_mediapi/cb1c85e9b1.vtt
# Traitement de test_clean_sent_mediapi/1f910187a6.vtt
# File long enough, traitement : test_clean_sent_mediapi/1f910187a6.vtt --- 42
# Ecriture du nouveau fichier test_clean_sent_mediapi/1f910187a6.vtt
# test_clean_sent_mediapi/1f910187a6.vtt done
# Traitement de test_clean_sent_mediapi/5aa593b3d8.vtt
# File long enough, traitement : test_clean_sent_mediapi/5aa593b3d8.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/5aa593b3d8.vtt
# test_clean_sent_mediapi/5aa593b3d8.vtt done
# Traitement de test_clean_sent_mediapi/11cf125577.vtt
# File long enough, traitement : test_clean_sent_mediapi/11cf125577.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/11cf125577.vtt
# test_clean_sent_mediapi/11cf125577.vtt done
# Traitement de test_clean_sent_mediapi/401daa4e94.vtt
# File long enough, traitement : test_clean_sent_mediapi/401daa4e94.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/401daa4e94.vtt
# test_clean_sent_mediapi/401daa4e94.vtt done
# Traitement de test_clean_sent_mediapi/11d2454505.vtt
# File long enough, traitement : test_clean_sent_mediapi/11d2454505.vtt --- 8
# Ecriture du nouveau fichier test_clean_sent_mediapi/11d2454505.vtt
# test_clean_sent_mediapi/11d2454505.vtt done
# Traitement de test_clean_sent_mediapi/e1426c448b.vtt
# File long enough, traitement : test_clean_sent_mediapi/e1426c448b.vtt --- 54
# Ecriture du nouveau fichier test_clean_sent_mediapi/e1426c448b.vtt
# test_clean_sent_mediapi/e1426c448b.vtt done
# Traitement de test_clean_sent_mediapi/10c33b8224.vtt
# File long enough, traitement : test_clean_sent_mediapi/10c33b8224.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/10c33b8224.vtt
# test_clean_sent_mediapi/10c33b8224.vtt done
# Traitement de test_clean_sent_mediapi/11c134b52a.vtt
# File long enough, traitement : test_clean_sent_mediapi/11c134b52a.vtt --- 19
# Ecriture du nouveau fichier test_clean_sent_mediapi/11c134b52a.vtt
# test_clean_sent_mediapi/11c134b52a.vtt done
# Traitement de test_clean_sent_mediapi/b54a4872f1.vtt
# File long enough, traitement : test_clean_sent_mediapi/b54a4872f1.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/b54a4872f1.vtt
# test_clean_sent_mediapi/b54a4872f1.vtt done
# Traitement de test_clean_sent_mediapi/bf7a8e3536.vtt
# not long enough : test_clean_sent_mediapi/bf7a8e3536.vtt
# Traitement de test_clean_sent_mediapi/71956066fb.vtt
# not long enough : test_clean_sent_mediapi/71956066fb.vtt
# Traitement de test_clean_sent_mediapi/aa652b7e98.vtt
# File long enough, traitement : test_clean_sent_mediapi/aa652b7e98.vtt --- 31
# Ecriture du nouveau fichier test_clean_sent_mediapi/aa652b7e98.vtt
# test_clean_sent_mediapi/aa652b7e98.vtt done
# Traitement de test_clean_sent_mediapi/c89d4e9e51.vtt
# File long enough, traitement : test_clean_sent_mediapi/c89d4e9e51.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/c89d4e9e51.vtt
# test_clean_sent_mediapi/c89d4e9e51.vtt done
# Traitement de test_clean_sent_mediapi/a7bc181f15.vtt
# not long enough : test_clean_sent_mediapi/a7bc181f15.vtt
# Traitement de test_clean_sent_mediapi/b1b658bc7d.vtt
# File long enough, traitement : test_clean_sent_mediapi/b1b658bc7d.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/b1b658bc7d.vtt
# test_clean_sent_mediapi/b1b658bc7d.vtt done
# Traitement de test_clean_sent_mediapi/fa49778534.vtt
# not long enough : test_clean_sent_mediapi/fa49778534.vtt
# Traitement de test_clean_sent_mediapi/8ff5cdd8d1.vtt
# not long enough : test_clean_sent_mediapi/8ff5cdd8d1.vtt
# Traitement de test_clean_sent_mediapi/e3348417a4.vtt
# File long enough, traitement : test_clean_sent_mediapi/e3348417a4.vtt --- 56
# Ecriture du nouveau fichier test_clean_sent_mediapi/e3348417a4.vtt
# test_clean_sent_mediapi/e3348417a4.vtt done
# Traitement de test_clean_sent_mediapi/6d7058d758.vtt
# File long enough, traitement : test_clean_sent_mediapi/6d7058d758.vtt --- 46
# Ecriture du nouveau fichier test_clean_sent_mediapi/6d7058d758.vtt
# test_clean_sent_mediapi/6d7058d758.vtt done
# Traitement de test_clean_sent_mediapi/6c868284a0.vtt
# File long enough, traitement : test_clean_sent_mediapi/6c868284a0.vtt --- 69
# Ecriture du nouveau fichier test_clean_sent_mediapi/6c868284a0.vtt
# test_clean_sent_mediapi/6c868284a0.vtt done
# Traitement de test_clean_sent_mediapi/22339d12cd.vtt
# File long enough, traitement : test_clean_sent_mediapi/22339d12cd.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/22339d12cd.vtt
# test_clean_sent_mediapi/22339d12cd.vtt done
# Traitement de test_clean_sent_mediapi/9aa4bdc1e9.vtt
# File long enough, traitement : test_clean_sent_mediapi/9aa4bdc1e9.vtt --- 39
# Ecriture du nouveau fichier test_clean_sent_mediapi/9aa4bdc1e9.vtt
# test_clean_sent_mediapi/9aa4bdc1e9.vtt done
# Traitement de test_clean_sent_mediapi/94b345cd57.vtt
# File long enough, traitement : test_clean_sent_mediapi/94b345cd57.vtt --- 22
# Ecriture du nouveau fichier test_clean_sent_mediapi/94b345cd57.vtt
# test_clean_sent_mediapi/94b345cd57.vtt done
# Traitement de test_clean_sent_mediapi/bdad34a29b.vtt
# File long enough, traitement : test_clean_sent_mediapi/bdad34a29b.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/bdad34a29b.vtt
# test_clean_sent_mediapi/bdad34a29b.vtt done
# Traitement de test_clean_sent_mediapi/bb09c5688c.vtt
# File long enough, traitement : test_clean_sent_mediapi/bb09c5688c.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/bb09c5688c.vtt
# test_clean_sent_mediapi/bb09c5688c.vtt done
# Traitement de test_clean_sent_mediapi/b102a1e163.vtt
# File long enough, traitement : test_clean_sent_mediapi/b102a1e163.vtt --- 108
# Ecriture du nouveau fichier test_clean_sent_mediapi/b102a1e163.vtt
# test_clean_sent_mediapi/b102a1e163.vtt done
# Traitement de test_clean_sent_mediapi/81d3ca0ba7.vtt
# File long enough, traitement : test_clean_sent_mediapi/81d3ca0ba7.vtt --- 87
# Ecriture du nouveau fichier test_clean_sent_mediapi/81d3ca0ba7.vtt
# test_clean_sent_mediapi/81d3ca0ba7.vtt done
# Traitement de test_clean_sent_mediapi/5f586b7c7d.vtt
# not long enough : test_clean_sent_mediapi/5f586b7c7d.vtt
# Traitement de test_clean_sent_mediapi/8d6dcc66f1.vtt
# not long enough : test_clean_sent_mediapi/8d6dcc66f1.vtt
# Traitement de test_clean_sent_mediapi/798bb4ecf4.vtt
# File long enough, traitement : test_clean_sent_mediapi/798bb4ecf4.vtt --- 27
# Ecriture du nouveau fichier test_clean_sent_mediapi/798bb4ecf4.vtt
# test_clean_sent_mediapi/798bb4ecf4.vtt done
# Traitement de test_clean_sent_mediapi/4d7c882a41.vtt
# not long enough : test_clean_sent_mediapi/4d7c882a41.vtt
# Traitement de test_clean_sent_mediapi/0be0cf2056.vtt
# File long enough, traitement : test_clean_sent_mediapi/0be0cf2056.vtt --- 71
# Ecriture du nouveau fichier test_clean_sent_mediapi/0be0cf2056.vtt
# test_clean_sent_mediapi/0be0cf2056.vtt done
# Traitement de test_clean_sent_mediapi/c02ca8a63b.vtt
# not long enough : test_clean_sent_mediapi/c02ca8a63b.vtt
# Traitement de test_clean_sent_mediapi/6e81b7d1cf.vtt
# File long enough, traitement : test_clean_sent_mediapi/6e81b7d1cf.vtt --- 16
# Ecriture du nouveau fichier test_clean_sent_mediapi/6e81b7d1cf.vtt
# test_clean_sent_mediapi/6e81b7d1cf.vtt done
# Traitement de test_clean_sent_mediapi/20f4ef55ef.vtt
# File long enough, traitement : test_clean_sent_mediapi/20f4ef55ef.vtt --- 65
# Ecriture du nouveau fichier test_clean_sent_mediapi/20f4ef55ef.vtt
# test_clean_sent_mediapi/20f4ef55ef.vtt done
# Traitement de test_clean_sent_mediapi/7d3673c879.vtt
# not long enough : test_clean_sent_mediapi/7d3673c879.vtt
# Traitement de test_clean_sent_mediapi/3e2d70b57f.vtt
# File long enough, traitement : test_clean_sent_mediapi/3e2d70b57f.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/3e2d70b57f.vtt
# test_clean_sent_mediapi/3e2d70b57f.vtt done
# Traitement de test_clean_sent_mediapi/4a6ad3be05.vtt
# not long enough : test_clean_sent_mediapi/4a6ad3be05.vtt
# Traitement de test_clean_sent_mediapi/29c70e05fd.vtt
# not long enough : test_clean_sent_mediapi/29c70e05fd.vtt
# Traitement de test_clean_sent_mediapi/2e445f0c29.vtt
# File long enough, traitement : test_clean_sent_mediapi/2e445f0c29.vtt --- 62
# Ecriture du nouveau fichier test_clean_sent_mediapi/2e445f0c29.vtt
# test_clean_sent_mediapi/2e445f0c29.vtt done
# Traitement de test_clean_sent_mediapi/034e97db12.vtt
# not long enough : test_clean_sent_mediapi/034e97db12.vtt
# Traitement de test_clean_sent_mediapi/f25b099f70.vtt
# File long enough, traitement : test_clean_sent_mediapi/f25b099f70.vtt --- 45
# Ecriture du nouveau fichier test_clean_sent_mediapi/f25b099f70.vtt
# test_clean_sent_mediapi/f25b099f70.vtt done
# Traitement de test_clean_sent_mediapi/840a9ef102.vtt
# File long enough, traitement : test_clean_sent_mediapi/840a9ef102.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/840a9ef102.vtt
# test_clean_sent_mediapi/840a9ef102.vtt done
# Traitement de test_clean_sent_mediapi/2486641c7f.vtt
# not long enough : test_clean_sent_mediapi/2486641c7f.vtt
# Traitement de test_clean_sent_mediapi/26e86eed1d.vtt
# File long enough, traitement : test_clean_sent_mediapi/26e86eed1d.vtt --- 75
# Ecriture du nouveau fichier test_clean_sent_mediapi/26e86eed1d.vtt
# test_clean_sent_mediapi/26e86eed1d.vtt done
# Traitement de test_clean_sent_mediapi/5c91a69806.vtt
# File long enough, traitement : test_clean_sent_mediapi/5c91a69806.vtt --- 54
# Ecriture du nouveau fichier test_clean_sent_mediapi/5c91a69806.vtt
# test_clean_sent_mediapi/5c91a69806.vtt done
# Traitement de test_clean_sent_mediapi/a6751ed1ac.vtt
# not long enough : test_clean_sent_mediapi/a6751ed1ac.vtt
# Traitement de test_clean_sent_mediapi/bfcef7c2b3.vtt
# File long enough, traitement : test_clean_sent_mediapi/bfcef7c2b3.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/bfcef7c2b3.vtt
# test_clean_sent_mediapi/bfcef7c2b3.vtt done
# Traitement de test_clean_sent_mediapi/6fe1be8eeb.vtt
# File long enough, traitement : test_clean_sent_mediapi/6fe1be8eeb.vtt --- 52
# Ecriture du nouveau fichier test_clean_sent_mediapi/6fe1be8eeb.vtt
# test_clean_sent_mediapi/6fe1be8eeb.vtt done
# Traitement de test_clean_sent_mediapi/2c2dfd3fc9.vtt
# File long enough, traitement : test_clean_sent_mediapi/2c2dfd3fc9.vtt --- 63
# Ecriture du nouveau fichier test_clean_sent_mediapi/2c2dfd3fc9.vtt
# test_clean_sent_mediapi/2c2dfd3fc9.vtt done
# Traitement de test_clean_sent_mediapi/9648e8f26c.vtt
# File long enough, traitement : test_clean_sent_mediapi/9648e8f26c.vtt --- 9
# Ecriture du nouveau fichier test_clean_sent_mediapi/9648e8f26c.vtt
# test_clean_sent_mediapi/9648e8f26c.vtt done
# Traitement de test_clean_sent_mediapi/c5f16d8593.vtt
# not long enough : test_clean_sent_mediapi/c5f16d8593.vtt
# Traitement de test_clean_sent_mediapi/81dadd7460.vtt
# not long enough : test_clean_sent_mediapi/81dadd7460.vtt
# Traitement de test_clean_sent_mediapi/5461b5bde9.vtt
# File long enough, traitement : test_clean_sent_mediapi/5461b5bde9.vtt --- 62
# Ecriture du nouveau fichier test_clean_sent_mediapi/5461b5bde9.vtt
# test_clean_sent_mediapi/5461b5bde9.vtt done
# Traitement de test_clean_sent_mediapi/8c5bc3ccfb.vtt
# File long enough, traitement : test_clean_sent_mediapi/8c5bc3ccfb.vtt --- 12
# Ecriture du nouveau fichier test_clean_sent_mediapi/8c5bc3ccfb.vtt
# test_clean_sent_mediapi/8c5bc3ccfb.vtt done
# Traitement de test_clean_sent_mediapi/3cdedd9322.vtt
# File long enough, traitement : test_clean_sent_mediapi/3cdedd9322.vtt --- 11
# Ecriture du nouveau fichier test_clean_sent_mediapi/3cdedd9322.vtt
# test_clean_sent_mediapi/3cdedd9322.vtt done
# Traitement de test_clean_sent_mediapi/9d6d788d6f.vtt
# not long enough : test_clean_sent_mediapi/9d6d788d6f.vtt
# Traitement de test_clean_sent_mediapi/29b3d8f02f.vtt
# not long enough : test_clean_sent_mediapi/29b3d8f02f.vtt
# Traitement de test_clean_sent_mediapi/0adba1635f.vtt
# File long enough, traitement : test_clean_sent_mediapi/0adba1635f.vtt --- 38
# Ecriture du nouveau fichier test_clean_sent_mediapi/0adba1635f.vtt
# test_clean_sent_mediapi/0adba1635f.vtt done
# Traitement de test_clean_sent_mediapi/da4deaad0b.vtt
# File long enough, traitement : test_clean_sent_mediapi/da4deaad0b.vtt --- 34
# Ecriture du nouveau fichier test_clean_sent_mediapi/da4deaad0b.vtt
# test_clean_sent_mediapi/da4deaad0b.vtt done
# Traitement de test_clean_sent_mediapi/32dcb171f1.vtt
# File long enough, traitement : test_clean_sent_mediapi/32dcb171f1.vtt --- 41
# Ecriture du nouveau fichier test_clean_sent_mediapi/32dcb171f1.vtt
# test_clean_sent_mediapi/32dcb171f1.vtt done
# Traitement de test_clean_sent_mediapi/b5e53a7d55.vtt
# File long enough, traitement : test_clean_sent_mediapi/b5e53a7d55.vtt --- 67
# Ecriture du nouveau fichier test_clean_sent_mediapi/b5e53a7d55.vtt
# test_clean_sent_mediapi/b5e53a7d55.vtt done
# Traitement de test_clean_sent_mediapi/3bfd5a2d10.vtt
# File long enough, traitement : test_clean_sent_mediapi/3bfd5a2d10.vtt --- 19
# Ecriture du nouveau fichier test_clean_sent_mediapi/3bfd5a2d10.vtt
# test_clean_sent_mediapi/3bfd5a2d10.vtt done
# Traitement de test_clean_sent_mediapi/1ee409d870.vtt
# File long enough, traitement : test_clean_sent_mediapi/1ee409d870.vtt --- 5
# Ecriture du nouveau fichier test_clean_sent_mediapi/1ee409d870.vtt
# test_clean_sent_mediapi/1ee409d870.vtt done
# Traitement de test_clean_sent_mediapi/5626f0426c.vtt
# File long enough, traitement : test_clean_sent_mediapi/5626f0426c.vtt --- 71
# Ecriture du nouveau fichier test_clean_sent_mediapi/5626f0426c.vtt
# test_clean_sent_mediapi/5626f0426c.vtt done
# Traitement de test_clean_sent_mediapi/bcc5f33667.vtt
# File long enough, traitement : test_clean_sent_mediapi/bcc5f33667.vtt --- 71
# Ecriture du nouveau fichier test_clean_sent_mediapi/bcc5f33667.vtt
# test_clean_sent_mediapi/bcc5f33667.vtt done
# Traitement de test_clean_sent_mediapi/3de1279be3.vtt
# File long enough, traitement : test_clean_sent_mediapi/3de1279be3.vtt --- 290
# Ecriture du nouveau fichier test_clean_sent_mediapi/3de1279be3.vtt
# test_clean_sent_mediapi/3de1279be3.vtt done
# Traitement de test_clean_sent_mediapi/1f84300c69.vtt
# File long enough, traitement : test_clean_sent_mediapi/1f84300c69.vtt --- 76
# Ecriture du nouveau fichier test_clean_sent_mediapi/1f84300c69.vtt
# test_clean_sent_mediapi/1f84300c69.vtt done
# Traitement de test_clean_sent_mediapi/7cfbe856ee.vtt
# File long enough, traitement : test_clean_sent_mediapi/7cfbe856ee.vtt --- 7
# Ecriture du nouveau fichier test_clean_sent_mediapi/7cfbe856ee.vtt
# test_clean_sent_mediapi/7cfbe856ee.vtt done
# Traitement de test_clean_sent_mediapi/5d458bfe95.vtt
# File long enough, traitement : test_clean_sent_mediapi/5d458bfe95.vtt --- 6
# Ecriture du nouveau fichier test_clean_sent_mediapi/5d458bfe95.vtt
# test_clean_sent_mediapi/5d458bfe95.vtt done
# Traitement de test_clean_sent_mediapi/9dd9c62411.vtt
# not long enough : test_clean_sent_mediapi/9dd9c62411.vtt
# Traitement de test_clean_sent_mediapi/a7c3a0d03b.vtt
# not long enough : test_clean_sent_mediapi/a7c3a0d03b.vtt
# Traitement de test_clean_sent_mediapi/5bf0f577d3.vtt
# File long enough, traitement : test_clean_sent_mediapi/5bf0f577d3.vtt --- 10
# Ecriture du nouveau fichier test_clean_sent_mediapi/5bf0f577d3.vtt
# test_clean_sent_mediapi/5bf0f577d3.vtt done
